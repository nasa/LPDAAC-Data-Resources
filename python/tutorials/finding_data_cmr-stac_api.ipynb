# %% [markdown]
# # Finding Data using the NASA CMR-STAC API
#
# **Summary**
#
# This notebook will demonstrate how to find and access remote sensing data using the [NASA Common Metadata Repository (CMR) SpatioTemporal Asset Catalog (STAC) application programming interface (API)](https://cmr.earthdata.nasa.gov/stac/docs/index.html). The CMR-STAC API is NASA's implementation of the [STAC API specification](https://stacspec.org/) for all Earth Science data archived by NASA Earthdata. The current implementation allows users to execute searches within provider catalogs (e.g., LPCLOUD) to find the STAC Items they are searching for. All the providers can be found at the CMR-STAC endpoint here: <https://cmr.earthdata.nasa.gov/stac/>. In this exercise, we will query the **LPCLOUD** provider to identify STAC Items matching our search criteria.
#
# After finding the results we are interested in, we will write a text file output with links that will allow us to access the HLS assets in the cloud. We will create an example text file of these cloud access links for use via HTTPS and Amazon Web Services s3 buckets.
#
# **What is STAC?**
#
# [SpatioTemporal Asset Catalog (STAC)](https://stacspec.org/) is a specification that provides a common language for interpreting geospatial information in order to standardize indexing and discovering data.
#
# The [STAC specification](https://stacspec.org/core.html) is made up of a collection of related, yet independent specifications that when used together provide search and discovery capabilities for remove assets.
#
# **Four STAC Specifications**
#
# - [STAC Item](https://github.com/radiantearth/stac-spec/blob/master/item-spec/item-spec.md)
# - [STAC Catalog](https://github.com/radiantearth/stac-spec/blob/master/catalog-spec/catalog-spec.md)
# - [STAC Collection](https://github.com/radiantearth/stac-spec/blob/master/collection-spec/collection-spec.md)
# - [STAC API](https://github.com/radiantearth/stac-api-spec)
#
# In the following sections, we will explore each of STAC element using NASA's CMR-STAC API.
#
# **Requirements:**
# - A NASA [Earthdata Login](https://urs.earthdata.nasa.gov/) account is required to download EMIT data
# - *No Python setup requirements if connected to the workshop cloud instance!*
# - **Local Only** Set up Python Environment - See **setup_instructions.md** in the `/setup/` folder to set up a local compatible Python environment
#
# **Learning Objectives:**
# - Understand the STAC Specification and how to user it to find data
# - Write an output text file with links to access the data
# - Open a file and visualize it

# %% [markdown]
# ## Setup
# Import the required packages.

# %%
import requests
from pystac_client import Client
from collections import defaultdict    
import json
import geopandas as gpd
import hvplot.pandas
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="d518d64b-060a-456e-a059-02dccdb2834f" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"38f67886-6ad6-4533-b27d-a47e8a491569":{"version":"3.5.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"dbe2e102f1224bce957a9827b25180d0","client_comm_id":"f363ee7c2baa4f339d08ae43e51f40b8"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1"},{"type":"model","name":"JSComponent1"},{"ty ...
#   var render_items = [{"docid":"38f67886-6ad6-4533-b27d-a47e8a491569","roots":{"p1002":"d518d64b-060a-456e-a059-02dccdb2834f"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %% [markdown]
# ### Submit `GET` request to the CMR STAC API
#
# Use the `reqests` package to submit a `GET` request to the CMR STAC API. We'll parse the response and extract the information we need to navigate the STAC Catalog.

# %%
stac_url = 'https://cmr.earthdata.nasa.gov/stac'

# %%
provider_cat = requests.get(stac_url)

# %% [markdown]
# The CMR STAC API endpoint lists the available providers. Each **provider** is a separate STAC Catalog endpoint that can be used to submit spatiotemporal queries against.

# %%
providers = [p['title'] for p in provider_cat.json()['links'] if 'child' in p['rel']]
print(providers)
# Out:
# ['ESA', 'GHRC', 'ECHO', 'ISRO', 'EDF_DEV04', 'ASF', 'EUMETSAT', 'CDDIS', 'JAXA', 'AU_AADC', 'ECHO10_OPS', 'LANCEAMSR2', 'GESDISCCLD', 'GHRSSTCWIC', 'LARC_CLOUD', 'LANCEMODIS', 'NSIDCV0', 'NSIDC_ECS', 'NCCS', 'OBPG', 'OMINRT', 'USGS_LTA', 'ASIPS', 'ESDIS', 'NSIDC_CPRD', 'ORNL_CLOUD', 'FEDEO', 'MLHUB', 'LAADS', 'LARC_ASDC', 'LPDAAC_ECS', 'NOAA_NCEI', 'OB_DAAC', 'XYZ_PROV', 'GHRC_DAAC', 'CSDA', 'NRSCC', 'CEOS_EXTRA', 'AMD_KOPRI', 'AMD_USAPDC', 'LARC', 'SCIOPS', 'USGS_EROS', 'LPCUMULUS', 'MOPITT', 'GHRC_CLOUD', 'LPCLOUD', 'ORNL_DAAC', 'CCMEO', 'POCLOUD', 'PODAAC', 'SEDAC', 'GES_DISC', 'LM_FIRMS', 'ENVIDAT', 'TROPICSDPC', 'INPE', 'OB_CLOUD', 'USGS', 'all']

# %% [markdown]
# In this example we will explore the `LPCLOUD` provider.

# %%
provider = 'LPCLOUD'

# %%
provider_url = f'{stac_url}/{provider}'
provider_url
# Out:
# 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD'

# %% [markdown]
# We can submit a get request to the provider endpoint to get details about it, including the data collections available.

# %%
cat = requests.get(provider_url)
cat.json()
# Out:
# {'type': 'Catalog',
#  'id': 'LPCLOUD',
#  'title': 'LPCLOUD STAC Catalog',
#  'stac_version': '1.0.0',
#  'description': 'Root STAC catalog for LPCLOUD',
#  'conformsTo': ['https://api.stacspec.org/v1.0.0-rc.2/core',
#   'https://api.stacspec.org/v1.0.0-rc.2/item-search',
#   'https://api.stacspec.org/v1.0.0-rc.2/ogcapi-features',
#   'https://api.stacspec.org/v1.0.0-rc.2/item-search#fields',
#   'https://api.stacspec.org/v1.0.0-rc.2/item-search#features',
#   'https://api.stacspec.org/v1.0.0-rc.2/item-search#query',
#   'https://api.stacspec.org/v1.0.0-rc.2/item-search#sort',
#   'https://api.stacspec.org/v1.0.0-rc.2/item-search#context',
#   'http://www.opengis.net/spec/ogcapi-features-1/1.0/conf/core',
#   'http://www.opengis.net/spec/ogcapi-features-1/1.0/conf/oas30',
#   'http://www.opengis.net/spec/ogcapi-features-1/1.0/conf/geojson',
#   'https://api.stacspec.org/v1.0.0-rc.2/collection-search',
#   'https://api.stacspec.org/v1.0.0-rc.2/collection-search#free-text',
#   'https://api.stacspec.org/v1.0.0-rc.2/collection-search#sort',
#   'http://www.opengis.net/spec/ogcapi-common-1/1.0/conf/simple-query'],
#  'links': [{'rel': 'self',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD',
#    'type': 'application/geo+json',
#    'title': 'Provider Catalog'},
#   {'rel': 'root',
#    'href': 'https://cmr.earthdata.nasa.gov/stac',
#    'type': 'application/geo+json',
#    'title': 'Root Catalog'},
#   {'rel': 'data',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections',
#    'type': 'application/json',
#    'title': 'Provider Collections',
#    'method': 'GET'},
#   {'rel': 'data',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections',
#    'type': 'application/json',
#    'title': 'Provider Collections',
#    'method': 'POST'},
#   {'rel': 'conformance',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/conformance',
#    'type': 'application/json',
#    'title': 'Conformance Classes'},
#   {'rel': 'service-desc',
#    'href': 'https://api.stacspec.org/v1.0.0-beta.1/openapi.yaml',
#    'type': 'application/yaml',
#    'title': 'OpenAPI Doc'},
#   {'rel': 'service-doc',
#    'href': 'https://api.stacspec.org/v1.0.0-beta.1/index.html',
#    'type': 'text/html',
#    'title': 'HTML documentation'},
#   {'rel': 'search',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search',
#    'type': 'application/geo+json',
#    'title': 'Provider Item Search',
#    'method': 'GET'},
#   {'rel': 'search',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/search',
#    'type': 'application/geo+json',
#    'title': 'Provider Item Search',
#    'method': 'POST'},
#   {'rel': 'next',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD?cursor=eyJqc29uIjoiW1wibW9kaXMvYXF1YSBsYW5kIHN1cmZhY2UgdGVtcGVyYXR1cmUvMy1iYW5kIGVtaXNzaXZpdHkgZGFpbHkgbDMgZ2xvYmFsIDAuMDVkZWcgY21nIHYwNjFcIixcIkxQQ0xPVURcIixcIk1ZRDIxQzFcIixcIjYxXCIsMjU2NTgwNTgwNSwyOF0ifQ%3D%3D',
#    'type': 'application/json',
#    'title': 'Next page of results'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ASTGTM_NUMNC_003',
#    'title': 'ASTER Global Digital Elevation Model Attributes NetCDF V003',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ASTGTM_NC_003',
#    'title': 'ASTER Global Digital Elevation Model NetCDF V003',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ASTGTM_003',
#    'title': 'ASTER Global Digital Elevation Model V003',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/AG1km_003',
#    'title': 'ASTER Global Emissivity Dataset, 1 kilometer, HDF5 V003',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/AG100_003',
#    'title': 'ASTER Global Emissivity Dataset, 100 meter, HDF5 V003',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/AG5KMMOH_041',
#    'title': 'ASTER Global Emissivity Dataset, Monthly, 0.05 deg, HDF5 V041',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/CAM5K30CFCLIM_003',
#    'title': 'Combined ASTER and MODIS Emissivity database over Land (CAMEL) Coefficient Climatology Monthly Global 0.05Deg V003',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/CAM5K30CF_002',
#    'title': 'Combined ASTER and MODIS Emissivity database over Land (CAMEL) Coefficient Monthly Global 0.05Deg V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/CAM5K30COVCLIM_003',
#    'title': 'Combined ASTER and MODIS Emissivity database over Land (CAMEL) Covariances Climatology Monthly Global 0.25Deg V003',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/CAM5K30EMCLIM_003',
#    'title': 'Combined ASTER and MODIS Emissivity database over Land (CAMEL) Emissivity Climatology Monthly Global 0.05Deg V003',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/CAM5K30EM_002',
#    'title': 'Combined ASTER and MODIS Emissivity database over Land (CAMEL) Emissivity Monthly Global 0.05Deg V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/CAM5K30UCCLIM_003',
#    'title': 'Combined ASTER and MODIS Emissivity database over Land (CAMEL) Uncertainty Climatology Monthly Global 0.05Deg V003',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/CAM5K30UC_002',
#    'title': 'Combined ASTER and MODIS Emissivity database over Land (CAMEL) Uncertainty Monthly Global 0.05Deg V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/WaterBalance_Daily_Historical_GRIDMET_1.5',
#    'title': 'Daily Historical Water Balance Products for the CONUS',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L2G_CLOUD_002',
#    'title': 'ECOSTRESS Gridded Cloud Mask Instantaneous L2 Global 70 m V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L3G_MET_002',
#    'title': 'ECOSTRESS Gridded Downscaled Meteorology Instantaneous L3 Global 70 m V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L3G_SM_002',
#    'title': 'ECOSTRESS Gridded Downscaled Soil Moisture Instantaneous L3 Global 70 m V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L4G_ESI_002',
#    'title': 'ECOSTRESS Gridded Evaporative Stress Index PT-JPL Instantaneous L4 Global 70 m V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L3G_JET_002',
#    'title': 'ECOSTRESS Gridded Evapotranspiration Instantaneous and Daytime L3 Global 70 m V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L2G_LSTE_002',
#    'title': 'ECOSTRESS Gridded Land Surface Temperature and Emissivity Instantaneous L2 Global 70 m V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L3G_SEB_002',
#    'title': 'ECOSTRESS Gridded Surface Energy Balance Instantaneous L3 Global 70 m V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L1CG_RAD_002',
#    'title': 'ECOSTRESS Gridded Top of Atmosphere Calibrated Radiance Instantaneous L1C Global 70 m V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L4G_WUE_002',
#    'title': 'ECOSTRESS Gridded Water Use Efficiency Instantaneous L4 Global 70 m V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L1B_ATT_002',
#    'title': 'ECOSTRESS Swath Attitude and Ephemeris Instantaneous L1B Global V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L2_CLOUD_002',
#    'title': 'ECOSTRESS Swath Cloud Mask Instantaneous L2 Global 70 m V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L1B_GEO_002',
#    'title': 'ECOSTRESS Swath Geolocation Instantaneous L1B Global 70 m V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L2_LSTE_002',
#    'title': 'ECOSTRESS Swath Land Surface Temperature and Emissivity Instantaneous L2 Global 70 m V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L1B_RAD_002',
#    'title': 'ECOSTRESS Swath Top of Atmosphere Calibrated Radiance Instantaneous L1B Global 70 m V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L2T_STARS_002',
#    'title': 'ECOSTRESS Tiled Ancillary NDVI and Albedo L2 Global 70 m V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L3T_MET_002',
#    'title': 'ECOSTRESS Tiled Downscaled Meteorology Instantaneous L3 Global 70 m V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L3T_SM_002',
#    'title': 'ECOSTRESS Tiled Downscaled Soil Moisture Instantaneous L3 Global 70 m V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L4T_ESI_002',
#    'title': 'ECOSTRESS Tiled Evaporative Stress Index PT-JPL Instantaneous L4 Global 70 m V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L3T_JET_002',
#    'title': 'ECOSTRESS Tiled Evapotranspiration Instantaneous and Daytime L3 Global 70 m V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L2T_LSTE_002',
#    'title': 'ECOSTRESS Tiled Land Surface Temperature and Emissivity Instantaneous L2 Global 70 m V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L3T_SEB_002',
#    'title': 'ECOSTRESS Tiled Surface Energy Balance Instantaneous L3 Global 70 m V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L1CT_RAD_002',
#    'title': 'ECOSTRESS Tiled Top of Atmosphere Calibrated Radiance Instantaneous L1C Global 70 m V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L4T_WUE_002',
#    'title': 'ECOSTRESS Tiled Water Use Efficiency Instantaneous L4 Global 70 m V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL1BRAD_001',
#    'title': 'EMIT L1B At-Sensor Calibrated Radiance and Geolocation Data 60 m V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL1BATT_001',
#    'title': 'EMIT L1B Corrected Spacecraft Attitude and Ephemeris V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL2ARFL_001',
#    'title': 'EMIT L2A Estimated Surface Reflectance and Uncertainty and Masks 60 m V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL2BCO2ENH_001',
#    'title': 'EMIT L2B Carbon Dioxide Enhancement Data 60 m V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL2BCO2PLM_001',
#    'title': 'EMIT L2B Estimated Carbon Dioxide Plume Complexes 60 m V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL2BCH4PLM_001',
#    'title': 'EMIT L2B Estimated Methane Plume Complexes 60 m V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL2BMIN_001',
#    'title': 'EMIT L2B Estimated Mineral Identification and Band Depth and Uncertainty 60 m V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL2BCH4ENH_001',
#    'title': 'EMIT L2B Methane Enhancement Data 60 m V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL3ASA_001',
#    'title': 'EMIT L3 Aggregated Mineral Spectral Abundance and Uncertainty 0.5 Deg V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL4ESM_001',
#    'title': 'EMIT L4 Earth System Model Products V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLORTHO_001',
#    'title': 'G-LiHT Aerial Orthomosaic V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLCHMK_001',
#    'title': 'G-LiHT Canopy Height Model KML V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLCHMT_001',
#    'title': 'G-LiHT Canopy Height Model V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLDSMT_001',
#    'title': 'G-LiHT Digital Surface Model V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLDTMK_001',
#    'title': 'G-LiHT Digital Terrain Model KML V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLDTMT_001',
#    'title': 'G-LiHT Digital Terrain Model V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLHYANC_001',
#    'title': 'G-LiHT Hyperspectral Ancillary V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLRADS_001',
#    'title': 'G-LiHT Hyperspectral Radiance V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLREFL_001',
#    'title': 'G-LiHT Hyperspectral Reflectance V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLHYVI_001',
#    'title': 'G-LiHT Hyperspectral Vegetative Indices V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLLIDARPC_001',
#    'title': 'G-LiHT Lidar Point Cloud V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLMETRICS_001',
#    'title': 'G-LiHT Metrics V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLTRAJECTORY_001',
#    'title': 'G-LiHT Trajectory Data V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GEDI01_B_002',
#    'title': 'GEDI L1B Geolocated Waveform Data Global Footprint Level V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GEDI02_A_002',
#    'title': 'GEDI L2A Elevation and Height Metrics Data Global Footprint Level V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GEDI02_B_002',
#    'title': 'GEDI L2B Canopy Cover and Vertical Profile Metrics Data Global Footprint Level V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFSAD1KCD_001',
#    'title': 'Global Food Security Support Analysis Data (GFSAD) Crop Dominance 2010 Global 1 km V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFSAD1KCM_001',
#    'title': 'Global Food Security Support Analysis Data (GFSAD) Crop Mask 2010 Global 1 km V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFSAD30NACE_001',
#    'title': 'Global Food Security-support Analysis Data (GFSAD) Cropland Extent 2010 North America product 30 m V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFSAD30AFCE_001',
#    'title': 'Global Food Security-support Analysis Data (GFSAD) Cropland Extent 2015 Africa 30 m V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFSAD30AUNZCNMOCE_001',
#    'title': 'Global Food Security-support Analysis Data (GFSAD) Cropland Extent 2015 Australia, New Zealand, China, Mongolia 30 m V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFSAD30EUCEARUMECE_001',
#    'title': 'Global Food Security-support Analysis Data (GFSAD) Cropland Extent 2015 Europe, Central Asia, Russia, Middle East product 30 m V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFSAD30SACE_001',
#    'title': 'Global Food Security-support Analysis Data (GFSAD) Cropland Extent 2015 South America product 30 m V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFSAD30SAAFGIRCE_001',
#    'title': 'Global Food Security-support Analysis Data (GFSAD) Cropland Extent 2015 South Asia, Afghanistan, and Iran product 30 m V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFSAD30SEACE_001',
#    'title': 'Global Food Security-support Analysis Data (GFSAD) Cropland Extent 2015 Southeast and Northeast Asia product 30 m V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFCC30FCC_001',
#    'title': 'Global Forest Cover Change Forest Cover Change Multi-Year Global 30m V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFCC30SR_001',
#    'title': 'Global Forest Cover Change Surface Reflectance Estimates Multi-Year Global 30m V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFCC30TC_003',
#    'title': 'Global Forest Cover Change Tree Cover Multi-Year Global 30m V003',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFCC30WC_001',
#    'title': 'Global Forest Cover Change Water Cover 2000 Global 30m V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GHISACASIA_001',
#    'title': 'Global Hyperspectral Imaging Spectral-library of Agricultural crops for Central Asia V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GHISACONUS_001',
#    'title': 'Global Hyperspectral Imaging Spectral-library of Agricultural crops for Conterminous United States V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLanCE30_001',
#    'title': 'Global Land Cover Mapping and Estimation Yearly 30 m V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30_2.0',
#    'title': 'HLS Landsat Operational Land Imager Surface Reflectance and TOA Brightness Daily Global 30m v2.0',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30_VI_2.0',
#    'title': 'HLS Operational Land Imager Vegetation Indices Daily Global 30 m V2.0',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSS30_2.0',
#    'title': 'HLS Sentinel-2 Multi-spectral Instrument Surface Reflectance Daily Global 30m v2.0',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSS30_VI_2.0',
#    'title': 'HLS Sentinel-2 Multi-spectral Instrument Vegetation Indices Daily Global 30 m V2.0',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/LGRIP30_L1_IRRI_002',
#    'title': 'Landsat-Derived Global Irrigated-Cropland Product L1 2020 30 m V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/LGRIP30_L2_IRRI_002',
#    'title': 'Landsat-Derived Global Irrigated-Cropland Product L2 2020 30 m V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/LGRIP30_L3_002',
#    'title': 'Landsat-derived Global Rainfed and Irrigated-Cropland Product L3 2020 30 m V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/LGRIP30_L1_RAIN_002',
#    'title': 'Landsat-Derived Global Rainfed-Cropland Product L1 2020 30 m V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/LGRIP30_L2_RAIN_002',
#    'title': 'Landsat-Derived Global Rainfed-Cropland Product L2 2020 30 m V002',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/LEOLSTCMG30_001',
#    'title': 'Low Earth Orbit Land Surface Temperature Monthly Global Gridded V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/LPJ_EOSIM_L2_DCH4E_LL_001',
#    'title': 'LPJ-EOSIM L2 Global Simulated Daily Wetland Methane Flux Low Latency V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/LPJ_EOSIM_L2_DCH4E_001',
#    'title': 'LPJ-EOSIM L2 Global Simulated Daily Wetland Methane Flux V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/LPJ_EOSIM_L2_MCH4E_LL_001',
#    'title': 'LPJ-EOSIM L2 Global Simulated Monthly Wetland Methane Flux Low Latency V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/LPJ_EOSIM_L2_MCH4E_001',
#    'title': 'LPJ-EOSIM L2 Global Simulated Monthly Wetland Methane Flux V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VCF5KYR_001',
#    'title': 'MEaSUREs Vegetation Continuous Fields (VCF) Yearly Global 0.05 Deg V001',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD17A2H_061',
#    'title': 'MODIS/Aqua Gross Primary Productivity 8-Day L4 Global 500m SIN Grid V061',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD17A2HGF_061',
#    'title': 'MODIS/Aqua Gross Primary Productivity Gap-Filled 8-Day L4 Global 500m SIN Grid V061',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD21_061',
#    'title': 'MODIS/Aqua Land Surface Temperature/3-Band Emissivity 5-Min L2 1km V061',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD21C2_061',
#    'title': 'MODIS/Aqua Land Surface Temperature/3-Band Emissivity 8-Day L3 Global 0.05Deg CMG V061',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD21A2_061',
#    'title': 'MODIS/Aqua Land Surface Temperature/3-Band Emissivity 8-Day L3 Global 1km SIN Grid V061',
#    'type': 'application/json'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD21C1_061',
#    'title': 'MODIS/Aqua Land Surface Temperature/3-Band Emissivity Daily L3 Global 0.05Deg CMG V061',
#    'type': 'application/json'}]}

# %% [markdown]
# There's a lot if information returned. Filter it using string matching to create a dictionary of collections and their endpoints.

# %%
cols = [{l['href'].split('/')[-1]: l['href']} for l in cat.json() ['links'] if 'child' in l['rel']]
for c in cols:
    print(c)
# Out:
# {'ASTGTM_NUMNC_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ASTGTM_NUMNC_003'}
# {'ASTGTM_NC_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ASTGTM_NC_003'}
# {'ASTGTM_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ASTGTM_003'}
# {'AG1km_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/AG1km_003'}
# {'AG100_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/AG100_003'}
# {'AG5KMMOH_041': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/AG5KMMOH_041'}
# {'CAM5K30CFCLIM_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/CAM5K30CFCLIM_003'}
# {'CAM5K30CF_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/CAM5K30CF_002'}
# {'CAM5K30COVCLIM_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/CAM5K30COVCLIM_003'}
# {'CAM5K30EMCLIM_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/CAM5K30EMCLIM_003'}
# {'CAM5K30EM_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/CAM5K30EM_002'}
# {'CAM5K30UCCLIM_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/CAM5K30UCCLIM_003'}
# {'CAM5K30UC_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/CAM5K30UC_002'}
# {'WaterBalance_Daily_Historical_GRIDMET_1.5': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/WaterBalance_Daily_Historical_GRIDMET_1.5'}
# {'ECO_L2G_CLOUD_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L2G_CLOUD_002'}
# {'ECO_L3G_MET_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L3G_MET_002'}
# {'ECO_L3G_SM_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L3G_SM_002'}
# {'ECO_L4G_ESI_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L4G_ESI_002'}
# {'ECO_L3G_JET_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L3G_JET_002'}
# {'ECO_L2G_LSTE_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L2G_LSTE_002'}
# {'ECO_L3G_SEB_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L3G_SEB_002'}
# {'ECO_L1CG_RAD_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L1CG_RAD_002'}
# {'ECO_L4G_WUE_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L4G_WUE_002'}
# {'ECO_L1B_ATT_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L1B_ATT_002'}
# {'ECO_L2_CLOUD_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L2_CLOUD_002'}
# {'ECO_L1B_GEO_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L1B_GEO_002'}
# {'ECO_L2_LSTE_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L2_LSTE_002'}
# {'ECO_L1B_RAD_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L1B_RAD_002'}
# {'ECO_L2T_STARS_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L2T_STARS_002'}
# {'ECO_L3T_MET_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L3T_MET_002'}
# {'ECO_L3T_SM_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L3T_SM_002'}
# {'ECO_L4T_ESI_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L4T_ESI_002'}
# {'ECO_L3T_JET_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L3T_JET_002'}
# {'ECO_L2T_LSTE_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L2T_LSTE_002'}
# {'ECO_L3T_SEB_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L3T_SEB_002'}
# {'ECO_L1CT_RAD_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L1CT_RAD_002'}
# {'ECO_L4T_WUE_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L4T_WUE_002'}
# {'EMITL1BRAD_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL1BRAD_001'}
# {'EMITL1BATT_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL1BATT_001'}
# {'EMITL2ARFL_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL2ARFL_001'}
# {'EMITL2BCO2ENH_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL2BCO2ENH_001'}
# {'EMITL2BCO2PLM_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL2BCO2PLM_001'}
# {'EMITL2BCH4PLM_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL2BCH4PLM_001'}
# {'EMITL2BMIN_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL2BMIN_001'}
# {'EMITL2BCH4ENH_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL2BCH4ENH_001'}
# {'EMITL3ASA_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL3ASA_001'}
# {'EMITL4ESM_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL4ESM_001'}
# {'GLORTHO_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLORTHO_001'}
# {'GLCHMK_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLCHMK_001'}
# {'GLCHMT_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLCHMT_001'}
# {'GLDSMT_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLDSMT_001'}
# {'GLDTMK_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLDTMK_001'}
# {'GLDTMT_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLDTMT_001'}
# {'GLHYANC_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLHYANC_001'}
# {'GLRADS_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLRADS_001'}
# {'GLREFL_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLREFL_001'}
# {'GLHYVI_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLHYVI_001'}
# {'GLLIDARPC_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLLIDARPC_001'}
# {'GLMETRICS_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLMETRICS_001'}
# {'GLTRAJECTORY_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLTRAJECTORY_001'}
# {'GEDI01_B_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GEDI01_B_002'}
# {'GEDI02_A_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GEDI02_A_002'}
# {'GEDI02_B_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GEDI02_B_002'}
# {'GFSAD1KCD_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFSAD1KCD_001'}
# {'GFSAD1KCM_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFSAD1KCM_001'}
# {'GFSAD30NACE_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFSAD30NACE_001'}
# {'GFSAD30AFCE_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFSAD30AFCE_001'}
# {'GFSAD30AUNZCNMOCE_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFSAD30AUNZCNMOCE_001'}
# {'GFSAD30EUCEARUMECE_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFSAD30EUCEARUMECE_001'}
# {'GFSAD30SACE_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFSAD30SACE_001'}
# {'GFSAD30SAAFGIRCE_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFSAD30SAAFGIRCE_001'}
# {'GFSAD30SEACE_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFSAD30SEACE_001'}
# {'GFCC30FCC_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFCC30FCC_001'}
# {'GFCC30SR_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFCC30SR_001'}
# {'GFCC30TC_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFCC30TC_003'}
# {'GFCC30WC_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFCC30WC_001'}
# {'GHISACASIA_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GHISACASIA_001'}
# {'GHISACONUS_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GHISACONUS_001'}
# {'GLanCE30_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLanCE30_001'}
# {'HLSL30_2.0': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30_2.0'}
# {'HLSL30_VI_2.0': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30_VI_2.0'}
# {'HLSS30_2.0': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSS30_2.0'}
# {'HLSS30_VI_2.0': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSS30_VI_2.0'}
# {'LGRIP30_L1_IRRI_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/LGRIP30_L1_IRRI_002'}
# {'LGRIP30_L2_IRRI_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/LGRIP30_L2_IRRI_002'}
# {'LGRIP30_L3_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/LGRIP30_L3_002'}
# {'LGRIP30_L1_RAIN_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/LGRIP30_L1_RAIN_002'}
# {'LGRIP30_L2_RAIN_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/LGRIP30_L2_RAIN_002'}
# {'LEOLSTCMG30_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/LEOLSTCMG30_001'}
# {'LPJ_EOSIM_L2_DCH4E_LL_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/LPJ_EOSIM_L2_DCH4E_LL_001'}
# {'LPJ_EOSIM_L2_DCH4E_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/LPJ_EOSIM_L2_DCH4E_001'}
# {'LPJ_EOSIM_L2_MCH4E_LL_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/LPJ_EOSIM_L2_MCH4E_LL_001'}
# {'LPJ_EOSIM_L2_MCH4E_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/LPJ_EOSIM_L2_MCH4E_001'}
# {'VCF5KYR_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VCF5KYR_001'}
# {'MYD17A2H_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD17A2H_061'}
# {'MYD17A2HGF_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD17A2HGF_061'}
# {'MYD21_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD21_061'}
# {'MYD21C2_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD21C2_061'}
# {'MYD21A2_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD21A2_061'}
# {'MYD21C1_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD21C1_061'}

# %% [markdown]
# **Notice** that only 10 collections are returned here, but the `LPCLOUD` provider has over 100 data products available in Earthdata Cloud. This is because the CMR STAC API returns 10 collections by default. A `limit` parameter can be added to the end of the `LPCLOUD` STAC API endpoint to increase the number of collections returned at one time, but this can sometimes be time consuming. Here we'll loop through each `next` page link to make a seperate request for the next 10 collections from each available page.

# %%
try:
    print(f"Requesting page:")
    while nxt_pg := [l for l in cat.json()['links'] if 'next' in l['rel']][0]:
        print(f"{nxt_pg['href'].split('=')[-1]}...", end = ' ')
        cat = requests.get(nxt_pg['href'])
        cols.extend([{l['href'].split('/')[-1]: l['href']} for l in cat.json()['links']if 'child' in l['rel']])
except:
    print('No additional pages')
# Out:
# Requesting page:
# eyJqc29uIjoiW1wibW9kaXMvYXF1YSBsYW5kIHN1cmZhY2UgdGVtcGVyYXR1cmUvMy1iYW5kIGVtaXNzaXZpdHkgZGFpbHkgbDMgZ2xvYmFsIDAuMDVkZWcgY21nIHYwNjFcIixcIkxQQ0xPVURcIixcIk1ZRDIxQzFcIixcIjYxXCIsMjU2NTgwNTgwNSwyOF0ifQ%3D%3D... eyJqc29uIjoiW1wibW9kaXMvdGVycmErYXF1YSBicmRmL2FsYmVkbyBuYWRpciBicmRmLWFkanVzdGVkIHJlZiBkYWlseSBsMyBnbG9iYWwgMC4wNWRlZyBjbWcgdjA2MVwiLFwiTFBDTE9VRFwiLFwiTUNENDNDNFwiLFwiNjFcIiwyNTMyNDQ5MTc5LDMwXSJ9... eyJqc29uIjoiW1widmVnZXRhdGlvbiBpbmRleCBhbmQgcGhlbm9sb2d5ICh2aXApIHZlZ2V0YXRpb24gaW5kaWNlcyA3ZGF5cyBnbG9iYWwgMC4wNWRlZyBjbWcgdjAwNFwiLFwiTFBDTE9VRFwiLFwiVklQMDdcIixcIjRcIiwyNzYzMjY4NDQ5LDI0XSJ9... eyJqc29uIjoiW1widmlpcnMvbnBwIHN1cmZhY2UgcmVmbGVjdGFuY2UgZGFpbHkgbDMgZ2xvYmFsIDAuMDVkZWcgY21nIHYwMDJcIixcIkxQQ0xPVURcIixcIlZOUDA5Q01HXCIsXCIyXCIsMjUxOTEyNjc5Myw0NF0ifQ%3D%3D... No additional pages

# %% [markdown]
# Print all available STAC Collections within the `LPCLOUD` catalog.

# %%
print(f'LPCLOUD has {len(cols)} Collections')
# Out:
# LPCLOUD has 409 Collections

# %%
for c in cols:
    print(c)
# Out:
# {'ASTGTM_NUMNC_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ASTGTM_NUMNC_003'}
# {'ASTGTM_NC_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ASTGTM_NC_003'}
# {'ASTGTM_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ASTGTM_003'}
# {'AG1km_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/AG1km_003'}
# {'AG100_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/AG100_003'}
# {'AG5KMMOH_041': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/AG5KMMOH_041'}
# {'CAM5K30CFCLIM_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/CAM5K30CFCLIM_003'}
# {'CAM5K30CF_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/CAM5K30CF_002'}
# {'CAM5K30COVCLIM_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/CAM5K30COVCLIM_003'}
# {'CAM5K30EMCLIM_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/CAM5K30EMCLIM_003'}
# {'CAM5K30EM_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/CAM5K30EM_002'}
# {'CAM5K30UCCLIM_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/CAM5K30UCCLIM_003'}
# {'CAM5K30UC_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/CAM5K30UC_002'}
# {'WaterBalance_Daily_Historical_GRIDMET_1.5': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/WaterBalance_Daily_Historical_GRIDMET_1.5'}
# {'ECO_L2G_CLOUD_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L2G_CLOUD_002'}
# {'ECO_L3G_MET_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L3G_MET_002'}
# {'ECO_L3G_SM_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L3G_SM_002'}
# {'ECO_L4G_ESI_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L4G_ESI_002'}
# {'ECO_L3G_JET_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L3G_JET_002'}
# {'ECO_L2G_LSTE_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L2G_LSTE_002'}
# {'ECO_L3G_SEB_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L3G_SEB_002'}
# {'ECO_L1CG_RAD_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L1CG_RAD_002'}
# {'ECO_L4G_WUE_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L4G_WUE_002'}
# {'ECO_L1B_ATT_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L1B_ATT_002'}
# {'ECO_L2_CLOUD_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L2_CLOUD_002'}
# {'ECO_L1B_GEO_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L1B_GEO_002'}
# {'ECO_L2_LSTE_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L2_LSTE_002'}
# {'ECO_L1B_RAD_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L1B_RAD_002'}
# {'ECO_L2T_STARS_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L2T_STARS_002'}
# {'ECO_L3T_MET_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L3T_MET_002'}
# {'ECO_L3T_SM_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L3T_SM_002'}
# {'ECO_L4T_ESI_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L4T_ESI_002'}
# {'ECO_L3T_JET_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L3T_JET_002'}
# {'ECO_L2T_LSTE_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L2T_LSTE_002'}
# {'ECO_L3T_SEB_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L3T_SEB_002'}
# {'ECO_L1CT_RAD_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L1CT_RAD_002'}
# {'ECO_L4T_WUE_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L4T_WUE_002'}
# {'EMITL1BRAD_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL1BRAD_001'}
# {'EMITL1BATT_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL1BATT_001'}
# {'EMITL2ARFL_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL2ARFL_001'}
# {'EMITL2BCO2ENH_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL2BCO2ENH_001'}
# {'EMITL2BCO2PLM_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL2BCO2PLM_001'}
# {'EMITL2BCH4PLM_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL2BCH4PLM_001'}
# {'EMITL2BMIN_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL2BMIN_001'}
# {'EMITL2BCH4ENH_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL2BCH4ENH_001'}
# {'EMITL3ASA_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL3ASA_001'}
# {'EMITL4ESM_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/EMITL4ESM_001'}
# {'GLORTHO_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLORTHO_001'}
# {'GLCHMK_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLCHMK_001'}
# {'GLCHMT_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLCHMT_001'}
# {'GLDSMT_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLDSMT_001'}
# {'GLDTMK_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLDTMK_001'}
# {'GLDTMT_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLDTMT_001'}
# {'GLHYANC_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLHYANC_001'}
# {'GLRADS_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLRADS_001'}
# {'GLREFL_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLREFL_001'}
# {'GLHYVI_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLHYVI_001'}
# {'GLLIDARPC_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLLIDARPC_001'}
# {'GLMETRICS_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLMETRICS_001'}
# {'GLTRAJECTORY_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLTRAJECTORY_001'}
# {'GEDI01_B_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GEDI01_B_002'}
# {'GEDI02_A_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GEDI02_A_002'}
# {'GEDI02_B_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GEDI02_B_002'}
# {'GFSAD1KCD_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFSAD1KCD_001'}
# {'GFSAD1KCM_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFSAD1KCM_001'}
# {'GFSAD30NACE_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFSAD30NACE_001'}
# {'GFSAD30AFCE_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFSAD30AFCE_001'}
# {'GFSAD30AUNZCNMOCE_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFSAD30AUNZCNMOCE_001'}
# {'GFSAD30EUCEARUMECE_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFSAD30EUCEARUMECE_001'}
# {'GFSAD30SACE_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFSAD30SACE_001'}
# {'GFSAD30SAAFGIRCE_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFSAD30SAAFGIRCE_001'}
# {'GFSAD30SEACE_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFSAD30SEACE_001'}
# {'GFCC30FCC_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFCC30FCC_001'}
# {'GFCC30SR_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFCC30SR_001'}
# {'GFCC30TC_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFCC30TC_003'}
# {'GFCC30WC_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GFCC30WC_001'}
# {'GHISACASIA_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GHISACASIA_001'}
# {'GHISACONUS_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GHISACONUS_001'}
# {'GLanCE30_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GLanCE30_001'}
# {'HLSL30_2.0': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30_2.0'}
# {'HLSL30_VI_2.0': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30_VI_2.0'}
# {'HLSS30_2.0': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSS30_2.0'}
# {'HLSS30_VI_2.0': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSS30_VI_2.0'}
# {'LGRIP30_L1_IRRI_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/LGRIP30_L1_IRRI_002'}
# {'LGRIP30_L2_IRRI_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/LGRIP30_L2_IRRI_002'}
# {'LGRIP30_L3_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/LGRIP30_L3_002'}
# {'LGRIP30_L1_RAIN_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/LGRIP30_L1_RAIN_002'}
# {'LGRIP30_L2_RAIN_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/LGRIP30_L2_RAIN_002'}
# {'LEOLSTCMG30_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/LEOLSTCMG30_001'}
# {'LPJ_EOSIM_L2_DCH4E_LL_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/LPJ_EOSIM_L2_DCH4E_LL_001'}
# {'LPJ_EOSIM_L2_DCH4E_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/LPJ_EOSIM_L2_DCH4E_001'}
# {'LPJ_EOSIM_L2_MCH4E_LL_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/LPJ_EOSIM_L2_MCH4E_LL_001'}
# {'LPJ_EOSIM_L2_MCH4E_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/LPJ_EOSIM_L2_MCH4E_001'}
# {'VCF5KYR_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VCF5KYR_001'}
# {'MYD17A2H_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD17A2H_061'}
# {'MYD17A2HGF_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD17A2HGF_061'}
# {'MYD21_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD21_061'}
# {'MYD21C2_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD21C2_061'}
# {'MYD21A2_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD21A2_061'}
# {'MYD21C1_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD21C1_061'}
# {'MYD21A1D_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD21A1D_061'}
# {'MYD21A1N_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD21A1N_061'}
# {'MYD21C3_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD21C3_061'}
# {'MYD11_L2_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD11_L2_061'}
# {'MYD11C2_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD11C2_061'}
# {'MYD11A2_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD11A2_061'}
# {'MYD11B2_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD11B2_061'}
# {'MYD11C1_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD11C1_061'}
# {'MYD11A1_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD11A1_061'}
# {'MYD11B1_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD11B1_061'}
# {'MYD11C3_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD11C3_061'}
# {'MYD11B3_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD11B3_061'}
# {'MYD15A2H_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD15A2H_061'}
# {'MYD16A2_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD16A2_061'}
# {'MYD16A2GF_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD16A2GF_061'}
# {'MYD16A3GF_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD16A3GF_061'}
# {'MYD17A3HGF_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD17A3HGF_061'}
# {'MYD09Q1_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD09Q1_061'}
# {'MYD09A1_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD09A1_061'}
# {'MYD09GA_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD09GA_061'}
# {'MYD09GQ_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD09GQ_061'}
# {'MYD09CMG_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD09CMG_061'}
# {'MYD14_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD14_061'}
# {'MYD14A2_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD14A2_061'}
# {'MYD14A1_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD14A1_061'}
# {'MYD13C1_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD13C1_061'}
# {'MYD13A2_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD13A2_061'}
# {'MYD13Q1_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD13Q1_061'}
# {'MYD13A1_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD13A1_061'}
# {'MYD13C2_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD13C2_061'}
# {'MYD13A3_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD13A3_061'}
# {'MYD28C2_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD28C2_061'}
# {'MYD28C3_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MYD28C3_061'}
# {'MOD17A2H_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD17A2H_061'}
# {'MOD17A2HGF_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD17A2HGF_061'}
# {'MOD21_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD21_061'}
# {'MOD21C2_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD21C2_061'}
# {'MOD21A2_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD21A2_061'}
# {'MOD21C1_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD21C1_061'}
# {'MOD21A1D_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD21A1D_061'}
# {'MOD21A1N_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD21A1N_061'}
# {'MOD21C3_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD21C3_061'}
# {'MOD11_L2_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD11_L2_061'}
# {'MOD11C2_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD11C2_061'}
# {'MOD11A2_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD11A2_061'}
# {'MOD11B2_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD11B2_061'}
# {'MOD11C1_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD11C1_061'}
# {'MOD11A1_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD11A1_061'}
# {'MOD11B1_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD11B1_061'}
# {'MOD11C3_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD11C3_061'}
# {'MOD11B3_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD11B3_061'}
# {'MOD44W_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD44W_061'}
# {'MOD15A2H_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD15A2H_061'}
# {'MOD16A2_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD16A2_061'}
# {'MOD16A2GF_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD16A2GF_061'}
# {'MOD16A3GF_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD16A3GF_061'}
# {'MOD17A3HGF_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD17A3HGF_061'}
# {'MOD09Q1_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD09Q1_061'}
# {'MOD09A1_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD09A1_061'}
# {'MOD09GA_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD09GA_061'}
# {'MOD09GQ_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD09GQ_061'}
# {'MOD09CMG_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD09CMG_061'}
# {'MOD14_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD14_061'}
# {'MOD14A2_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD14A2_061'}
# {'MOD14A1_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD14A1_061'}
# {'MOD44B_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD44B_061'}
# {'MOD13C1_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD13C1_061'}
# {'MOD13A2_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD13A2_061'}
# {'MOD13Q1_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD13Q1_061'}
# {'MOD13A1_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD13A1_061'}
# {'MOD13C2_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD13C2_061'}
# {'MOD13A3_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD13A3_061'}
# {'MOD28C2_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD28C2_061'}
# {'MOD28C3_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MOD28C3_061'}
# {'MCD19A2CMG_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD19A2CMG_061'}
# {'MCD19A3D_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD19A3D_061'}
# {'MCD43A3_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43A3_061'}
# {'MCD43C3_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43C3_061'}
# {'MCD43D42_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D42_061'}
# {'MCD43D43_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D43_061'}
# {'MCD43D44_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D44_061'}
# {'MCD43D45_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D45_061'}
# {'MCD43D46_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D46_061'}
# {'MCD43D47_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D47_061'}
# {'MCD43D48_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D48_061'}
# {'MCD43D50_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D50_061'}
# {'MCD43D51_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D51_061'}
# {'MCD43D49_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D49_061'}
# {'MCD43GF_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43GF_061'}
# {'MCD43A1_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43A1_061'}
# {'MCD43C1_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43C1_061'}
# {'MCD43D62_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D62_061'}
# {'MCD43D63_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D63_061'}
# {'MCD43D64_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D64_061'}
# {'MCD43D65_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D65_061'}
# {'MCD43D66_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D66_061'}
# {'MCD43D67_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D67_061'}
# {'MCD43D68_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D68_061'}
# {'MCD43A4_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43A4_061'}
# {'MCD43C4_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43C4_061'}
# {'MCD43D01_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D01_061'}
# {'MCD43D04_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D04_061'}
# {'MCD43D02_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D02_061'}
# {'MCD43D05_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D05_061'}
# {'MCD43D03_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D03_061'}
# {'MCD43D06_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D06_061'}
# {'MCD43D07_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D07_061'}
# {'MCD43D10_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D10_061'}
# {'MCD43D13_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D13_061'}
# {'MCD43D16_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D16_061'}
# {'MCD43D19_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D19_061'}
# {'MCD43D25_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D25_061'}
# {'MCD43D28_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D28_061'}
# {'MCD43D22_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D22_061'}
# {'MCD43D08_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D08_061'}
# {'MCD43D11_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D11_061'}
# {'MCD43D14_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D14_061'}
# {'MCD43D17_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D17_061'}
# {'MCD43D20_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D20_061'}
# {'MCD43D26_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D26_061'}
# {'MCD43D29_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D29_061'}
# {'MCD43D23_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D23_061'}
# {'MCD43D09_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D09_061'}
# {'MCD43D12_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D12_061'}
# {'MCD43D15_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D15_061'}
# {'MCD43D18_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D18_061'}
# {'MCD43D21_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D21_061'}
# {'MCD43D27_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D27_061'}
# {'MCD43D30_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D30_061'}
# {'MCD43D24_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D24_061'}
# {'MCD43D31_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D31_061'}
# {'MCD43D32_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D32_061'}
# {'MCD43D40_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D40_061'}
# {'MCD43D41_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D41_061'}
# {'MCD43D33_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D33_061'}
# {'MCD43D34_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D34_061'}
# {'MCD43D35_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D35_061'}
# {'MCD43D36_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D36_061'}
# {'MCD43D37_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D37_061'}
# {'MCD43D38_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D38_061'}
# {'MCD43D39_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D39_061'}
# {'MCD43A2_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43A2_061'}
# {'MCD43C2_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43C2_061'}
# {'MCD43D52_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D52_061'}
# {'MCD43D53_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D53_061'}
# {'MCD43D54_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D54_061'}
# {'MCD43D55_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D55_061'}
# {'MCD43D56_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D56_061'}
# {'MCD43D57_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D57_061'}
# {'MCD43D58_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D58_061'}
# {'MCD43D60_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D60_061'}
# {'MCD43D61_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D61_061'}
# {'MCD43D59_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD43D59_061'}
# {'MCD64A1_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD64A1_061'}
# {'MCD18C1_062': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD18C1_062'}
# {'MCD19A2_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD19A2_061'}
# {'MCD19A2_006': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD19A2_006'}
# {'MCD12Q2_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD12Q2_061'}
# {'MCD12C1_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD12C1_061'}
# {'MCD12Q1_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD12Q1_061'}
# {'MCD19A1_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD19A1_061'}
# {'MCD15A3H_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD15A3H_061'}
# {'MCD15A2H_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD15A2H_061'}
# {'MCD18C2_062': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD18C2_062'}
# {'MCD18A2_062': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD18A2_062'}
# {'MCD18A1_062': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD18A1_062'}
# {'MCD19A1CMGL_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD19A1CMGL_061'}
# {'MCD19A1CMGO_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD19A1CMGO_061'}
# {'MCD19A3CMG_061': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/MCD19A3CMG_061'}
# {'WaterBalance_Monthly_Historical_GRIDMET_1.5': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/WaterBalance_Monthly_Historical_GRIDMET_1.5'}
# {'GWELDYR_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GWELDYR_003'}
# {'GWELDYR_031': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GWELDYR_031'}
# {'GWELDYR_032': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GWELDYR_032'}
# {'GWELDMO_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GWELDMO_003'}
# {'GWELDMO_031': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GWELDMO_031'}
# {'GWELDMO_032': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/GWELDMO_032'}
# {'SRTMIMGM_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/SRTMIMGM_003'}
# {'SRTMGL1N_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/SRTMGL1N_003'}
# {'SRTMGL1_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/SRTMGL1_003'}
# {'SRTMGL3_NC_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/SRTMGL3_NC_003'}
# {'SRTMGL3_NUMNC_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/SRTMGL3_NUMNC_003'}
# {'SRTMGL3N_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/SRTMGL3N_003'}
# {'SRTMGL3S_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/SRTMGL3S_003'}
# {'SRTMGL3_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/SRTMGL3_003'}
# {'SRTMGL30_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/SRTMGL30_002'}
# {'SRTMIMGR_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/SRTMIMGR_003'}
# {'SRTMSWBD_003': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/SRTMSWBD_003'}
# {'NASADEM_NC_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/NASADEM_NC_001'}
# {'NASADEM_HGT_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/NASADEM_HGT_001'}
# {'NASADEM_NUMNC_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/NASADEM_NUMNC_001'}
# {'NASADEM_SC_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/NASADEM_SC_001'}
# {'NASADEM_SIM_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/NASADEM_SIM_001'}
# {'NASADEM_SSP_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/NASADEM_SSP_001'}
# {'NASADEM_SHHP_001': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/NASADEM_SHHP_001'}
# {'OPERA_L3_DIST-ALERT-HLS_V1_1': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/OPERA_L3_DIST-ALERT-HLS_V1_1'}
# {'OPERA_L3_DIST-ANN-HLS_V1_1': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/OPERA_L3_DIST-ANN-HLS_V1_1'}
# {'VIPPHEN_EVI2_004': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VIPPHEN_EVI2_004'}
# {'VIPPHEN_NDVI_004': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VIPPHEN_NDVI_004'}
# {'VIP15_004': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VIP15_004'}
# {'VIP07_004': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VIP07_004'}
# {'VIP01_004': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VIP01_004'}
# {'VIP30_004': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VIP30_004'}
# {'VJ114IMG_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ114IMG_002'}
# {'VJ143C3_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ143C3_002'}
# {'VJ143MA3_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ143MA3_002'}
# {'VJ143IA3_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ143IA3_002'}
# {'VJ143C1_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ143C1_002'}
# {'VJ143MA1_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ143MA1_002'}
# {'VJ143IA1_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ143IA1_002'}
# {'VJ143MA4_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ143MA4_002'}
# {'VJ143IA4_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ143IA4_002'}
# {'VJ143C4_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ143C4_002'}
# {'VJ143MA2_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ143MA2_002'}
# {'VJ143IA2_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ143IA2_002'}
# {'VJ143C2_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ143C2_002'}
# {'VJ143DNBA3_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ143DNBA3_002'}
# {'VJ143DNBA1_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ143DNBA1_002'}
# {'VJ143DNBA4_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ143DNBA4_002'}
# {'VJ143DNBA2_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ143DNBA2_002'}
# {'VJ147IMG_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ147IMG_002'}
# {'VJ121_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ121_002'}
# {'VJ121C2_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ121C2_002'}
# {'VJ121A2_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ121A2_002'}
# {'VJ121C1_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ121C1_002'}
# {'VJ121A1D_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ121A1D_002'}
# {'VJ121A1N_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ121A1N_002'}
# {'VJ121C3_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ121C3_002'}
# {'VJ115A2H_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ115A2H_002'}
# {'VJ103MODLL_021': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ103MODLL_021'}
# {'VJ109A1_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ109A1_002'}
# {'VJ109H1_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ109H1_002'}
# {'VJ109GA_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ109GA_002'}
# {'VJ109CMG_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ109CMG_002'}
# {'VJ114A1_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ114A1_002'}
# {'VJ114_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ114_002'}
# {'VJ113C1_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ113C1_002'}
# {'VJ113A2_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ113A2_002'}
# {'VJ113A1_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ113A1_002'}
# {'VJ113C2_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ113C2_002'}
# {'VJ113A3_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ113A3_002'}
# {'VJ128C2_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ128C2_002'}
# {'VJ128C3_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ128C3_002'}
# {'VJ147MOD_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VJ147MOD_002'}
# {'VNP14IMG_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP14IMG_002'}
# {'VNP43C3_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43C3_002'}
# {'VNP43MA3_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43MA3_002'}
# {'VNP43IA3_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43IA3_002'}
# {'VNP43C1_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43C1_002'}
# {'VNP43MA1_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43MA1_002'}
# {'VNP43IA1_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43IA1_002'}
# {'VNP43MA4_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43MA4_002'}
# {'VNP43IA4_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43IA4_002'}
# {'VNP43C4_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43C4_002'}
# {'VNP43D01_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43D01_002'}
# {'VNP43D04_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43D04_002'}
# {'VNP43D07_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43D07_002'}
# {'VNP43D10_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43D10_002'}
# {'VNP43D13_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43D13_002'}
# {'VNP43D16_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43D16_002'}
# {'VNP43D19_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43D19_002'}
# {'VNP43D02_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43D02_002'}
# {'VNP43D05_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43D05_002'}
# {'VNP43D08_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43D08_002'}
# {'VNP43D11_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43D11_002'}
# {'VNP43D14_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43D14_002'}
# {'VNP43D17_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43D17_002'}
# {'VNP43D20_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43D20_002'}
# {'VNP43D03_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43D03_002'}
# {'VNP43D06_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43D06_002'}
# {'VNP43D09_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43D09_002'}
# {'VNP43D12_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43D12_002'}
# {'VNP43D15_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43D15_002'}
# {'VNP43D18_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43D18_002'}
# {'VNP43MA2_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43MA2_002'}
# {'VNP43D40_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43D40_002'}
# {'VNP43IA2_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43IA2_002'}
# {'VNP43C2_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43C2_002'}
# {'VNP43D53_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43D53_002'}
# {'VNP64A1_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP64A1_002'}
# {'VNP43DNBA3_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43DNBA3_002'}
# {'VNP43DNBA1_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43DNBA1_002'}
# {'VNP43DNBA4_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43DNBA4_002'}
# {'VNP43DNBA2_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP43DNBA2_002'}
# {'VNP47IMG_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP47IMG_002'}
# {'VNP47MOD_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP47MOD_002'}
# {'VNP22C2_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP22C2_002'}
# {'VNP22Q2_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP22Q2_002'}
# {'VNP21_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP21_002'}
# {'VNP21C2_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP21C2_002'}
# {'VNP21A2_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP21A2_002'}
# {'VNP21C1_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP21C1_002'}
# {'VNP21A1D_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP21A1D_002'}
# {'VNP21A1N_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP21A1N_002'}
# {'VNP21C3_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP21C3_002'}
# {'VNP15A2H_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP15A2H_002'}
# {'VNP03MODLL_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP03MODLL_002'}
# {'VNP09A1_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP09A1_002'}
# {'VNP09H1_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP09H1_002'}
# {'VNP09GA_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP09GA_002'}
# {'VNP09CMG_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP09CMG_002'}
# {'VNP14A1_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP14A1_002'}
# {'VNP14_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP14_002'}
# {'VNP13C1_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP13C1_002'}
# {'VNP13A2_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP13A2_002'}
# {'VNP13A1_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP13A1_002'}
# {'VNP13C2_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP13C2_002'}
# {'VNP13A3_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP13A3_002'}
# {'VNP28C2_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP28C2_002'}
# {'VNP28C3_002': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/VNP28C3_002'}

# %% [markdown]
# ### Get information about an individual Collection
#
# Below we'll specify a STAC Collection, `HLSL30_2.0`, and request the STAC metadata.

# %%
# Define desired collection
collection = 'HLSL30_2.0'

# %%
# Filter list of collections
collection_link = list(filter(lambda c: collection == list(c.keys())[0], cols))[0]
collection_link
# Out:
# {'HLSL30_2.0': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30_2.0'}

# %%
# Request STAC collection metadata
requests.get(collection_link[collection]).json()
# Out:
# {'type': 'Collection',
#  'id': 'HLSL30_2.0',
#  'title': 'HLS Landsat Operational Land Imager Surface Reflectance and TOA Brightness Daily Global 30m v2.0',
#  'description': 'The Harmonized Landsat Sentinel-2 (HLS) project provides consistent surface reflectance (SR) and top of atmosphere (TOA) brightness data from a virtual constellation of satellite sensors. The Operational Land Imager (OLI) is housed aboard the joint NASA/USGS Landsat 8 and Landsat 9 satellites, while the Multi-Spectral Instrument (MSI) is mounted aboard Europe’s Copernicus Sentinel-2A, Sentinel-2B, and Sentinel-2C satellites. The combined measurement enables global observations of the land every 2–3 days at 30-meter (m) spatial resolution. The HLS project uses a set of algorithms to obtain seamless products from OLI and MSI that include atmospheric correction, cloud and cloud-shadow masking, spatial co-registration and common gridding, illumination and view angle normalization, and spectral bandpass adjustment.\n\nThe HLSL30 product provides 30-m Nadir Bidirectional Reflectance Distribution Function (BRDF)-Adjusted Reflectance (NBAR) and is derived from Landsat 8/9 OLI data products. The HLSS30 and HLSL30 products are gridded to the same resolution and Military Grid Reference System (MGRS)(https://hls.gsfc.nasa.gov/products-description/tiling-system/) tiling system, and thus are “stackable” for time series analysis.\n\nThe HLSL30 product is provided in Cloud Optimized GeoTIFF (COG) format, and each band is distributed as a separate file. There are 11 bands included in the HLSL30 product along with one quality assessment (QA) band and four angle bands. See the User Guide for a more detailed description of the individual bands provided in the HLSL30 product.',
#  'stac_version': '1.0.0',
#  'extent': {'spatial': {'bbox': [[-180, -90, 180, 90]]},
#   'temporal': {'interval': [['2013-04-11T00:00:00.000Z', None]]}},
#  'assets': {'browse': {'href': 'https://worldview.earthdata.nasa.gov/images/layers/previews/geographic/HLS_L30_Nadir_BRDF_Adjusted_Reflectance.jpg',
#    'title': 'Download HLS_L30_Nadir_BRDF_Adjusted_Reflectance.jpg',
#    'type': 'image/jpeg',
#    'roles': ['browse']},
#   'thumbnail_0': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSL30.020/HLS.L30.T03WXN.2024206T221402.v2.0/HLS.L30.T03WXN.2024206T221402.v2.0.jpg',
#    'title': 'Thumbnail [0]',
#    'description': 'Browse image for Earthdata Search',
#    'roles': ['thumbnail']},
#   'thumbnail_1': {'href': 'https://worldview.earthdata.nasa.gov/images/layers/previews/geographic/HLS_L30_Nadir_BRDF_Adjusted_Reflectance.jpg',
#    'title': 'Thumbnail [1]',
#    'description': "The URL for viewing a Worldview visualization. The Worldview tool from NASA's Earth Observing System Data and Information System (EOSDIS) provides the capability to interactively browse over 600 global, full-resolution satellite imagery layers and then download the underlying data.",
#    'roles': ['thumbnail']},
#   'nasa': {'href': 'https://appeears.earthdatacloud.nasa.gov/',
#    'title': 'Direct Download [1]',
#    'description': 'The Application for Extracting and Exploring Analysis Ready Samples (AppEEARS) offers a simple and efficient way to perform data access and transformation processes.',
#    'roles': ['data']},
#   'provider_metadata': {'href': 'https://doi.org/10.5067/HLS/HLSL30.002',
#    'title': 'Provider Metadata',
#    'description': 'The LP DAAC product page provides information on Science Data Set layers and links for user guides, ATBDs, data access, tools, customer support, etc.',
#    'roles': ['metadata']},
#   's3_lp_prod_protected_HLSL30_020': {'href': 's3://lp-prod-protected/HLSL30.020',
#    'roles': ['data'],
#    'title': 'lp_prod_protected_HLSL30_020'},
#   's3_lp_prod_public_HLSL30_020': {'href': 's3://lp-prod-public/HLSL30.020',
#    'roles': ['data'],
#    'title': 'lp_prod_public_HLSL30_020'},
#   's3_credentials': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/s3credentials',
#    'title': 'S3 credentials API endpoint',
#    'roles': ['metadata']},
#   's3_credentials_documentation': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/s3credentialsREADME',
#    'title': 'S3 credentials API endpoint documentation',
#    'roles': ['metadata']},
#   'metadata': {'href': 'https://cmr.earthdata.nasa.gov/search/concepts/C2021957657-LPCLOUD.xml',
#    'title': 'CMR XML metadata for C2021957657-LPCLOUD',
#    'type': 'application/xml',
#    'roles': ['metadata']}},
#  'providers': [{'name': 'LPCLOUD', 'roles': ['producer']},
#   {'name': 'NASA EOSDIS', 'roles': ['host']}],
#  'links': [{'rel': 'self',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30_2.0',
#    'type': 'application/json'},
#   {'rel': 'root',
#    'href': 'https://cmr.earthdata.nasa.gov/stac',
#    'type': 'application/json',
#    'title': 'Root Catalog'},
#   {'rel': 'parent',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections',
#    'type': 'application/json',
#    'title': 'Provider Collections'},
#   {'rel': 'license',
#    'href': 'https://science.nasa.gov/earth-science/earth-science-data/data-information-policy',
#    'title': 'EOSDIS Data Use Policy',
#    'type': 'text/html'},
#   {'rel': 'about',
#    'href': 'https://cmr.earthdata.nasa.gov/search/concepts/C2021957657-LPCLOUD.html',
#    'title': 'HTML metadata for collection',
#    'type': 'text/html'},
#   {'rel': 'via',
#    'href': 'https://cmr.earthdata.nasa.gov/search/concepts/C2021957657-LPCLOUD.native',
#    'title': 'Native metadata for collection',
#    'type': 'application/xml'},
#   {'rel': 'via',
#    'href': 'https://cmr.earthdata.nasa.gov/search/concepts/C2021957657-LPCLOUD.echo10',
#    'title': 'ECHO10 metadata for collection',
#    'type': 'application/echo10+xml'},
#   {'rel': 'via',
#    'href': 'https://cmr.earthdata.nasa.gov/search/concepts/C2021957657-LPCLOUD.json',
#    'title': 'CMR JSON metadata for collection',
#    'type': 'application/json'},
#   {'rel': 'via',
#    'href': 'https://cmr.earthdata.nasa.gov/search/concepts/C2021957657-LPCLOUD.umm_json',
#    'title': 'CMR UMM_JSON metadata for collection',
#    'type': 'application/vnd.nasa.cmr.umm+json'},
#   {'rel': 'items',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30_2.0/items',
#    'type': 'application/geo+json',
#    'title': 'Collection Items'}],
#  'license': 'proprietary',
#  'keywords': ['EARTH SCIENCE',
#   'LAND SURFACE',
#   'SURFACE RADIATIVE PROPERTIES',
#   'REFLECTANCE'],
#  'summaries': {'platform': ['LANDSAT-8', 'LANDSAT-9'],
#   'instruments': ['OLI', 'OLI']}}

# %% [markdown]
# For this next section, use `pystac_client` to submit a spatiotemporal query for data assets across multiple collections. We will define our area of interest using a geojson file, while also specifying the data collections and time range of needed for our example.

# %%
# Open geojson file
field = gpd.read_file('../../data/ne_w_agfields.geojson')
field
# Out:
#                                             geometry
# 0  POLYGON ((-101.67272 41.04754, -101.65345 41.0...

# %%
# Visualize area of interest using hvplot
field.hvplot(tiles='ESRI', crs='EPSG:4326', line_color='yellow', line_width=2, fill_color=None)
# Out:
# :Overlay
#    .WMTS.I     :WMTS   [Longitude,Latitude]
#    .Polygons.I :Polygons   [Longitude,Latitude]

# %% [markdown]
# We will now start to specify the search criteria we are interested in, i.e, the **date range**, the **region of interest** (roi), and the **data collections**, to pass to the STAC API

# %%
# Specify area of interest
roi = field['geometry'][0].__geo_interface__
roi
# Out:
# {'type': 'Polygon',
#  'coordinates': (((-101.67271614074707, 41.04754380304359),
#    (-101.65344715118408, 41.04754380304359),
#    (-101.65344715118408, 41.06213891056728),
#    (-101.67271614074707, 41.06213891056728),
#    (-101.67271614074707, 41.04754380304359)),)}

# %% [markdown]
# Date ranges can be submitted as a start and end date with a "/". For our search we will only use year and month to define our range, but an example is included below using a full `%Y-%m-%dT%H:%M:%SZ` format.

# %%
# Specify data range
date_range = "2021-05/2021-08"
# date_range = "2021-05-01T00:00:00Z/2021-08-30T23:59:59Z"

# %% [markdown]
# A STAC Collection is synonymous with what is referred by LP DAAC as a Data Product, though within STAC, the collection name may not match exactly with the product shortname.

# %%
# Define Collections
collections = ['HLSL30_2.0', 'HLSS30_2.0']
collections
# Out:
# ['HLSL30_2.0', 'HLSS30_2.0']

# %%
# Define Search Parameters
search_params = {
    "collections": collections,
    "intersects": roi,
    "datetime": date_range,
}

# %% [markdown]
# Now that we have our search parameters we will place them into a dictionary, then use `pystac_client` to submit the request to search the catalog.

# %%
# Define Catalog to Search
catalog = Client.open(provider_url)

# %%
# Perform the search
query = catalog.search(**search_params)

# %% [markdown]
# Print the number of STAC Items returned from our search.

# %%
# Count result quantity
query.matched()
# Out:
# 113

# %% [markdown]
# We now have a search object containing the STAC records that matched our query. Let's pull out all of the STAC Items (as a PySTAC ItemCollection object) and explore the contents (i.e., the STAC Items).

# %%
# Return Resulting Items
items = list(query.items())

# %% [markdown]
# We can view the individual STAC Items and their metadata using their index.

# %%
items[0]
# Out:
# <Item id=HLS.L30.T13TGF.2021124T173013.v2.0>

# %% [markdown]
# We can use the nice representation provided by `pystac_client` to view the metadata for each STAC Item, or we can convert it to a dictionary.

# %%
# Convert to dictionary
items[0].to_dict()
# Out:
# {'type': 'Feature',
#  'stac_version': '1.1.0',
#  'stac_extensions': ['https://stac-extensions.github.io/eo/v1.1.0/schema.json'],
#  'id': 'HLS.L30.T13TGF.2021124T173013.v2.0',
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[-101.5423534, 40.5109845],
#     [-101.3056118, 41.2066375],
#     [-101.2894253, 41.4919436],
#     [-102.6032964, 41.5268623],
#     [-102.638891, 40.5386175],
#     [-101.5423534, 40.5109845]]]},
#  'bbox': [-102.638891, 40.5109845, -101.2894253, 41.5268623],
#  'properties': {'datetime': '2021-05-04T17:30:13.428000Z',
#   'eo:cloud_cover': 36,
#   'start_datetime': '2021-05-04T17:30:13.428Z',
#   'end_datetime': '2021-05-04T17:30:37.319Z'},
#  'links': [{'rel': 'self',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30_2.0/items/HLS.L30.T13TGF.2021124T173013.v2.0',
#    'type': 'application/geo+json'},
#   {'rel': 'parent',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30_2.0/',
#    'type': 'application/geo+json'},
#   {'rel': 'collection',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30_2.0/',
#    'type': 'application/geo+json'},
#   {'rel': 'root',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD',
#    'type': 'application/json',
#    'title': 'LPCLOUD STAC Catalog'},
#   {'rel': 'provider',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD',
#    'type': 'application/json'},
#   {'rel': 'via',
#    'href': 'https://cmr.earthdata.nasa.gov/search/concepts/G2144020713-LPCLOUD.json',
#    'type': 'application/json',
#    'title': 'CMR JSON metadata for item'},
#   {'rel': 'via',
#    'href': 'https://cmr.earthdata.nasa.gov/search/concepts/G2144020713-LPCLOUD.umm_json',
#    'type': 'application/vnd.nasa.cmr.umm+json',
#    'title': 'CMR UMM_JSON metadata for item'}],
#  'assets': {'browse': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSL30.020/HLS.L30.T13TGF.2021124T173013.v2.0/HLS.L30.T13TGF.2021124T173013.v2.0.jpg',
#    'type': 'image/jpeg',
#    'title': 'Download HLS.L30.T13TGF.2021124T173013.v2.0.jpg',
#    'roles': ['browse']},
#   'thumbnail_0': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSL30.020/HLS.L30.T13TGF.2021124T173013.v2.0/HLS.L30.T13TGF.2021124T173013.v2.0.jpg',
#    'title': 'Thumbnail [0]',
#    'description': 'Download HLS.L30.T13TGF.2021124T173013.v2.0.jpg',
#    'roles': ['thumbnail']},
#   'thumbnail_1': {'href': 's3://lp-prod-public/HLSL30.020/HLS.L30.T13TGF.2021124T173013.v2.0/HLS.L30.T13TGF.2021124T173013.v2.0.jpg',
#    'title': 'Thumbnail [1]',
#    'description': 'This link provides direct download access via S3 to the granule',
#    'roles': ['thumbnail']},
#   'B11': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021124T173013.v2.0/HLS.L30.T13TGF.2021124T173013.v2.0.B11.tif',
#    'title': 'Direct Download [0]',
#    'description': 'Download HLS.L30.T13TGF.2021124T173013.v2.0.B11.tif',
#    'roles': ['data']},
#   'B07': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021124T173013.v2.0/HLS.L30.T13TGF.2021124T173013.v2.0.B07.tif',
#    'title': 'Direct Download [1]',
#    'description': 'Download HLS.L30.T13TGF.2021124T173013.v2.0.B07.tif',
#    'roles': ['data']},
#   'SAA': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021124T173013.v2.0/HLS.L30.T13TGF.2021124T173013.v2.0.SAA.tif',
#    'title': 'Direct Download [2]',
#    'description': 'Download HLS.L30.T13TGF.2021124T173013.v2.0.SAA.tif',
#    'roles': ['data']},
#   'B06': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021124T173013.v2.0/HLS.L30.T13TGF.2021124T173013.v2.0.B06.tif',
#    'title': 'Direct Download [3]',
#    'description': 'Download HLS.L30.T13TGF.2021124T173013.v2.0.B06.tif',
#    'roles': ['data']},
#   'B09': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021124T173013.v2.0/HLS.L30.T13TGF.2021124T173013.v2.0.B09.tif',
#    'title': 'Direct Download [4]',
#    'description': 'Download HLS.L30.T13TGF.2021124T173013.v2.0.B09.tif',
#    'roles': ['data']},
#   'B10': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021124T173013.v2.0/HLS.L30.T13TGF.2021124T173013.v2.0.B10.tif',
#    'title': 'Direct Download [5]',
#    'description': 'Download HLS.L30.T13TGF.2021124T173013.v2.0.B10.tif',
#    'roles': ['data']},
#   'VZA': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021124T173013.v2.0/HLS.L30.T13TGF.2021124T173013.v2.0.VZA.tif',
#    'title': 'Direct Download [6]',
#    'description': 'Download HLS.L30.T13TGF.2021124T173013.v2.0.VZA.tif',
#    'roles': ['data']},
#   'SZA': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021124T173013.v2.0/HLS.L30.T13TGF.2021124T173013.v2.0.SZA.tif',
#    'title': 'Direct Download [7]',
#    'description': 'Download HLS.L30.T13TGF.2021124T173013.v2.0.SZA.tif',
#    'roles': ['data']},
#   'B01': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021124T173013.v2.0/HLS.L30.T13TGF.2021124T173013.v2.0.B01.tif',
#    'title': 'Direct Download [8]',
#    'description': 'Download HLS.L30.T13TGF.2021124T173013.v2.0.B01.tif',
#    'roles': ['data']},
#   'VAA': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021124T173013.v2.0/HLS.L30.T13TGF.2021124T173013.v2.0.VAA.tif',
#    'title': 'Direct Download [9]',
#    'description': 'Download HLS.L30.T13TGF.2021124T173013.v2.0.VAA.tif',
#    'roles': ['data']},
#   'B05': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021124T173013.v2.0/HLS.L30.T13TGF.2021124T173013.v2.0.B05.tif',
#    'title': 'Direct Download [10]',
#    'description': 'Download HLS.L30.T13TGF.2021124T173013.v2.0.B05.tif',
#    'roles': ['data']},
#   'B02': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021124T173013.v2.0/HLS.L30.T13TGF.2021124T173013.v2.0.B02.tif',
#    'title': 'Direct Download [11]',
#    'description': 'Download HLS.L30.T13TGF.2021124T173013.v2.0.B02.tif',
#    'roles': ['data']},
#   'Fmask': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021124T173013.v2.0/HLS.L30.T13TGF.2021124T173013.v2.0.Fmask.tif',
#    'title': 'Direct Download [12]',
#    'description': 'Download HLS.L30.T13TGF.2021124T173013.v2.0.Fmask.tif',
#    'roles': ['data']},
#   'B03': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021124T173013.v2.0/HLS.L30.T13TGF.2021124T173013.v2.0.B03.tif',
#    'title': 'Direct Download [13]',
#    'description': 'Download HLS.L30.T13TGF.2021124T173013.v2.0.B03.tif',
#    'roles': ['data']},
#   'B04': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021124T173013.v2.0/HLS.L30.T13TGF.2021124T173013.v2.0.B04.tif',
#    'title': 'Direct Download [14]',
#    'description': 'Download HLS.L30.T13TGF.2021124T173013.v2.0.B04.tif',
#    'roles': ['data']},
#   'metadata': {'href': 'https://cmr.earthdata.nasa.gov/search/concepts/G2144020713-LPCLOUD.xml',
#    'type': 'application/xml',
#    'title': 'CMR XML metadata for G2144020713-LPCLOUD',
#    'roles': ['metadata']}},
#  'collection': 'HLSL30_2.0'}

# %% [markdown]
# While the CMR-STAC API is a powerful search and discovery utility, it is still maturing and currently does not have the full gamut of filtering capabilities that the STAC API specification allows for. Hence, additional filtering is required if we want to filter by a property like cloud cover. Below we will loop through and filter the STAC items by a specified cloud cover as well as extract the bands we want.

# %% [markdown]
# Set the max cloud cover threshold to 25%.

# %%
cloudcover = 25

# %% [markdown]
# We will also specify the STAC Assets (i.e., bands/layers) of interest for both the S30 and L30 collections. These differ because B8A is the NIR band for the S30 collection, while B5 is the NIR band for the L30 collection.

# %%
s30_bands = ['B8A', 'B04', 'B02', 'Fmask']
l30_bands = ['B05', 'B04', 'B02', 'Fmask']

# %% [markdown]
# Retrieve the asset links for each band from the STAC Items that match our cloud cover threshold and store them in a list.

# %%
evi_band_links = []

for i in items:
    if i.properties['eo:cloud_cover'] <= cloudcover:
        if i.collection_id == 'HLSS30_2.0':
            #print(i.properties['eo:cloud_cover'])
            evi_bands = s30_bands
        elif i.collection_id == 'HLSL30_2.0':
            #print(i.properties['eo:cloud_cover'])
            evi_bands = l30_bands

        for a in i.assets:
            if any(b==a for b in evi_bands):
                evi_band_links.append(i.assets[a].href)

# %% [markdown]
# The filtering done in the previous steps produces a list of links to STAC Assets. Let's print out the first ten links.

# %%
evi_band_links[:10]
# Out:
# ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.B05.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.Fmask.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.B02.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T14TKL.2021133T172406.v2.0/HLS.L30.T14TKL.2021133T172406.v2.0.B02.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T14TKL.2021133T172406.v2.0/HLS.L30.T14TKL.2021133T172406.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T14TKL.2021133T172406.v2.0/HLS.L30.T14TKL.2021133T172406.v2.0.B05.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T14TKL.2021133T172406.v2.0/HLS.L30.T14TKL.2021133T172406.v2.0.Fmask.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14TKL.2021133T173859.v2.0/HLS.S30.T14TKL.2021133T173859.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14TKL.2021133T173859.v2.0/HLS.S30.T14TKL.2021133T173859.v2.0.B8A.tif']

# %% [markdown]
# Notice that in the list of links that we have multiple tiles, i.e. **T14TKL** & **T13TGF** that intersect with our region of interest. These tiles represent neighboring UTM zones. We will split the list of links into separate lists for each tile.

# %% [markdown]
# Split by Universal Transverse Mercator (UTM) tile specified in the file name (e.g., T14TKL & T13TGF)

# %%
tile_dicts = defaultdict(list) 
tile_dicts
# Out:
# defaultdict(list, {})

# %%
for l in evi_band_links:
    tile = l.split('.')[-6]
    tile_dicts[tile].append(l)

# %% [markdown]
# Print dictionary keys and values, i.e. the data links.

# %%
tile_dicts.keys()
# Out:
# dict_keys(['T13TGF', 'T14TKL'])

# %%
tile_dicts['T13TGF'][:5]
# Out:
# ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.B05.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.Fmask.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.B02.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13TGF.2021133T173859.v2.0/HLS.S30.T13TGF.2021133T173859.v2.0.B8A.tif']

# %% [markdown]
# Now we will create a seperate list of data links for each tile

# %%
tile_links_T14TKL = tile_dicts['T14TKL']
tile_links_T13TGF = tile_dicts['T13TGF']

# %% [markdown]
# Print the band/layer links for HLS tile T13TGF.

# %%
tile_links_T13TGF[:10]
# Out:
# ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.B05.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.Fmask.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.B02.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13TGF.2021133T173859.v2.0/HLS.S30.T13TGF.2021133T173859.v2.0.B8A.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13TGF.2021133T173859.v2.0/HLS.S30.T13TGF.2021133T173859.v2.0.Fmask.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13TGF.2021133T173859.v2.0/HLS.S30.T13TGF.2021133T173859.v2.0.B02.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13TGF.2021133T173859.v2.0/HLS.S30.T13TGF.2021133T173859.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021140T173021.v2.0/HLS.L30.T13TGF.2021140T173021.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021140T173021.v2.0/HLS.L30.T13TGF.2021140T173021.v2.0.B05.tif']

# %% [markdown]
# Split the links by band.

# %%
bands_dicts = defaultdict(list)

# %%
for b in tile_links_T13TGF:
    band = b.split('.')[-2]
    bands_dicts[band].append(b)

# %%
bands_dicts.keys()
# Out:
# dict_keys(['B04', 'B05', 'Fmask', 'B02', 'B8A'])

# %%
bands_dicts['B04']
# Out:
# ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13TGF.2021133T173859.v2.0/HLS.S30.T13TGF.2021133T173859.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021140T173021.v2.0/HLS.L30.T13TGF.2021140T173021.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13TGF.2021140T172859.v2.0/HLS.S30.T13TGF.2021140T172859.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13TGF.2021145T172901.v2.0/HLS.S30.T13TGF.2021145T172901.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13TGF.2021155T172901.v2.0/HLS.S30.T13TGF.2021155T172901.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021156T173029.v2.0/HLS.L30.T13TGF.2021156T173029.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13TGF.2021158T173901.v2.0/HLS.S30.T13TGF.2021158T173901.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13TGF.2021163T173909.v2.0/HLS.S30.T13TGF.2021163T173909.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021165T172422.v2.0/HLS.L30.T13TGF.2021165T172422.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13TGF.2021165T172901.v2.0/HLS.S30.T13TGF.2021165T172901.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13TGF.2021173T173909.v2.0/HLS.S30.T13TGF.2021173T173909.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13TGF.2021185T172901.v2.0/HLS.S30.T13TGF.2021185T172901.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021188T173037.v2.0/HLS.L30.T13TGF.2021188T173037.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13TGF.2021190T172859.v2.0/HLS.S30.T13TGF.2021190T172859.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13TGF.2021193T173909.v2.0/HLS.S30.T13TGF.2021193T173909.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13TGF.2021198T173911.v2.0/HLS.S30.T13TGF.2021198T173911.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13TGF.2021200T172859.v2.0/HLS.S30.T13TGF.2021200T172859.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13TGF.2021203T173909.v2.0/HLS.S30.T13TGF.2021203T173909.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021204T173042.v2.0/HLS.L30.T13TGF.2021204T173042.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13TGF.2021208T173911.v2.0/HLS.S30.T13TGF.2021208T173911.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13TGF.2021210T172859.v2.0/HLS.S30.T13TGF.2021210T172859.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13TGF.2021215T172901.v2.0/HLS.S30.T13TGF.2021215T172901.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13TGF.2021218T173911.v2.0/HLS.S30.T13TGF.2021218T173911.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021220T173049.v2.0/HLS.L30.T13TGF.2021220T173049.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13TGF.2021220T172859.v2.0/HLS.S30.T13TGF.2021220T172859.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13TGF.2021223T173909.v2.0/HLS.S30.T13TGF.2021223T173909.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13TGF.2021228T173911.v2.0/HLS.S30.T13TGF.2021228T173911.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021229T172441.v2.0/HLS.L30.T13TGF.2021229T172441.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13TGF.2021230T172859.v2.0/HLS.S30.T13TGF.2021230T172859.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13TGF.2021235T172901.v2.0/HLS.S30.T13TGF.2021235T172901.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13TGF.2021243T173859.v2.0/HLS.S30.T13TGF.2021243T173859.v2.0.B04.tif']

# %% [markdown]
# Save the individual link lists as separate text files with descriptive names.

# %%
for k, v in bands_dicts.items():
    name = (f'HTTPS_T13TGF_{k}_Links.txt')
    with open(f'../../data/{name}', 'w') as f:
        for l in v:
            f.write(f"{l}" + '\n')

# %% [markdown]
# Write links to files for S3 direct access.

# %%
for k, v in bands_dicts.items():
    name = (f'S3_T13TGF_{k}_Links.txt')
    with open(f'../../data/{name}', 'w') as f:
        for l in v:
            s3l = l.replace('https://data.lpdaac.earthdatacloud.nasa.gov/', 's3://')
            f.write(f"{s3l}" + '\n')

# %% [markdown]
# ## Additional Resources
#
# - https://github.com/nasa/cmr-stac
# - https://stacspec.org/
# - https://stackoverflow.com/questions/26367812/appending-to-list-in-python-dictionary
# - https://pystac-client.readthedocs.io/en/latest/index.html
# - https://pystac.readthedocs.io/en/1.0/

# %% [markdown]
# ## Contact Info:
#
# Email: LPDAAC@usgs.gov
# Voice: +1-866-573-3222
# Organization: Land Processes Distributed Active Archive Center (LP DAAC)¹
# Website: <https://lpdaac.usgs.gov/>
#
# ¹Work performed under USGS contract G15PD00467 for NASA contract NNG14HH33I.
