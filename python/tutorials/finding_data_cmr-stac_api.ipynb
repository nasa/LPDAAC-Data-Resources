# %% [markdown]
# # Finding Data using the NASA CMR-STAC API
#
# **Summary**
#
# This notebook will demonstrate how to find and access remote sensing data using the [NASA Common Metadata Repository (CMR) SpatioTemporal Asset Catalog (STAC) application programming interface (API)](https://cmr.earthdata.nasa.gov/stac/docs/index.html). The CMR-STAC API is NASA's implementation of the [STAC API specification](https://stacspec.org/) for all Earth Science data archived by NASA Earthdata. The current implementation allows users to execute searches within provider catalogs (e.g., LPCLOUD) to find the STAC Items they are searching for. All the providers can be found at the CMR-STAC endpoint here: <https://cmr.earthdata.nasa.gov/stac/>. In this exercise, we will query the **LPCLOUD** provider to identify STAC Items matching our search criteria.
#
# After finding the results we are interested in, we will write a text file output with links that will allow us to access the HLS assets in the cloud. We will create an example text file of these cloud access links for use via HTTPS and Amazon Web Services s3 buckets.
#
# **What is STAC?**
#
# [SpatioTemporal Asset Catalog (STAC)](https://stacspec.org/) is a specification that provides a common language for interpreting geospatial information in order to standardize indexing and discovering data.
#
# The [STAC specification](https://stacspec.org/en/about/stac-spec/) is made up of a collection of related, yet independent specifications that when used together provide search and discovery capabilities for remote assets.
#
# **Four STAC Specifications**
#
# - [STAC Item](https://github.com/radiantearth/stac-spec/blob/master/item-spec/item-spec.md)
# - [STAC Catalog](https://github.com/radiantearth/stac-spec/blob/master/catalog-spec/catalog-spec.md)
# - [STAC Collection](https://github.com/radiantearth/stac-spec/blob/master/collection-spec/collection-spec.md)
# - [STAC API](https://github.com/radiantearth/stac-api-spec)
#
# In the following sections, we will explore each of STAC elements using NASA's CMR-STAC API.
#
# **Requirements:**
# - A NASA [Earthdata Login](https://urs.earthdata.nasa.gov/) account is required to download EMIT data
# - Follow the [instructions](https://github.com/nasa/LPDAAC-Data-Resources/blob/main/setup/setup_instructions_python.md) to set up a compatible local Python environment.
#
# **Learning Objectives:**
# - Understand the STAC Specification and how to use it to find data
# - Write an output text file with links to access the data
# - Open a file and visualize it

# %% [markdown]
# ## Setup
# Import the required packages.

# %%
# import requests
from pystac_client import Client
from collections import defaultdict    
import json
import geopandas as gpd
import hvplot.pandas
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='8e481c3e-1499-492b-9d41-ba0af123b751'>
#   <div id="cf356290-1699-44f3-b6e8-8635cd70850a" data-root-id="8e481c3e-1499-492b-9d41-ba0af123b751" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"27bac8cd-53a3-49e8-a8e9-0be4a1938753":{"version":"3.7.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"8e481c3e-1499-492b-9d41-ba0af123b751"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"ca35447a-16be-4eef-9f99-b022685212bc","attributes":{"plot_id":"8e481c3e-1499-492b-9d41-ba0af123b751","comm_id":"0d555e4ae22849efbd4d98609b66ffb6","client_comm_id":"70ee91c88ab340dcb7d974c52072d16f"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1" ...
#   var render_items = [{"docid":"27bac8cd-53a3-49e8-a8e9-0be4a1938753","roots":{"8e481c3e-1499-492b-9d41-ba0af123b751":"cf356290-1699-44f3-b6e8-8635cd70850a"},"root_ids":["8e481c3e-1499-492b-9d41-ba0af123b751"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %% [markdown]
# ## CMR STAC Client
#
# ### Submit request to the CMR STAC API
#
# Use the `pystac_client` package to submit a request to the CMR STAC API.

# %%
stac_url = 'https://cmr.earthdata.nasa.gov/stac'

# %%
provider_cat = Client.open(stac_url)
provider_cat.to_dict()
# Out:
# {'type': 'Catalog',
#  'id': 'CMR-STAC',
#  'stac_version': '1.1.0',
#  'description': 'This is the landing page for CMR-STAC. Each provider link contains a STAC endpoint.',
#  'links': [{'rel': 'self',
#    'href': 'https://cmr.earthdata.nasa.gov/stac',
#    'type': 'application/json'},
#   {'rel': 'root',
#    'href': 'https://cmr.earthdata.nasa.gov/stac',
#    'type': 'application/json',
#    'title': 'NASA Common Metadata Repository CMR-STAC API'},
#   {'rel': 'service-desc',
#    'href': 'https://api.stacspec.org/v1.0.0-beta.1/openapi.yaml',
#    'type': 'application/yaml',
#    'title': 'OpenAPI Documentation'},
#   {'rel': 'service-doc',
#    'href': 'https://wiki.earthdata.nasa.gov/display/ED/CMR+SpatioTemporal+Asset+Catalog+%28CMR-STAC%29+Documentation',
#    'type': 'text/html',
#    'title': 'NASA CMR-STAC Documentation'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/ESA',
#    'type': 'application/json',
#    'title': 'ESA'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/GHRC',
#    'type': 'application/json',
#    'title': 'GHRC'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/ECHO',
#    'type': 'application/json',
#    'title': 'ECHO'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/ISRO',
#    'type': 'application/json',
#    'title': 'ISRO'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/EDF_DEV04',
#    'type': 'application/json',
#    'title': 'EDF_DEV04'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/ASF',
#    'type': 'application/json',
#    'title': 'ASF'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/EUMETSAT',
#    'type': 'application/json',
#    'title': 'EUMETSAT'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/CDDIS',
#    'type': 'application/json',
#    'title': 'CDDIS'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/JAXA',
#    'type': 'application/json',
#    'title': 'JAXA'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/AU_AADC',
#    'type': 'application/json',
#    'title': 'AU_AADC'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/ECHO10_OPS',
#    'type': 'application/json',
#    'title': 'ECHO10_OPS'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LANCEAMSR2',
#    'type': 'application/json',
#    'title': 'LANCEAMSR2'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/GESDISCCLD',
#    'type': 'application/json',
#    'title': 'GESDISCCLD'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/GHRSSTCWIC',
#    'type': 'application/json',
#    'title': 'GHRSSTCWIC'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LARC_CLOUD',
#    'type': 'application/json',
#    'title': 'LARC_CLOUD'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LANCEMODIS',
#    'type': 'application/json',
#    'title': 'LANCEMODIS'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/NSIDCV0',
#    'type': 'application/json',
#    'title': 'NSIDCV0'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/NSIDC_ECS',
#    'type': 'application/json',
#    'title': 'NSIDC_ECS'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/NCCS',
#    'type': 'application/json',
#    'title': 'NCCS'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/OBPG',
#    'type': 'application/json',
#    'title': 'OBPG'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/OMINRT',
#    'type': 'application/json',
#    'title': 'OMINRT'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_LTA',
#    'type': 'application/json',
#    'title': 'USGS_LTA'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/ASIPS',
#    'type': 'application/json',
#    'title': 'ASIPS'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/ESDIS',
#    'type': 'application/json',
#    'title': 'ESDIS'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/NSIDC_CPRD',
#    'type': 'application/json',
#    'title': 'NSIDC_CPRD'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/ORNL_CLOUD',
#    'type': 'application/json',
#    'title': 'ORNL_CLOUD'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/FEDEO',
#    'type': 'application/json',
#    'title': 'FEDEO'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/MLHUB',
#    'type': 'application/json',
#    'title': 'MLHUB'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LAADS',
#    'type': 'application/json',
#    'title': 'LAADS'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LARC_ASDC',
#    'type': 'application/json',
#    'title': 'LARC_ASDC'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS',
#    'type': 'application/json',
#    'title': 'LPDAAC_ECS'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/NOAA_NCEI',
#    'type': 'application/json',
#    'title': 'NOAA_NCEI'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/OB_DAAC',
#    'type': 'application/json',
#    'title': 'OB_DAAC'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/XYZ_PROV',
#    'type': 'application/json',
#    'title': 'XYZ_PROV'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/GHRC_DAAC',
#    'type': 'application/json',
#    'title': 'GHRC_DAAC'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/CSDA',
#    'type': 'application/json',
#    'title': 'CSDA'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/NRSCC',
#    'type': 'application/json',
#    'title': 'NRSCC'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/CEOS_EXTRA',
#    'type': 'application/json',
#    'title': 'CEOS_EXTRA'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/AMD_KOPRI',
#    'type': 'application/json',
#    'title': 'AMD_KOPRI'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/AMD_USAPDC',
#    'type': 'application/json',
#    'title': 'AMD_USAPDC'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LARC',
#    'type': 'application/json',
#    'title': 'LARC'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/SCIOPS',
#    'type': 'application/json',
#    'title': 'SCIOPS'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/USGS_EROS',
#    'type': 'application/json',
#    'title': 'USGS_EROS'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCUMULUS',
#    'type': 'application/json',
#    'title': 'LPCUMULUS'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/MOPITT',
#    'type': 'application/json',
#    'title': 'MOPITT'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/GHRC_CLOUD',
#    'type': 'application/json',
#    'title': 'GHRC_CLOUD'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD',
#    'type': 'application/json',
#    'title': 'LPCLOUD'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/ORNL_DAAC',
#    'type': 'application/json',
#    'title': 'ORNL_DAAC'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/CCMEO',
#    'type': 'application/json',
#    'title': 'CCMEO'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/POCLOUD',
#    'type': 'application/json',
#    'title': 'POCLOUD'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/PODAAC',
#    'type': 'application/json',
#    'title': 'PODAAC'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/SEDAC',
#    'type': 'application/json',
#    'title': 'SEDAC'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/GES_DISC',
#    'type': 'application/json',
#    'title': 'GES_DISC'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LM_FIRMS',
#    'type': 'application/json',
#    'title': 'LM_FIRMS'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/ENVIDAT',
#    'type': 'application/json',
#    'title': 'ENVIDAT'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/TROPICSDPC',
#    'type': 'application/json',
#    'title': 'TROPICSDPC'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/INPE',
#    'type': 'application/json',
#    'title': 'INPE'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/OB_CLOUD',
#    'type': 'application/json',
#    'title': 'OB_CLOUD'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/USGS',
#    'type': 'application/json',
#    'title': 'USGS'},
#   {'rel': 'child',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/ALL',
#    'type': 'application/json',
#    'title': 'all'}],
#  'conformsTo': ['https://api.stacspec.org/v1.0.0-rc.2/core',
#   'https://api.stacspec.org/v1.0.0-rc.2/item-search',
#   'https://api.stacspec.org/v1.0.0-rc.2/ogcapi-features',
#   'https://api.stacspec.org/v1.0.0-rc.2/item-search#fields',
#   'https://api.stacspec.org/v1.0.0-rc.2/item-search#features',
#   'https://api.stacspec.org/v1.0.0-rc.2/item-search#query',
#   'https://api.stacspec.org/v1.0.0-rc.2/item-search#sort',
#   'https://api.stacspec.org/v1.0.0-rc.2/item-search#context',
#   'http://www.opengis.net/spec/ogcapi-features-1/1.0/conf/core',
#   'http://www.opengis.net/spec/ogcapi-features-1/1.0/conf/oas30',
#   'http://www.opengis.net/spec/ogcapi-features-1/1.0/conf/geojson',
#   'https://api.stacspec.org/v1.0.0-rc.2/collection-search',
#   'https://api.stacspec.org/v1.0.0-rc.2/collection-search#free-text',
#   'https://api.stacspec.org/v1.0.0-rc.2/collection-search#sort',
#   'http://www.opengis.net/spec/ogcapi-common-1/1.0/conf/simple-query'],
#  'title': 'NASA Common Metadata Repository CMR-STAC API'}

# %% [markdown]
# The CMR STAC API endpoint lists the available providers. Each **provider** is a separate STAC Catalog endpoint that can be used to submit spatiotemporal queries against.

# %%
providers = {}
for p in provider_cat.to_dict()['links']:
    if 'child' in p['rel']:
        providers[p['title']] =  p['href'] 
providers
# Out:
# {'ESA': 'https://cmr.earthdata.nasa.gov/stac/ESA',
#  'GHRC': 'https://cmr.earthdata.nasa.gov/stac/GHRC',
#  'ECHO': 'https://cmr.earthdata.nasa.gov/stac/ECHO',
#  'ISRO': 'https://cmr.earthdata.nasa.gov/stac/ISRO',
#  'EDF_DEV04': 'https://cmr.earthdata.nasa.gov/stac/EDF_DEV04',
#  'ASF': 'https://cmr.earthdata.nasa.gov/stac/ASF',
#  'EUMETSAT': 'https://cmr.earthdata.nasa.gov/stac/EUMETSAT',
#  'CDDIS': 'https://cmr.earthdata.nasa.gov/stac/CDDIS',
#  'JAXA': 'https://cmr.earthdata.nasa.gov/stac/JAXA',
#  'AU_AADC': 'https://cmr.earthdata.nasa.gov/stac/AU_AADC',
#  'ECHO10_OPS': 'https://cmr.earthdata.nasa.gov/stac/ECHO10_OPS',
#  'LANCEAMSR2': 'https://cmr.earthdata.nasa.gov/stac/LANCEAMSR2',
#  'GESDISCCLD': 'https://cmr.earthdata.nasa.gov/stac/GESDISCCLD',
#  'GHRSSTCWIC': 'https://cmr.earthdata.nasa.gov/stac/GHRSSTCWIC',
#  'LARC_CLOUD': 'https://cmr.earthdata.nasa.gov/stac/LARC_CLOUD',
#  'LANCEMODIS': 'https://cmr.earthdata.nasa.gov/stac/LANCEMODIS',
#  'NSIDCV0': 'https://cmr.earthdata.nasa.gov/stac/NSIDCV0',
#  'NSIDC_ECS': 'https://cmr.earthdata.nasa.gov/stac/NSIDC_ECS',
#  'NCCS': 'https://cmr.earthdata.nasa.gov/stac/NCCS',
#  'OBPG': 'https://cmr.earthdata.nasa.gov/stac/OBPG',
#  'OMINRT': 'https://cmr.earthdata.nasa.gov/stac/OMINRT',
#  'USGS_LTA': 'https://cmr.earthdata.nasa.gov/stac/USGS_LTA',
#  'ASIPS': 'https://cmr.earthdata.nasa.gov/stac/ASIPS',
#  'ESDIS': 'https://cmr.earthdata.nasa.gov/stac/ESDIS',
#  'NSIDC_CPRD': 'https://cmr.earthdata.nasa.gov/stac/NSIDC_CPRD',
#  'ORNL_CLOUD': 'https://cmr.earthdata.nasa.gov/stac/ORNL_CLOUD',
#  'FEDEO': 'https://cmr.earthdata.nasa.gov/stac/FEDEO',
#  'MLHUB': 'https://cmr.earthdata.nasa.gov/stac/MLHUB',
#  'LAADS': 'https://cmr.earthdata.nasa.gov/stac/LAADS',
#  'LARC_ASDC': 'https://cmr.earthdata.nasa.gov/stac/LARC_ASDC',
#  'LPDAAC_ECS': 'https://cmr.earthdata.nasa.gov/stac/LPDAAC_ECS',
#  'NOAA_NCEI': 'https://cmr.earthdata.nasa.gov/stac/NOAA_NCEI',
#  'OB_DAAC': 'https://cmr.earthdata.nasa.gov/stac/OB_DAAC',
#  'XYZ_PROV': 'https://cmr.earthdata.nasa.gov/stac/XYZ_PROV',
#  'GHRC_DAAC': 'https://cmr.earthdata.nasa.gov/stac/GHRC_DAAC',
#  'CSDA': 'https://cmr.earthdata.nasa.gov/stac/CSDA',
#  'NRSCC': 'https://cmr.earthdata.nasa.gov/stac/NRSCC',
#  'CEOS_EXTRA': 'https://cmr.earthdata.nasa.gov/stac/CEOS_EXTRA',
#  'AMD_KOPRI': 'https://cmr.earthdata.nasa.gov/stac/AMD_KOPRI',
#  'AMD_USAPDC': 'https://cmr.earthdata.nasa.gov/stac/AMD_USAPDC',
#  'LARC': 'https://cmr.earthdata.nasa.gov/stac/LARC',
#  'SCIOPS': 'https://cmr.earthdata.nasa.gov/stac/SCIOPS',
#  'USGS_EROS': 'https://cmr.earthdata.nasa.gov/stac/USGS_EROS',
#  'LPCUMULUS': 'https://cmr.earthdata.nasa.gov/stac/LPCUMULUS',
#  'MOPITT': 'https://cmr.earthdata.nasa.gov/stac/MOPITT',
#  'GHRC_CLOUD': 'https://cmr.earthdata.nasa.gov/stac/GHRC_CLOUD',
#  'LPCLOUD': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD',
#  'ORNL_DAAC': 'https://cmr.earthdata.nasa.gov/stac/ORNL_DAAC',
#  'CCMEO': 'https://cmr.earthdata.nasa.gov/stac/CCMEO',
#  'POCLOUD': 'https://cmr.earthdata.nasa.gov/stac/POCLOUD',
#  'PODAAC': 'https://cmr.earthdata.nasa.gov/stac/PODAAC',
#  'SEDAC': 'https://cmr.earthdata.nasa.gov/stac/SEDAC',
#  'GES_DISC': 'https://cmr.earthdata.nasa.gov/stac/GES_DISC',
#  'LM_FIRMS': 'https://cmr.earthdata.nasa.gov/stac/LM_FIRMS',
#  'ENVIDAT': 'https://cmr.earthdata.nasa.gov/stac/ENVIDAT',
#  'TROPICSDPC': 'https://cmr.earthdata.nasa.gov/stac/TROPICSDPC',
#  'INPE': 'https://cmr.earthdata.nasa.gov/stac/INPE',
#  'OB_CLOUD': 'https://cmr.earthdata.nasa.gov/stac/OB_CLOUD',
#  'USGS': 'https://cmr.earthdata.nasa.gov/stac/USGS',
#  'all': 'https://cmr.earthdata.nasa.gov/stac/ALL'}

# %% [markdown]
# In this example we will explore the collections availablee through `LPCLOUD` provider.

# %%
provider = 'LPCLOUD'
provider_url = providers[provider]
provider_url
# Out:
# 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD'

# %% [markdown]
# We can use both `collection_search` or `get_collections()` a get collections from the provider endpoint while `collection_search` method allows further filtering capabilities. The returned object is a PySTAC CollectionClient which is converted to a list to be able to access the actual contents without iteration.

# %%
catalog = Client.open(provider_url)
# collections = list(catalog.collection_search().collections())
collections = list(catalog.get_collections())
collections
# Out:
# [<CollectionClient id=ASTGTM_NUMNC_003>,
#  <CollectionClient id=ASTGTM_NC_003>,
#  <CollectionClient id=ASTGTM_003>,
#  <CollectionClient id=AG1km_003>,
#  <CollectionClient id=AG100_003>,
#  <CollectionClient id=AG5KMMOH_041>,
#  <CollectionClient id=CAM5K30CFCLIM_003>,
#  <CollectionClient id=CAM5K30CF_002>,
#  <CollectionClient id=CAM5K30COVCLIM_003>,
#  <CollectionClient id=CAM5K30EMCLIM_003>,
#  <CollectionClient id=CAM5K30EM_002>,
#  <CollectionClient id=CAM5K30UCCLIM_003>,
#  <CollectionClient id=CAM5K30UC_002>,
#  <CollectionClient id=WaterBalance_Daily_Historical_GRIDMET_1.5>,
#  <CollectionClient id=ECO_L2G_CLOUD_002>,
#  <CollectionClient id=ECO_L3G_MET_002>,
#  <CollectionClient id=ECO_L3G_SM_002>,
#  <CollectionClient id=ECO_L4G_ESI_002>,
#  <CollectionClient id=ECO_L3G_JET_002>,
#  <CollectionClient id=ECO_L2G_LSTE_002>,
#  <CollectionClient id=ECO_L3G_SEB_002>,
#  <CollectionClient id=ECO_L1CG_RAD_002>,
#  <CollectionClient id=ECO_L4G_WUE_002>,
#  <CollectionClient id=ECO_L1B_ATT_002>,
#  <CollectionClient id=ECO_L2_CLOUD_002>,
#  <CollectionClient id=ECO_L1B_GEO_002>,
#  <CollectionClient id=ECO_L2_LSTE_002>,
#  <CollectionClient id=ECO_L1B_RAD_002>,
#  <CollectionClient id=ECO_L2T_STARS_002>,
#  <CollectionClient id=ECO_L3T_MET_002>,
#  <CollectionClient id=ECO_L3T_SM_002>,
#  <CollectionClient id=ECO_L4T_ESI_002>,
#  <CollectionClient id=ECO_L3T_JET_002>,
#  <CollectionClient id=ECO_L2T_LSTE_002>,
#  <CollectionClient id=ECO_L3T_SEB_002>,
#  <CollectionClient id=ECO_L1CT_RAD_002>,
#  <CollectionClient id=ECO_L4T_WUE_002>,
#  <CollectionClient id=EMITL1BRAD_001>,
#  <CollectionClient id=EMITL1BATT_001>,
#  <CollectionClient id=EMITL2ARFL_001>,
#  <CollectionClient id=EMITL2BCO2ENH_001>,
#  <CollectionClient id=EMITL2BCO2PLM_001>,
#  <CollectionClient id=EMITL2BCH4PLM_001>,
#  <CollectionClient id=EMITL2BMIN_001>,
#  <CollectionClient id=EMITL2BCH4ENH_001>,
#  <CollectionClient id=EMITL3ASA_001>,
#  <CollectionClient id=EMITL4ESM_001>,
#  <CollectionClient id=GLORTHO_001>,
#  <CollectionClient id=GLCHMK_001>,
#  <CollectionClient id=GLCHMT_001>,
#  <CollectionClient id=GLDSMT_001>,
#  <CollectionClient id=GLDTMK_001>,
#  <CollectionClient id=GLDTMT_001>,
#  <CollectionClient id=GLHYANC_001>,
#  <CollectionClient id=GLRADS_001>,
#  <CollectionClient id=GLREFL_001>,
#  <CollectionClient id=GLHYVI_001>,
#  <CollectionClient id=GLLIDARPC_001>,
#  <CollectionClient id=GLMETRICS_001>,
#  <CollectionClient id=GLTRAJECTORY_001>,
#  <CollectionClient id=GEDI01_B_002>,
#  <CollectionClient id=GEDI02_A_002>,
#  <CollectionClient id=GEDI02_B_002>,
#  <CollectionClient id=GFSAD1KCD_001>,
#  <CollectionClient id=GFSAD1KCM_001>,
#  <CollectionClient id=GFSAD30NACE_001>,
#  <CollectionClient id=GFSAD30AFCE_001>,
#  <CollectionClient id=GFSAD30AUNZCNMOCE_001>,
#  <CollectionClient id=GFSAD30EUCEARUMECE_001>,
#  <CollectionClient id=GFSAD30SACE_001>,
#  <CollectionClient id=GFSAD30SAAFGIRCE_001>,
#  <CollectionClient id=GFSAD30SEACE_001>,
#  <CollectionClient id=GFCC30FCC_001>,
#  <CollectionClient id=GFCC30SR_001>,
#  <CollectionClient id=GFCC30TC_003>,
#  <CollectionClient id=GFCC30WC_001>,
#  <CollectionClient id=GHISACASIA_001>,
#  <CollectionClient id=GHISACONUS_001>,
#  <CollectionClient id=GLanCE30_001>,
#  <CollectionClient id=HLSL30_2.0>,
#  <CollectionClient id=HLSL30_VI_2.0>,
#  <CollectionClient id=HLSS30_2.0>,
#  <CollectionClient id=HLSS30_VI_2.0>,
#  <CollectionClient id=LGRIP30_L1_IRRI_002>,
#  <CollectionClient id=LGRIP30_L2_IRRI_002>,
#  <CollectionClient id=LGRIP30_L3_002>,
#  <CollectionClient id=LGRIP30_L1_RAIN_002>,
#  <CollectionClient id=LGRIP30_L2_RAIN_002>,
#  <CollectionClient id=LEOLSTCMG30_001>,
#  <CollectionClient id=LPJ_EOSIM_L2_DCH4E_LL_001>,
#  <CollectionClient id=LPJ_EOSIM_L2_DCH4E_001>,
#  <CollectionClient id=LPJ_EOSIM_L2_MCH4E_LL_001>,
#  <CollectionClient id=LPJ_EOSIM_L2_MCH4E_001>,
#  <CollectionClient id=VCF5KYR_001>,
#  <CollectionClient id=MYD17A2H_061>,
#  <CollectionClient id=MYD17A2HGF_061>,
#  <CollectionClient id=MYD21_061>,
#  <CollectionClient id=MYD21C2_061>,
#  <CollectionClient id=MYD21A2_061>,
#  <CollectionClient id=MYD21C1_061>,
#  <CollectionClient id=MYD21A1D_061>,
#  <CollectionClient id=MYD21A1N_061>,
#  <CollectionClient id=MYD21C3_061>,
#  <CollectionClient id=MYD11_L2_061>,
#  <CollectionClient id=MYD11C2_061>,
#  <CollectionClient id=MYD11A2_061>,
#  <CollectionClient id=MYD11B2_061>,
#  <CollectionClient id=MYD11C1_061>,
#  <CollectionClient id=MYD11A1_061>,
#  <CollectionClient id=MYD11B1_061>,
#  <CollectionClient id=MYD11C3_061>,
#  <CollectionClient id=MYD11B3_061>,
#  <CollectionClient id=MYD15A2H_061>,
#  <CollectionClient id=MYD16A2_061>,
#  <CollectionClient id=MYD16A2GF_061>,
#  <CollectionClient id=MYD16A3GF_061>,
#  <CollectionClient id=MYD17A3HGF_061>,
#  <CollectionClient id=MYD09Q1_061>,
#  <CollectionClient id=MYD09A1_061>,
#  <CollectionClient id=MYD09GA_061>,
#  <CollectionClient id=MYD09GQ_061>,
#  <CollectionClient id=MYD09CMG_061>,
#  <CollectionClient id=MYD14_061>,
#  <CollectionClient id=MYD14A2_061>,
#  <CollectionClient id=MYD14A1_061>,
#  <CollectionClient id=MYD13C1_061>,
#  <CollectionClient id=MYD13A2_061>,
#  <CollectionClient id=MYD13Q1_061>,
#  <CollectionClient id=MYD13A1_061>,
#  <CollectionClient id=MYD13C2_061>,
#  <CollectionClient id=MYD13A3_061>,
#  <CollectionClient id=MYD28C2_061>,
#  <CollectionClient id=MYD28C3_061>,
#  <CollectionClient id=MOD17A2H_061>,
#  <CollectionClient id=MOD17A2HGF_061>,
#  <CollectionClient id=MOD21_061>,
#  <CollectionClient id=MOD21C2_061>,
#  <CollectionClient id=MOD21A2_061>,
#  <CollectionClient id=MOD21C1_061>,
#  <CollectionClient id=MOD21A1D_061>,
#  <CollectionClient id=MOD21A1N_061>,
#  <CollectionClient id=MOD21C3_061>,
#  <CollectionClient id=MOD11_L2_061>,
#  <CollectionClient id=MOD11C2_061>,
#  <CollectionClient id=MOD11A2_061>,
#  <CollectionClient id=MOD11B2_061>,
#  <CollectionClient id=MOD11C1_061>,
#  <CollectionClient id=MOD11A1_061>,
#  <CollectionClient id=MOD11B1_061>,
#  <CollectionClient id=MOD11C3_061>,
#  <CollectionClient id=MOD11B3_061>,
#  <CollectionClient id=MOD44W_061>,
#  <CollectionClient id=MOD15A2H_061>,
#  <CollectionClient id=MOD16A2_061>,
#  <CollectionClient id=MOD16A2GF_061>,
#  <CollectionClient id=MOD16A3GF_061>,
#  <CollectionClient id=MOD17A3HGF_061>,
#  <CollectionClient id=MOD09Q1_061>,
#  <CollectionClient id=MOD09A1_061>,
#  <CollectionClient id=MOD09GA_061>,
#  <CollectionClient id=MOD09GQ_061>,
#  <CollectionClient id=MOD09CMG_061>,
#  <CollectionClient id=MOD14_061>,
#  <CollectionClient id=MOD14A2_061>,
#  <CollectionClient id=MOD14A1_061>,
#  <CollectionClient id=MOD44B_061>,
#  <CollectionClient id=MOD13C1_061>,
#  <CollectionClient id=MOD13A2_061>,
#  <CollectionClient id=MOD13Q1_061>,
#  <CollectionClient id=MOD13A1_061>,
#  <CollectionClient id=MOD13C2_061>,
#  <CollectionClient id=MOD13A3_061>,
#  <CollectionClient id=MOD28C2_061>,
#  <CollectionClient id=MOD28C3_061>,
#  <CollectionClient id=MCD19A2CMG_061>,
#  <CollectionClient id=MCD19A3D_061>,
#  <CollectionClient id=MCD43A3_061>,
#  <CollectionClient id=MCD43C3_061>,
#  <CollectionClient id=MCD43D42_061>,
#  <CollectionClient id=MCD43D43_061>,
#  <CollectionClient id=MCD43D44_061>,
#  <CollectionClient id=MCD43D45_061>,
#  <CollectionClient id=MCD43D46_061>,
#  <CollectionClient id=MCD43D47_061>,
#  <CollectionClient id=MCD43D48_061>,
#  <CollectionClient id=MCD43D50_061>,
#  <CollectionClient id=MCD43D51_061>,
#  <CollectionClient id=MCD43D49_061>,
#  <CollectionClient id=MCD43GF_061>,
#  <CollectionClient id=MCD43A1_061>,
#  <CollectionClient id=MCD43C1_061>,
#  <CollectionClient id=MCD43D62_061>,
#  <CollectionClient id=MCD43D63_061>,
#  <CollectionClient id=MCD43D64_061>,
#  <CollectionClient id=MCD43D65_061>,
#  <CollectionClient id=MCD43D66_061>,
#  <CollectionClient id=MCD43D67_061>,
#  <CollectionClient id=MCD43D68_061>,
#  <CollectionClient id=MCD43A4_061>,
#  <CollectionClient id=MCD43C4_061>,
#  <CollectionClient id=MCD43D01_061>,
#  <CollectionClient id=MCD43D04_061>,
#  <CollectionClient id=MCD43D02_061>,
#  <CollectionClient id=MCD43D05_061>,
#  <CollectionClient id=MCD43D03_061>,
#  <CollectionClient id=MCD43D06_061>,
#  <CollectionClient id=MCD43D07_061>,
#  <CollectionClient id=MCD43D10_061>,
#  <CollectionClient id=MCD43D13_061>,
#  <CollectionClient id=MCD43D16_061>,
#  <CollectionClient id=MCD43D19_061>,
#  <CollectionClient id=MCD43D25_061>,
#  <CollectionClient id=MCD43D28_061>,
#  <CollectionClient id=MCD43D22_061>,
#  <CollectionClient id=MCD43D08_061>,
#  <CollectionClient id=MCD43D11_061>,
#  <CollectionClient id=MCD43D14_061>,
#  <CollectionClient id=MCD43D17_061>,
#  <CollectionClient id=MCD43D20_061>,
#  <CollectionClient id=MCD43D26_061>,
#  <CollectionClient id=MCD43D29_061>,
#  <CollectionClient id=MCD43D23_061>,
#  <CollectionClient id=MCD43D09_061>,
#  <CollectionClient id=MCD43D12_061>,
#  <CollectionClient id=MCD43D15_061>,
#  <CollectionClient id=MCD43D18_061>,
#  <CollectionClient id=MCD43D21_061>,
#  <CollectionClient id=MCD43D27_061>,
#  <CollectionClient id=MCD43D30_061>,
#  <CollectionClient id=MCD43D24_061>,
#  <CollectionClient id=MCD43D31_061>,
#  <CollectionClient id=MCD43D32_061>,
#  <CollectionClient id=MCD43D40_061>,
#  <CollectionClient id=MCD43D41_061>,
#  <CollectionClient id=MCD43D33_061>,
#  <CollectionClient id=MCD43D34_061>,
#  <CollectionClient id=MCD43D35_061>,
#  <CollectionClient id=MCD43D36_061>,
#  <CollectionClient id=MCD43D37_061>,
#  <CollectionClient id=MCD43D38_061>,
#  <CollectionClient id=MCD43D39_061>,
#  <CollectionClient id=MCD43A2_061>,
#  <CollectionClient id=MCD43C2_061>,
#  <CollectionClient id=MCD43D52_061>,
#  <CollectionClient id=MCD43D53_061>,
#  <CollectionClient id=MCD43D54_061>,
#  <CollectionClient id=MCD43D55_061>,
#  <CollectionClient id=MCD43D56_061>,
#  <CollectionClient id=MCD43D57_061>,
#  <CollectionClient id=MCD43D58_061>,
#  <CollectionClient id=MCD43D60_061>,
#  <CollectionClient id=MCD43D61_061>,
#  <CollectionClient id=MCD43D59_061>,
#  <CollectionClient id=MCD64A1_061>,
#  <CollectionClient id=MCD18C1_062>,
#  <CollectionClient id=MCD19A2_061>,
#  <CollectionClient id=MCD19A2_006>,
#  <CollectionClient id=MCD12Q2_061>,
#  <CollectionClient id=MCD12C1_061>,
#  <CollectionClient id=MCD12Q1_061>,
#  <CollectionClient id=MCD19A1_061>,
#  <CollectionClient id=MCD15A3H_061>,
#  <CollectionClient id=MCD15A2H_061>,
#  <CollectionClient id=MCD18C2_062>,
#  <CollectionClient id=MCD18A2_062>,
#  <CollectionClient id=MCD18A1_062>,
#  <CollectionClient id=MCD19A1CMGL_061>,
#  <CollectionClient id=MCD19A1CMGO_061>,
#  <CollectionClient id=MCD19A3CMG_061>,
#  <CollectionClient id=WaterBalance_Monthly_Historical_GRIDMET_1.5>,
#  <CollectionClient id=GWELDYR_003>,
#  <CollectionClient id=GWELDYR_031>,
#  <CollectionClient id=GWELDYR_032>,
#  <CollectionClient id=GWELDMO_003>,
#  <CollectionClient id=GWELDMO_031>,
#  <CollectionClient id=GWELDMO_032>,
#  <CollectionClient id=SRTMIMGM_003>,
#  <CollectionClient id=SRTMGL1N_003>,
#  <CollectionClient id=SRTMGL1_003>,
#  <CollectionClient id=SRTMGL3_NC_003>,
#  <CollectionClient id=SRTMGL3_NUMNC_003>,
#  <CollectionClient id=SRTMGL3N_003>,
#  <CollectionClient id=SRTMGL3S_003>,
#  <CollectionClient id=SRTMGL3_003>,
#  <CollectionClient id=SRTMGL30_002>,
#  <CollectionClient id=SRTMIMGR_003>,
#  <CollectionClient id=SRTMSWBD_003>,
#  <CollectionClient id=NASADEM_NC_001>,
#  <CollectionClient id=NASADEM_HGT_001>,
#  <CollectionClient id=NASADEM_NUMNC_001>,
#  <CollectionClient id=NASADEM_SC_001>,
#  <CollectionClient id=NASADEM_SIM_001>,
#  <CollectionClient id=NASADEM_SSP_001>,
#  <CollectionClient id=NASADEM_SHHP_001>,
#  <CollectionClient id=OPERA_L3_DIST-ALERT-HLS_V1_1>,
#  <CollectionClient id=OPERA_L3_DIST-ANN-HLS_V1_1>,
#  <CollectionClient id=VIPPHEN_EVI2_004>,
#  <CollectionClient id=VIPPHEN_NDVI_004>,
#  <CollectionClient id=VIP15_004>,
#  <CollectionClient id=VIP07_004>,
#  <CollectionClient id=VIP01_004>,
#  <CollectionClient id=VIP30_004>,
#  <CollectionClient id=VJ114IMG_002>,
#  <CollectionClient id=VJ143C3_002>,
#  <CollectionClient id=VJ143MA3_002>,
#  <CollectionClient id=VJ143IA3_002>,
#  <CollectionClient id=VJ143C1_002>,
#  <CollectionClient id=VJ143MA1_002>,
#  <CollectionClient id=VJ143IA1_002>,
#  <CollectionClient id=VJ143MA4_002>,
#  <CollectionClient id=VJ143IA4_002>,
#  <CollectionClient id=VJ143C4_002>,
#  <CollectionClient id=VJ143MA2_002>,
#  <CollectionClient id=VJ143IA2_002>,
#  <CollectionClient id=VJ143C2_002>,
#  <CollectionClient id=VJ143DNBA3_002>,
#  <CollectionClient id=VJ143DNBA1_002>,
#  <CollectionClient id=VJ143DNBA4_002>,
#  <CollectionClient id=VJ143DNBA2_002>,
#  <CollectionClient id=VJ147IMG_002>,
#  <CollectionClient id=VJ121_002>,
#  <CollectionClient id=VJ121C2_002>,
#  <CollectionClient id=VJ121A2_002>,
#  <CollectionClient id=VJ121C1_002>,
#  <CollectionClient id=VJ121A1D_002>,
#  <CollectionClient id=VJ121A1N_002>,
#  <CollectionClient id=VJ121C3_002>,
#  <CollectionClient id=VJ115A2H_002>,
#  <CollectionClient id=VJ103MODLL_021>,
#  <CollectionClient id=VJ109A1_002>,
#  <CollectionClient id=VJ109H1_002>,
#  <CollectionClient id=VJ109GA_002>,
#  <CollectionClient id=VJ109CMG_002>,
#  <CollectionClient id=VJ114A1_002>,
#  <CollectionClient id=VJ114_002>,
#  <CollectionClient id=VJ113C1_002>,
#  <CollectionClient id=VJ113A2_002>,
#  <CollectionClient id=VJ113A1_002>,
#  <CollectionClient id=VJ113C2_002>,
#  <CollectionClient id=VJ113A3_002>,
#  <CollectionClient id=VJ128C2_002>,
#  <CollectionClient id=VJ128C3_002>,
#  <CollectionClient id=VJ147MOD_002>,
#  <CollectionClient id=VNP14IMG_002>,
#  <CollectionClient id=VNP43C3_002>,
#  <CollectionClient id=VNP43MA3_002>,
#  <CollectionClient id=VNP43IA3_002>,
#  <CollectionClient id=VNP43D41_002>,
#  <CollectionClient id=VNP43C1_002>,
#  <CollectionClient id=VNP43MA1_002>,
#  <CollectionClient id=VNP43IA1_002>,
#  <CollectionClient id=VNP43MA4_002>,
#  <CollectionClient id=VNP43IA4_002>,
#  <CollectionClient id=VNP43C4_002>,
#  <CollectionClient id=VNP43D01_002>,
#  <CollectionClient id=VNP43D22_002>,
#  <CollectionClient id=VNP43D25_002>,
#  <CollectionClient id=VNP43D04_002>,
#  <CollectionClient id=VNP43D07_002>,
#  <CollectionClient id=VNP43D10_002>,
#  <CollectionClient id=VNP43D13_002>,
#  <CollectionClient id=VNP43D16_002>,
#  <CollectionClient id=VNP43D19_002>,
#  <CollectionClient id=VNP43D37_002>,
#  <CollectionClient id=VNP43D31_002>,
#  <CollectionClient id=VNP43D34_002>,
#  <CollectionClient id=VNP43D28_002>,
#  <CollectionClient id=VNP43D02_002>,
#  <CollectionClient id=VNP43D23_002>,
#  <CollectionClient id=VNP43D26_002>,
#  <CollectionClient id=VNP43D05_002>,
#  <CollectionClient id=VNP43D08_002>,
#  <CollectionClient id=VNP43D11_002>,
#  <CollectionClient id=VNP43D14_002>,
#  <CollectionClient id=VNP43D17_002>,
#  <CollectionClient id=VNP43D20_002>,
#  <CollectionClient id=VNP43D38_002>,
#  <CollectionClient id=VNP43D32_002>,
#  <CollectionClient id=VNP43D35_002>,
#  <CollectionClient id=VNP43D29_002>,
#  <CollectionClient id=VNP43D03_002>,
#  <CollectionClient id=VNP43D24_002>,
#  <CollectionClient id=VNP43D27_002>,
#  <CollectionClient id=VNP43D06_002>,
#  <CollectionClient id=VNP43D09_002>,
#  <CollectionClient id=VNP43D12_002>,
#  <CollectionClient id=VNP43D15_002>,
#  <CollectionClient id=VNP43D18_002>,
#  <CollectionClient id=VNP43D21_002>,
#  <CollectionClient id=VNP43D39_002>,
#  <CollectionClient id=VNP43D33_002>,
#  <CollectionClient id=VNP43D36_002>,
#  <CollectionClient id=VNP43D30_002>,
#  <CollectionClient id=VNP43MA2_002>,
#  <CollectionClient id=VNP43D40_002>,
#  <CollectionClient id=VNP43IA2_002>,
#  <CollectionClient id=VNP43C2_002>,
#  <CollectionClient id=VNP43D53_002>,
#  <CollectionClient id=VNP43D42_002>,
#  <CollectionClient id=VNP43D49_002>,
#  <CollectionClient id=VNP43D50_002>,
#  <CollectionClient id=VNP43D43_002>,
#  <CollectionClient id=VNP43D44_002>,
#  <CollectionClient id=VNP43D45_002>,
#  <CollectionClient id=VNP43D46_002>,
#  <CollectionClient id=VNP43D47_002>,
#  <CollectionClient id=VNP43D48_002>,
#  <CollectionClient id=VNP64A1_002>,
#  <CollectionClient id=VNP43DNBA3_002>,
#  <CollectionClient id=VNP43DNBA1_002>,
#  <CollectionClient id=VNP43DNBA4_002>,
#  <CollectionClient id=VNP43DNBA2_002>,
#  <CollectionClient id=VNP47IMG_002>,
#  <CollectionClient id=VNP47MOD_002>,
#  <CollectionClient id=VNP22C2_002>,
#  <CollectionClient id=VNP22Q2_002>,
#  <CollectionClient id=VNP21_002>,
#  <CollectionClient id=VNP21C2_002>,
#  <CollectionClient id=VNP21A2_002>,
#  <CollectionClient id=VNP21C1_002>,
#  <CollectionClient id=VNP21A1D_002>,
#  <CollectionClient id=VNP21A1N_002>,
#  <CollectionClient id=VNP21C3_002>,
#  <CollectionClient id=VNP15A2H_002>,
#  <CollectionClient id=VNP03MODLL_002>,
#  <CollectionClient id=VNP09A1_002>,
#  <CollectionClient id=VNP09H1_002>,
#  <CollectionClient id=VNP09GA_002>,
#  <CollectionClient id=VNP09CMG_002>,
#  <CollectionClient id=VNP14A1_002>,
#  <CollectionClient id=VNP14_002>,
#  <CollectionClient id=VNP13C1_002>,
#  <CollectionClient id=VNP13A2_002>,
#  <CollectionClient id=VNP13A1_002>,
#  <CollectionClient id=VNP13C2_002>,
#  <CollectionClient id=VNP13A3_002>,
#  <CollectionClient id=VNP28C2_002>,
#  <CollectionClient id=VNP28C3_002>]

# %% [markdown]
# View the content returned for the first collection.

# %%
collections[0].to_dict()
# Out:
# {'type': 'Collection',
#  'id': 'ASTGTM_NUMNC_003',
#  'stac_version': '1.1.0',
#  'description': 'The ASTER Global Digital Elevation Model (GDEM) Version 3 (ASTGTM) provides a global digital elevation model (DEM) of land areas on Earth at a spatial resolution of 1 arc second (approximately 30 meter horizontal posting at the equator).\r\n\r\nThe development of the ASTER GDEM data products is a collaborative effort between National Aeronautics and Space Administration (NASA) and Japan’s Ministry of Economy, Trade, and Industry (METI). The ASTER GDEM data products are created by the Sensor Information Laboratory Corporation (SILC) in Tokyo. \r\n\r\nThe ASTER GDEM Version 3 data product was created from the automated processing of the entire ASTER Level 1A (https://doi.org/10.5067/ASTER/AST_L1A.003) archive of scenes acquired between March 1, 2000, and November 30, 2013. Stereo correlation was used to produce over one million individual scene based ASTER DEMs, to which cloud masking was applied. All cloud screened DEMs and non-cloud screened DEMs were stacked. Residual bad values and outliers were removed. In areas with limited data stacking, several existing reference DEMs were used to supplement ASTER data to correct for residual anomalies. Selected data were averaged to create final pixel values before partitioning the data into 1 degree latitude by 1 degree longitude tiles with a one pixel overlap. To correct elevation values of water body surfaces, the ASTER Global Water Bodies Database (ASTWBD) (https://doi.org/10.5067/ASTER/ASTWBD.001) Version 1 data product was also generated. \r\n\r\nThe geographic coverage of the ASTER GDEM extends from 83° North to 83° South. Each tile is distributed in NetCDF format and projected on the 1984 World Geodetic System (WGS84)/1996 Earth Gravitational Model (EGM96) geoid. Each of the 22,912 tiles in the collection contain at least 0.01% land area. \r\n\r\nEach ASTGTM_NUMNC file indicates the number of scenes that were processed for each pixel and the source of the data.. The corresponding ASTGTM_NC data product contains a DEM file, which provides elevation information. \r\n\r\nWhile the ASTER GDEM Version 3 data products offer substantial improvements over Version 2, users are advised that the products still may contain anomalies and artifacts that will reduce its usability for certain applications. \r\n\r\nImprovements/Changes from Previous Versions \r\n• Expansion of acquisition coverage to increase the amount of cloud-free input scenes from about 1.5 million in Version 2 to about 1.88 million scenes in Version 3.\r\n• Separation of rivers from lakes in the water body processing. \r\n• Minimum water body detection size decreased from 1 km2 to 0.2 km2. ',
#  'links': [{'rel': 'license',
#    'href': 'https://science.nasa.gov/earth-science/earth-science-data/data-information-policy',
#    'type': 'text/html',
#    'title': 'EOSDIS Data Use Policy'},
#   {'rel': 'about',
#    'href': 'https://cmr.earthdata.nasa.gov/search/concepts/C2439429778-LPCLOUD.html',
#    'type': 'text/html',
#    'title': 'HTML metadata for collection'},
#   {'rel': 'via',
#    'href': 'https://cmr.earthdata.nasa.gov/search/concepts/C2439429778-LPCLOUD.native',
#    'type': 'application/xml',
#    'title': 'Native metadata for collection'},
#   {'rel': 'via',
#    'href': 'https://cmr.earthdata.nasa.gov/search/concepts/C2439429778-LPCLOUD.echo10',
#    'type': 'application/echo10+xml',
#    'title': 'ECHO10 metadata for collection'},
#   {'rel': 'via',
#    'href': 'https://cmr.earthdata.nasa.gov/search/concepts/C2439429778-LPCLOUD.json',
#    'type': 'application/json',
#    'title': 'CMR JSON metadata for collection'},
#   {'rel': 'via',
#    'href': 'https://cmr.earthdata.nasa.gov/search/concepts/C2439429778-LPCLOUD.umm_json',
#    'type': 'application/vnd.nasa.cmr.umm+json',
#    'title': 'CMR UMM_JSON metadata for collection'},
#   {'rel': 'self',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ASTGTM_NUMNC_003',
#    'type': 'application/json'},
#   {'rel': 'root',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD',
#    'type': 'application/json',
#    'title': 'LPCLOUD STAC Catalog'},
#   {'rel': 'items',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ASTGTM_NUMNC_003/items',
#    'type': 'application/geo+json',
#    'title': 'Collection Items'}],
#  'title': 'ASTER Global Digital Elevation Model Attributes NetCDF V003',
#  'extent': {'spatial': {'bbox': [[-180, -83, 180, 82]]},
#   'temporal': {'interval': [['2000-03-01T00:00:00Z',
#      '2013-11-30T23:59:59.999000Z']]}},
#  'license': 'proprietary',
#  'keywords': ['EARTH SCIENCE',
#   'LAND SURFACE',
#   'TOPOGRAPHY',
#   'TERRAIN ELEVATION',
#   'DIGITAL ELEVATION/TERRAIN MODEL (DEM)',
#   'TOPOGRAPHICAL RELIEF MAPS'],
#  'providers': [{'name': 'LPCLOUD', 'roles': ['producer']},
#   {'name': 'NASA EOSDIS', 'roles': ['host']}],
#  'summaries': {'platform': ['Terra'], 'instruments': ['ASTER']},
#  'assets': {'nasa': {'href': 'https://appeears.earthdatacloud.nasa.gov/',
#    'title': 'Direct Download [2]',
#    'description': 'The Application for Extracting and Exploring Analysis Ready Samples (AppEEARS) offers a simple and efficient way to perform data access and transformation processes.',
#    'roles': ['data']},
#   'gov/ASTT/ASTGTM_NUMNC': {'href': 'https://e4ftl01.cr.usgs.gov/ASTT/ASTGTM_NUMNC.003/',
#    'title': 'Direct Download [1]',
#    'description': 'LP DAAC Data Pool provides direct access to available products via HTTPS.',
#    'roles': ['data']},
#   'provider_metadata': {'href': 'https://doi.org/10.5067/ASTER/ASTGTM_NUMNC.003',
#    'title': 'Provider Metadata',
#    'description': 'The LP DAAC product page provides information on Science Data Set layers and links for user guides, ATBDs, data access, tools, customer support, etc. ',
#    'roles': ['metadata']},
#   's3_lp_prod_protected_ASTGTM_NUMNC_003': {'href': 's3://lp-prod-protected/ASTGTM_NUMNC.003',
#    'title': 'lp_prod_protected_ASTGTM_NUMNC_003',
#    'roles': ['data']},
#   's3_lp_prod_public_ASTGTM_NUMNC_003': {'href': 's3://lp-prod-public/ASTGTM_NUMNC.003',
#    'title': 'lp_prod_public_ASTGTM_NUMNC_003',
#    'roles': ['data']},
#   's3_credentials': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/s3credentials',
#    'title': 'S3 credentials API endpoint',
#    'roles': ['metadata']},
#   's3_credentials_documentation': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/s3credentialsREADME',
#    'title': 'S3 credentials API endpoint documentation',
#    'roles': ['metadata']},
#   'metadata': {'href': 'https://cmr.earthdata.nasa.gov/search/concepts/C2439429778-LPCLOUD.xml',
#    'type': 'application/xml',
#    'title': 'CMR XML metadata for C2439429778-LPCLOUD',
#    'roles': ['metadata']}}}

# %% [markdown]
# There's a lot of information returned for each collection. Let's print all available STAC Collections within the `LPCLOUD` catalog.

# %%
for c in collections:
    print(f'{c.id}: {c.title}')
# Out:
# ASTGTM_NUMNC_003: ASTER Global Digital Elevation Model Attributes NetCDF V003
# ASTGTM_NC_003: ASTER Global Digital Elevation Model NetCDF V003
# ASTGTM_003: ASTER Global Digital Elevation Model V003
# AG1km_003: ASTER Global Emissivity Dataset, 1 kilometer, HDF5 V003
# AG100_003: ASTER Global Emissivity Dataset, 100 meter, HDF5 V003
# AG5KMMOH_041: ASTER Global Emissivity Dataset, Monthly, 0.05 deg, HDF5 V041
# CAM5K30CFCLIM_003: Combined ASTER and MODIS Emissivity database over Land (CAMEL) Coefficient Climatology Monthly Global 0.05Deg V003
# CAM5K30CF_002: Combined ASTER and MODIS Emissivity database over Land (CAMEL) Coefficient Monthly Global 0.05Deg V002
# CAM5K30COVCLIM_003: Combined ASTER and MODIS Emissivity database over Land (CAMEL) Covariances Climatology Monthly Global 0.25Deg V003
# CAM5K30EMCLIM_003: Combined ASTER and MODIS Emissivity database over Land (CAMEL) Emissivity Climatology Monthly Global 0.05Deg V003
# CAM5K30EM_002: Combined ASTER and MODIS Emissivity database over Land (CAMEL) Emissivity Monthly Global 0.05Deg V002
# CAM5K30UCCLIM_003: Combined ASTER and MODIS Emissivity database over Land (CAMEL) Uncertainty Climatology Monthly Global 0.05Deg V003
# CAM5K30UC_002: Combined ASTER and MODIS Emissivity database over Land (CAMEL) Uncertainty Monthly Global 0.05Deg V002
# WaterBalance_Daily_Historical_GRIDMET_1.5: Daily Historical Water Balance Products for the CONUS
# ECO_L2G_CLOUD_002: ECOSTRESS Gridded Cloud Mask Instantaneous L2 Global 70 m V002
# ECO_L3G_MET_002: ECOSTRESS Gridded Downscaled Meteorology Instantaneous L3 Global 70 m V002
# ECO_L3G_SM_002: ECOSTRESS Gridded Downscaled Soil Moisture Instantaneous L3 Global 70 m V002
# ECO_L4G_ESI_002: ECOSTRESS Gridded Evaporative Stress Index PT-JPL Instantaneous L4 Global 70 m V002
# ECO_L3G_JET_002: ECOSTRESS Gridded Evapotranspiration Instantaneous and Daytime L3 Global 70 m V002
# ECO_L2G_LSTE_002: ECOSTRESS Gridded Land Surface Temperature and Emissivity Instantaneous L2 Global 70 m V002
# ECO_L3G_SEB_002: ECOSTRESS Gridded Surface Energy Balance Instantaneous L3 Global 70 m V002
# ECO_L1CG_RAD_002: ECOSTRESS Gridded Top of Atmosphere Calibrated Radiance Instantaneous L1C Global 70 m V002
# ECO_L4G_WUE_002: ECOSTRESS Gridded Water Use Efficiency Instantaneous L4 Global 70 m V002
# ECO_L1B_ATT_002: ECOSTRESS Swath Attitude and Ephemeris Instantaneous L1B Global V002
# ECO_L2_CLOUD_002: ECOSTRESS Swath Cloud Mask Instantaneous L2 Global 70 m V002
# ECO_L1B_GEO_002: ECOSTRESS Swath Geolocation Instantaneous L1B Global 70 m V002
# ECO_L2_LSTE_002: ECOSTRESS Swath Land Surface Temperature and Emissivity Instantaneous L2 Global 70 m V002
# ECO_L1B_RAD_002: ECOSTRESS Swath Top of Atmosphere Calibrated Radiance Instantaneous L1B Global 70 m V002
# ECO_L2T_STARS_002: ECOSTRESS Tiled Ancillary NDVI and Albedo L2 Global 70 m V002
# ECO_L3T_MET_002: ECOSTRESS Tiled Downscaled Meteorology Instantaneous L3 Global 70 m V002
# ECO_L3T_SM_002: ECOSTRESS Tiled Downscaled Soil Moisture Instantaneous L3 Global 70 m V002
# ECO_L4T_ESI_002: ECOSTRESS Tiled Evaporative Stress Index PT-JPL Instantaneous L4 Global 70 m V002
# ECO_L3T_JET_002: ECOSTRESS Tiled Evapotranspiration Instantaneous and Daytime L3 Global 70 m V002
# ECO_L2T_LSTE_002: ECOSTRESS Tiled Land Surface Temperature and Emissivity Instantaneous L2 Global 70 m V002
# ECO_L3T_SEB_002: ECOSTRESS Tiled Surface Energy Balance Instantaneous L3 Global 70 m V002
# ECO_L1CT_RAD_002: ECOSTRESS Tiled Top of Atmosphere Calibrated Radiance Instantaneous L1C Global 70 m V002
# ECO_L4T_WUE_002: ECOSTRESS Tiled Water Use Efficiency Instantaneous L4 Global 70 m V002
# EMITL1BRAD_001: EMIT L1B At-Sensor Calibrated Radiance and Geolocation Data 60 m V001
# EMITL1BATT_001: EMIT L1B Corrected Spacecraft Attitude and Ephemeris V001
# EMITL2ARFL_001: EMIT L2A Estimated Surface Reflectance and Uncertainty and Masks 60 m V001
# EMITL2BCO2ENH_001: EMIT L2B Carbon Dioxide Enhancement Data 60 m V001
# EMITL2BCO2PLM_001: EMIT L2B Estimated Carbon Dioxide Plume Complexes 60 m V001
# EMITL2BCH4PLM_001: EMIT L2B Estimated Methane Plume Complexes 60 m V001
# EMITL2BMIN_001: EMIT L2B Estimated Mineral Identification and Band Depth and Uncertainty 60 m V001
# EMITL2BCH4ENH_001: EMIT L2B Methane Enhancement Data 60 m V001
# EMITL3ASA_001: EMIT L3 Aggregated Mineral Spectral Abundance and Uncertainty 0.5 Deg V001
# EMITL4ESM_001: EMIT L4 Earth System Model Products V001
# GLORTHO_001: G-LiHT Aerial Orthomosaic V001
# GLCHMK_001: G-LiHT Canopy Height Model KML V001
# GLCHMT_001: G-LiHT Canopy Height Model V001
# GLDSMT_001: G-LiHT Digital Surface Model V001
# GLDTMK_001: G-LiHT Digital Terrain Model KML V001
# GLDTMT_001: G-LiHT Digital Terrain Model V001
# GLHYANC_001: G-LiHT Hyperspectral Ancillary V001
# GLRADS_001: G-LiHT Hyperspectral Radiance V001
# GLREFL_001: G-LiHT Hyperspectral Reflectance V001
# GLHYVI_001: G-LiHT Hyperspectral Vegetative Indices V001
# GLLIDARPC_001: G-LiHT Lidar Point Cloud V001
# GLMETRICS_001: G-LiHT Metrics V001
# GLTRAJECTORY_001: G-LiHT Trajectory Data V001
# GEDI01_B_002: GEDI L1B Geolocated Waveform Data Global Footprint Level V002
# GEDI02_A_002: GEDI L2A Elevation and Height Metrics Data Global Footprint Level V002
# GEDI02_B_002: GEDI L2B Canopy Cover and Vertical Profile Metrics Data Global Footprint Level V002
# GFSAD1KCD_001: Global Food Security Support Analysis Data (GFSAD) Crop Dominance 2010 Global 1 km V001
# GFSAD1KCM_001: Global Food Security Support Analysis Data (GFSAD) Crop Mask 2010 Global 1 km V001
# GFSAD30NACE_001: Global Food Security-support Analysis Data (GFSAD) Cropland Extent 2010 North America product 30 m V001
# GFSAD30AFCE_001: Global Food Security-support Analysis Data (GFSAD) Cropland Extent 2015 Africa 30 m V001
# GFSAD30AUNZCNMOCE_001: Global Food Security-support Analysis Data (GFSAD) Cropland Extent 2015 Australia, New Zealand, China, Mongolia 30 m V001
# GFSAD30EUCEARUMECE_001: Global Food Security-support Analysis Data (GFSAD) Cropland Extent 2015 Europe, Central Asia, Russia, Middle East product 30 m V001
# GFSAD30SACE_001: Global Food Security-support Analysis Data (GFSAD) Cropland Extent 2015 South America product 30 m V001
# GFSAD30SAAFGIRCE_001: Global Food Security-support Analysis Data (GFSAD) Cropland Extent 2015 South Asia, Afghanistan, and Iran product 30 m V001
# GFSAD30SEACE_001: Global Food Security-support Analysis Data (GFSAD) Cropland Extent 2015 Southeast and Northeast Asia product 30 m V001
# GFCC30FCC_001: Global Forest Cover Change Forest Cover Change Multi-Year Global 30m V001
# GFCC30SR_001: Global Forest Cover Change Surface Reflectance Estimates Multi-Year Global 30m V001
# GFCC30TC_003: Global Forest Cover Change Tree Cover Multi-Year Global 30m V003
# GFCC30WC_001: Global Forest Cover Change Water Cover 2000 Global 30m V001
# GHISACASIA_001: Global Hyperspectral Imaging Spectral-library of Agricultural crops for Central Asia V001
# GHISACONUS_001: Global Hyperspectral Imaging Spectral-library of Agricultural crops for Conterminous United States V001
# GLanCE30_001: Global Land Cover Mapping and Estimation Yearly 30 m V001
# HLSL30_2.0: HLS Landsat Operational Land Imager Surface Reflectance and TOA Brightness Daily Global 30m v2.0
# HLSL30_VI_2.0: HLS Operational Land Imager Vegetation Indices Daily Global 30 m V2.0
# HLSS30_2.0: HLS Sentinel-2 Multi-spectral Instrument Surface Reflectance Daily Global 30m v2.0
# HLSS30_VI_2.0: HLS Sentinel-2 Multi-spectral Instrument Vegetation Indices Daily Global 30 m V2.0
# LGRIP30_L1_IRRI_002: Landsat-Derived Global Irrigated-Cropland Product L1 2020 30 m V002
# LGRIP30_L2_IRRI_002: Landsat-Derived Global Irrigated-Cropland Product L2 2020 30 m V002
# LGRIP30_L3_002: Landsat-derived Global Rainfed and Irrigated-Cropland Product L3 2020 30 m V002
# LGRIP30_L1_RAIN_002: Landsat-Derived Global Rainfed-Cropland Product L1 2020 30 m V002
# LGRIP30_L2_RAIN_002: Landsat-Derived Global Rainfed-Cropland Product L2 2020 30 m V002
# LEOLSTCMG30_001: Low Earth Orbit Land Surface Temperature Monthly Global Gridded V001
# LPJ_EOSIM_L2_DCH4E_LL_001: LPJ-EOSIM L2 Global Simulated Daily Wetland Methane Flux Low Latency V001
# LPJ_EOSIM_L2_DCH4E_001: LPJ-EOSIM L2 Global Simulated Daily Wetland Methane Flux V001
# LPJ_EOSIM_L2_MCH4E_LL_001: LPJ-EOSIM L2 Global Simulated Monthly Wetland Methane Flux Low Latency V001
# LPJ_EOSIM_L2_MCH4E_001: LPJ-EOSIM L2 Global Simulated Monthly Wetland Methane Flux V001
# VCF5KYR_001: MEaSUREs Vegetation Continuous Fields (VCF) Yearly Global 0.05 Deg V001
# MYD17A2H_061: MODIS/Aqua Gross Primary Productivity 8-Day L4 Global 500m SIN Grid V061
# MYD17A2HGF_061: MODIS/Aqua Gross Primary Productivity Gap-Filled 8-Day L4 Global 500m SIN Grid V061
# MYD21_061: MODIS/Aqua Land Surface Temperature/3-Band Emissivity 5-Min L2 1km V061
# MYD21C2_061: MODIS/Aqua Land Surface Temperature/3-Band Emissivity 8-Day L3 Global 0.05Deg CMG V061
# MYD21A2_061: MODIS/Aqua Land Surface Temperature/3-Band Emissivity 8-Day L3 Global 1km SIN Grid V061
# MYD21C1_061: MODIS/Aqua Land Surface Temperature/3-Band Emissivity Daily L3 Global 0.05Deg CMG V061
# MYD21A1D_061: MODIS/Aqua Land Surface Temperature/3-Band Emissivity Daily L3 Global 1km SIN Grid Day V061
# MYD21A1N_061: MODIS/Aqua Land Surface Temperature/3-Band Emissivity Daily L3 Global 1km SIN Grid Night V061
# MYD21C3_061: MODIS/Aqua Land Surface Temperature/3-Band Emissivity Monthly L3 Global 0.05Deg CMG V061
# MYD11_L2_061: MODIS/Aqua Land Surface Temperature/Emissivity 5-Min L2 Swath 1km V061
# MYD11C2_061: MODIS/Aqua Land Surface Temperature/Emissivity 8-Day L3 Global 0.05Deg CMG V061
# MYD11A2_061: MODIS/Aqua Land Surface Temperature/Emissivity 8-Day L3 Global 1km SIN Grid V061
# MYD11B2_061: MODIS/Aqua Land Surface Temperature/Emissivity 8-Day L3 Global 6km SIN Grid V061
# MYD11C1_061: MODIS/Aqua Land Surface Temperature/Emissivity Daily L3 Global 0.05Deg CMG V061
# MYD11A1_061: MODIS/Aqua Land Surface Temperature/Emissivity Daily L3 Global 1km SIN Grid V061
# MYD11B1_061: MODIS/Aqua Land Surface Temperature/Emissivity Daily L3 Global 6km SIN Grid V061
# MYD11C3_061: MODIS/Aqua Land Surface Temperature/Emissivity Monthly L3 Global 0.05Deg CMG V061
# MYD11B3_061: MODIS/Aqua Land Surface Temperature/Emissivity Monthly L3 Global 6km SIN Grid V061
# MYD15A2H_061: MODIS/Aqua Leaf Area Index/FPAR 8-Day L4 Global 500m SIN Grid V061
# MYD16A2_061: MODIS/Aqua Net Evapotranspiration 8-Day L4 Global 500m SIN Grid V061
# MYD16A2GF_061: MODIS/Aqua Net Evapotranspiration Gap-Filled 8-Day L4 Global 500m SIN Grid V061
# MYD16A3GF_061: MODIS/Aqua Net Evapotranspiration Gap-Filled Yearly L4 Global 500m SIN Grid V061
# MYD17A3HGF_061: MODIS/Aqua Net Primary Production Gap-Filled Yearly L4 Global 500m SIN Grid V061
# MYD09Q1_061: MODIS/Aqua Surface Reflectance 8-Day L3 Global 250m SIN Grid V061
# MYD09A1_061: MODIS/Aqua Surface Reflectance 8-Day L3 Global 500m SIN Grid V061
# MYD09GA_061: MODIS/Aqua Surface Reflectance Daily L2G Global 1km and 500m SIN Grid V061
# MYD09GQ_061: MODIS/Aqua Surface Reflectance Daily L2G Global 250m SIN Grid V061
# MYD09CMG_061: MODIS/Aqua Surface Reflectance Daily L3 Global 0.05Deg CMG V061
# MYD14_061: MODIS/Aqua Thermal Anomalies/Fire 5-Min L2 Swath 1km V061
# MYD14A2_061: MODIS/Aqua Thermal Anomalies/Fire 8-Day L3 Global 1km SIN Grid V061
# MYD14A1_061: MODIS/Aqua Thermal Anomalies/Fire Daily L3 Global 1km SIN Grid V061
# MYD13C1_061: MODIS/Aqua Vegetation Indices 16-Day L3 Global 0.05Deg CMG V061
# MYD13A2_061: MODIS/Aqua Vegetation Indices 16-Day L3 Global 1km SIN Grid V061
# MYD13Q1_061: MODIS/Aqua Vegetation Indices 16-Day L3 Global 250m SIN Grid V061
# MYD13A1_061: MODIS/Aqua Vegetation Indices 16-Day L3 Global 500m SIN Grid V061
# MYD13C2_061: MODIS/Aqua Vegetation Indices Monthly L3 Global 0.05Deg CMG V061
# MYD13A3_061: MODIS/Aqua Vegetation Indices Monthly L3 Global 1km SIN Grid V061
# MYD28C2_061: MODIS/Aqua Water Reservoir 8-Day L3 Global V061
# MYD28C3_061: MODIS/Aqua Water Reservoir Monthly L3 Global V061
# MOD17A2H_061: MODIS/Terra Gross Primary Productivity 8-Day L4 Global 500m SIN Grid V061
# MOD17A2HGF_061: MODIS/Terra Gross Primary Productivity Gap-Filled 8-Day L4 Global 500m SIN Grid V061
# MOD21_061: MODIS/Terra Land Surface Temperature/3-Band Emissivity 5-Min L2 1km V061
# MOD21C2_061: MODIS/Terra Land Surface Temperature/3-Band Emissivity 8-Day L3 Global 0.05Deg CMG V061
# MOD21A2_061: MODIS/Terra Land Surface Temperature/3-Band Emissivity 8-Day L3 Global 1km SIN Grid V061
# MOD21C1_061: MODIS/Terra Land Surface Temperature/3-Band Emissivity Daily L3 Global 0.05Deg CMG V061
# MOD21A1D_061: MODIS/Terra Land Surface Temperature/3-Band Emissivity Daily L3 Global 1km SIN Grid Day V061
# MOD21A1N_061: MODIS/Terra Land Surface Temperature/3-Band Emissivity Daily L3 Global 1km SIN Grid Night V061
# MOD21C3_061: MODIS/Terra Land Surface Temperature/3-Band Emissivity Monthly L3 Global 0.05Deg CMG V061
# MOD11_L2_061: MODIS/Terra Land Surface Temperature/Emissivity 5-Min L2 Swath 1km V061
# MOD11C2_061: MODIS/Terra Land Surface Temperature/Emissivity 8-Day L3 Global 0.05Deg CMG V061
# MOD11A2_061: MODIS/Terra Land Surface Temperature/Emissivity 8-Day L3 Global 1km SIN Grid V061
# MOD11B2_061: MODIS/Terra Land Surface Temperature/Emissivity 8-Day L3 Global 6km SIN Grid V061
# MOD11C1_061: MODIS/Terra Land Surface Temperature/Emissivity Daily L3 Global 0.05Deg CMG V061
# MOD11A1_061: MODIS/Terra Land Surface Temperature/Emissivity Daily L3 Global 1km SIN Grid V061
# MOD11B1_061: MODIS/Terra Land Surface Temperature/Emissivity Daily L3 Global 6km SIN Grid V061
# MOD11C3_061: MODIS/Terra Land Surface Temperature/Emissivity Monthly L3 Global 0.05Deg CMG V061
# MOD11B3_061: MODIS/Terra Land Surface Temperature/Emissivity Monthly L3 Global 6km SIN Grid V061
# MOD44W_061: MODIS/Terra Land Water Mask Derived from MODIS and SRTM L3 Global 250m SIN Grid V061
# MOD15A2H_061: MODIS/Terra Leaf Area Index/FPAR 8-Day L4 Global 500m SIN Grid V061
# MOD16A2_061: MODIS/Terra Net Evapotranspiration 8-Day L4 Global 500m SIN Grid V061
# MOD16A2GF_061: MODIS/Terra Net Evapotranspiration Gap-Filled 8-Day L4 Global 500m SIN Grid V061
# MOD16A3GF_061: MODIS/Terra Net Evapotranspiration Gap-Filled Yearly L4 Global 500m SIN Grid V061
# MOD17A3HGF_061: MODIS/Terra Net Primary Production Gap-Filled Yearly L4 Global 500m SIN Grid V061
# MOD09Q1_061: MODIS/Terra Surface Reflectance 8-Day L3 Global 250m SIN Grid V061
# MOD09A1_061: MODIS/Terra Surface Reflectance 8-Day L3 Global 500m SIN Grid V061
# MOD09GA_061: MODIS/Terra Surface Reflectance Daily L2G Global 1km and 500m SIN Grid V061
# MOD09GQ_061: MODIS/Terra Surface Reflectance Daily L2G Global 250m SIN Grid V061
# MOD09CMG_061: MODIS/Terra Surface Reflectance Daily L3 Global 0.05Deg CMG V061
# MOD14_061: MODIS/Terra Thermal Anomalies/Fire 5-Min L2 Swath 1km V061
# MOD14A2_061: MODIS/Terra Thermal Anomalies/Fire 8-Day L3 Global 1km SIN Grid V061
# MOD14A1_061: MODIS/Terra Thermal Anomalies/Fire Daily L3 Global 1km SIN Grid V061
# MOD44B_061: MODIS/Terra Vegetation Continuous Fields Yearly L3 Global 250m SIN Grid V061
# MOD13C1_061: MODIS/Terra Vegetation Indices 16-Day L3 Global 0.05Deg CMG V061
# MOD13A2_061: MODIS/Terra Vegetation Indices 16-Day L3 Global 1km SIN Grid V061
# MOD13Q1_061: MODIS/Terra Vegetation Indices 16-Day L3 Global 250m SIN Grid V061
# MOD13A1_061: MODIS/Terra Vegetation Indices 16-Day L3 Global 500m SIN Grid V061
# MOD13C2_061: MODIS/Terra Vegetation Indices Monthly L3 Global 0.05Deg CMG V061
# MOD13A3_061: MODIS/Terra Vegetation Indices Monthly L3 Global 1km SIN Grid V061
# MOD28C2_061: MODIS/Terra Water Reservoir 8-Day L3 Global V061
# MOD28C3_061: MODIS/Terra Water Reservoir Monthly L3 Global V061
# MCD19A2CMG_061: MODIS/Terra+Aqua AOD and Water Vapor from MAIAC, Daily L3 Global 0.05Deg CMG V061
# MCD19A3D_061: MODIS/Terra+Aqua BRDF Model Parameters Daily L3 Global 1km SIN Grid V061
# MCD43A3_061: MODIS/Terra+Aqua BRDF/Albedo Albedo Daily L3 Global - 500m V061
# MCD43C3_061: MODIS/Terra+Aqua BRDF/Albedo Albedo Daily L3 Global 0.05Deg CMG V061
# MCD43D42_061: MODIS/Terra+Aqua BRDF/Albedo Black Sky Albedo Band1 Daily L3 Global 30ArcSec CMG V061
# MCD43D43_061: MODIS/Terra+Aqua BRDF/Albedo Black Sky Albedo Band2 Daily L3 Global 30ArcSec CMG V061
# MCD43D44_061: MODIS/Terra+Aqua BRDF/Albedo Black Sky Albedo Band3 Daily L3 Global 30ArcSec CMG V061
# MCD43D45_061: MODIS/Terra+Aqua BRDF/Albedo Black Sky Albedo Band4 Daily L3 Global 30ArcSec CMG V061
# MCD43D46_061: MODIS/Terra+Aqua BRDF/Albedo Black Sky Albedo Band5 Daily L3 Global 30ArcSec CMG V061
# MCD43D47_061: MODIS/Terra+Aqua BRDF/Albedo Black Sky Albedo Band6 Daily L3 Global 30ArcSec CMG V061
# MCD43D48_061: MODIS/Terra+Aqua BRDF/Albedo Black Sky Albedo Band7 Daily L3 Global 30ArcSec CMG V061
# MCD43D50_061: MODIS/Terra+Aqua BRDF/Albedo Black Sky Albedo NIR Daily L3 Global 30ArcSec CMG V061
# MCD43D51_061: MODIS/Terra+Aqua BRDF/Albedo Black Sky Albedo Shortwave Daily L3 Global 30ArcSec CMG V061
# MCD43D49_061: MODIS/Terra+Aqua BRDF/Albedo Black Sky Albedo VIS Daily L3 Global 30ArcSec CMG V061
# MCD43GF_061: MODIS/Terra+Aqua BRDF/Albedo Gap-Filled Snow-Free Daily L3 Global 30ArcSec CMG V061
# MCD43A1_061: MODIS/Terra+Aqua BRDF/Albedo Model Parameters Daily L3 Global - 500m V061
# MCD43C1_061: MODIS/Terra+Aqua BRDF/Albedo Model Parameters Daily L3 Global 0.05Deg CMG V061
# MCD43D62_061: MODIS/Terra+Aqua BRDF/Albedo Nadir BRDF-Adjusted Ref Band1 Daily L3 Global 30ArcSec CMG V061
# MCD43D63_061: MODIS/Terra+Aqua BRDF/Albedo Nadir BRDF-Adjusted Ref Band2 Daily L3 Global 30ArcSec CMG V061
# MCD43D64_061: MODIS/Terra+Aqua BRDF/Albedo Nadir BRDF-Adjusted Ref Band3 Daily L3 Global 30ArcSec CMG V061
# MCD43D65_061: MODIS/Terra+Aqua BRDF/Albedo Nadir BRDF-Adjusted Ref Band4 Daily L3 Global 30ArcSec CMG V061
# MCD43D66_061: MODIS/Terra+Aqua BRDF/Albedo Nadir BRDF-Adjusted Ref Band5 Daily L3 Global 30ArcSec CMG V061
# MCD43D67_061: MODIS/Terra+Aqua BRDF/Albedo Nadir BRDF-Adjusted Ref Band6 Daily L3 Global 30ArcSec CMG V061
# MCD43D68_061: MODIS/Terra+Aqua BRDF/Albedo Nadir BRDF-Adjusted Ref Band7 Daily L3 Global 30ArcSec CMG V061
# MCD43A4_061: MODIS/Terra+Aqua BRDF/Albedo Nadir BRDF-Adjusted Ref Daily L3 Global - 500m V061
# MCD43C4_061: MODIS/Terra+Aqua BRDF/Albedo Nadir BRDF-Adjusted Ref Daily L3 Global 0.05Deg CMG V061
# MCD43D01_061: MODIS/Terra+Aqua BRDF/Albedo Parameter 1 Band 1 Daily L3 Global 30 ArcSec CMG V061
# MCD43D04_061: MODIS/Terra+Aqua BRDF/Albedo Parameter 1 Band 2 Daily L3 Global 30 ArcSec CMG V061
# MCD43D02_061: MODIS/Terra+Aqua BRDF/Albedo Parameter 2 Band 1 Daily L3 Global 30 ArcSec CMG V061
# MCD43D05_061: MODIS/Terra+Aqua BRDF/Albedo Parameter 2 Band 2 Daily L3 Global 30 ArcSec CMG V061
# MCD43D03_061: MODIS/Terra+Aqua BRDF/Albedo Parameter 3 Band 1 Daily L3 Global 30 ArcSec CMG V061
# MCD43D06_061: MODIS/Terra+Aqua BRDF/Albedo Parameter 3 Band 2 Daily L3 Global 30 ArcSec CMG V061
# MCD43D07_061: MODIS/Terra+Aqua BRDF/Albedo Parameter1 Band3 Daily L3 Global 30ArcSec CMG V061
# MCD43D10_061: MODIS/Terra+Aqua BRDF/Albedo Parameter1 Band4 Daily L3 Global 30ArcSec CMG V061
# MCD43D13_061: MODIS/Terra+Aqua BRDF/Albedo Parameter1 Band5 Daily L3 Global 30ArcSec CMG V061
# MCD43D16_061: MODIS/Terra+Aqua BRDF/Albedo Parameter1 Band6 Daily L3 Global 30ArcSec CMG V061
# MCD43D19_061: MODIS/Terra+Aqua BRDF/Albedo Parameter1 Band7 Daily L3 Global 30ArcSec CMG V061
# MCD43D25_061: MODIS/Terra+Aqua BRDF/Albedo Parameter1 NIR Daily L3 Global 30ArcSec CMG V061
# MCD43D28_061: MODIS/Terra+Aqua BRDF/Albedo Parameter1 Shortwave Daily L3 Global 30ArcSec CMG V061
# MCD43D22_061: MODIS/Terra+Aqua BRDF/Albedo Parameter1 VIS Daily L3 Global 30ArcSec CMG V061
# MCD43D08_061: MODIS/Terra+Aqua BRDF/Albedo Parameter2 Band3 Daily L3 Global 30ArcSec CMG V061
# MCD43D11_061: MODIS/Terra+Aqua BRDF/Albedo Parameter2 Band4 Daily L3 Global 30ArcSec CMG V061
# MCD43D14_061: MODIS/Terra+Aqua BRDF/Albedo Parameter2 Band5 Daily L3 Global 30ArcSec CMG V061
# MCD43D17_061: MODIS/Terra+Aqua BRDF/Albedo Parameter2 Band6 Daily L3 Global 30ArcSec CMG V061
# MCD43D20_061: MODIS/Terra+Aqua BRDF/Albedo Parameter2 Band7 Daily L3 Global 30ArcSec CMG V061
# MCD43D26_061: MODIS/Terra+Aqua BRDF/Albedo Parameter2 NIR Daily L3 Global 30ArcSec CMG V061
# MCD43D29_061: MODIS/Terra+Aqua BRDF/Albedo Parameter2 Shortwave Daily L3 Global 30ArcSec CMG V061
# MCD43D23_061: MODIS/Terra+Aqua BRDF/Albedo Parameter2 VIS Daily L3 Global 30ArcSec CMG V061
# MCD43D09_061: MODIS/Terra+Aqua BRDF/Albedo Parameter3 Band3 Daily L3 Global 30ArcSec CMG V061
# MCD43D12_061: MODIS/Terra+Aqua BRDF/Albedo Parameter3 Band4 Daily L3 Global 30ArcSec CMG V061
# MCD43D15_061: MODIS/Terra+Aqua BRDF/Albedo Parameter3 Band5 Daily L3 Global 30ArcSec CMG V061
# MCD43D18_061: MODIS/Terra+Aqua BRDF/Albedo Parameter3 Band6 Daily L3 Global 30ArcSec CMG V061
# MCD43D21_061: MODIS/Terra+Aqua BRDF/Albedo Parameter3 Band7 Daily L3 Global 30ArcSec CMG V061
# MCD43D27_061: MODIS/Terra+Aqua BRDF/Albedo Parameter3 NIR Daily L3 Global 30ArcSec CMG V061
# MCD43D30_061: MODIS/Terra+Aqua BRDF/Albedo Parameter3 Shortwave Daily L3 Global 30ArcSec CMG V061
# MCD43D24_061: MODIS/Terra+Aqua BRDF/Albedo Parameter3 VIS Daily L3 Global 30ArcSec CMG V061
# MCD43D31_061: MODIS/Terra+Aqua BRDF/Albedo QA BRDFQuality Daily L3 Global 30ArcSec CMG V061
# MCD43D32_061: MODIS/Terra+Aqua BRDF/Albedo QA LocalSolarNoon Daily L3 Global 30ArcSec CMG V061
# MCD43D40_061: MODIS/Terra+Aqua BRDF/Albedo QA SnowStatus Daily L3 Global 30ArcSec CMG V061
# MCD43D41_061: MODIS/Terra+Aqua BRDF/Albedo QA Uncertainty Daily L3 Global 30ArcSec CMG V061
# MCD43D33_061: MODIS/Terra+Aqua BRDF/Albedo QA ValidobsBand1 Daily L3 Global 30ArcSec CMG V061
# MCD43D34_061: MODIS/Terra+Aqua BRDF/Albedo QA ValidobsBand2 Daily L3 Global 30ArcSec CMG V061
# MCD43D35_061: MODIS/Terra+Aqua BRDF/Albedo QA ValidobsBand3 Daily L3 Global 30ArcSec CMG V061
# MCD43D36_061: MODIS/Terra+Aqua BRDF/Albedo QA ValidobsBand4 Daily L3 Global 30ArcSec CMG V061
# MCD43D37_061: MODIS/Terra+Aqua BRDF/Albedo QA ValidobsBand5 Daily L3 Global 30ArcSec CMG V061
# MCD43D38_061: MODIS/Terra+Aqua BRDF/Albedo QA ValidobsBand6 Daily L3 Global 30ArcSec CMG V061
# MCD43D39_061: MODIS/Terra+Aqua BRDF/Albedo QA ValidobsBand7 Daily L3 Global 30ArcSec CMG V061
# MCD43A2_061: MODIS/Terra+Aqua BRDF/Albedo Quality Daily L3 Global - 500m V061
# MCD43C2_061: MODIS/Terra+Aqua BRDF/Albedo Snow-free Model Parameters Daily L3 Global 0.05Deg CMG V061
# MCD43D52_061: MODIS/Terra+Aqua BRDF/Albedo White Sky Albedo Band1 Daily L3 Global 30ArcSec CMG V061
# MCD43D53_061: MODIS/Terra+Aqua BRDF/Albedo White Sky Albedo Band2 Daily L3 Global 30ArcSec CMG V061
# MCD43D54_061: MODIS/Terra+Aqua BRDF/Albedo White Sky Albedo Band3 Daily L3 Global 30ArcSec CMG V061
# MCD43D55_061: MODIS/Terra+Aqua BRDF/Albedo White Sky Albedo Band4 Daily L3 Global 30ArcSec CMG V061
# MCD43D56_061: MODIS/Terra+Aqua BRDF/Albedo White Sky Albedo Band5 Daily L3 Global 30ArcSec CMG V061
# MCD43D57_061: MODIS/Terra+Aqua BRDF/Albedo White Sky Albedo Band6 Daily L3 Global 30ArcSec CMG V061
# MCD43D58_061: MODIS/Terra+Aqua BRDF/Albedo White Sky Albedo Band7 Daily L3 Global 30ArcSec CMG V061
# MCD43D60_061: MODIS/Terra+Aqua BRDF/Albedo White Sky Albedo NIR Daily L3 Global 30ArcSec CMG V061
# MCD43D61_061: MODIS/Terra+Aqua BRDF/Albedo White Sky Albedo Shortwave Daily L3 Global 30ArcSec CMG V061
# MCD43D59_061: MODIS/Terra+Aqua BRDF/Albedo White Sky Albedo VIS Daily L3 Global 30ArcSec CMG V061
# MCD64A1_061: MODIS/Terra+Aqua Direct Broadcast Burned Area Monthly L3 Global 500m SIN Grid V061
# MCD18C1_062: MODIS/Terra+Aqua Downward Shortwave Radiation Daily/3-Hour L3 Global 0.05Deg CMG V062
# MCD19A2_061: MODIS/Terra+Aqua Land Aerosol Optical Depth Daily L2G Global 1km SIN Grid V061
# MCD19A2_006: MODIS/Terra+Aqua Land Aerosol Optical Thickness Daily L2G Global 1km SIN Grid V006
# MCD12Q2_061: MODIS/Terra+Aqua Land Cover Dynamics Yearly L3 Global 500m SIN Grid V061
# MCD12C1_061: MODIS/Terra+Aqua Land Cover Type Yearly L3 Global 0.05Deg CMG V061
# MCD12Q1_061: MODIS/Terra+Aqua Land Cover Type Yearly L3 Global 500m SIN Grid V061
# MCD19A1_061: MODIS/Terra+Aqua Land Surface BRF Daily L2G Global 500m and 1km SIN Grid V061
# MCD15A3H_061: MODIS/Terra+Aqua Leaf Area Index/FPAR 4-Day L4 Global 500m SIN Grid V061
# MCD15A2H_061: MODIS/Terra+Aqua Leaf Area Index/FPAR 8-Day L4 Global 500m SIN Grid V061
# MCD18C2_062: MODIS/Terra+Aqua Photosynthetically Active Radiation Daily/3-Hour L3 Global 0.05Deg CMG V062
# MCD18A2_062: MODIS/Terra+Aqua Photosynthetically Active Radiation Daily/3-Hour L3 Global 1km SIN Grid V062
# MCD18A1_062: MODIS/Terra+Aqua Surface Radiation Daily/3-Hour L3 Global 1km SIN Grid V062
# MCD19A1CMGL_061: MODIS/Terra+Aqua Surface Reflectance (Bands 1-7) from MAIAC, Daily L3 Global 0.05Deg CMG V061
# MCD19A1CMGO_061: MODIS/Terra+Aqua Surface Reflectance (Bands 8-12) from MAIAC, Daily L3 Global 0.05Deg CMG V061
# MCD19A3CMG_061: MODIS/Terra+Aqua Vegetation Index from MAIAC, Daily L3 Global 0.05Deg CMG V061
# WaterBalance_Monthly_Historical_GRIDMET_1.5: Monthly Historical Water Balance Products for the CONUS
# GWELDYR_003: NASA Global Web-Enabled Landsat Data Annual Global 30 m V003
# GWELDYR_031: NASA Global Web-Enabled Landsat Data Annual Global 30 m V031
# GWELDYR_032: NASA Global Web-Enabled Landsat Data Annual Global 30 m V032
# GWELDMO_003: NASA Global Web-Enabled Landsat Data Monthly Global 30 m V003
# GWELDMO_031: NASA Global Web-Enabled Landsat Data Monthly Global 30 m V031
# GWELDMO_032: NASA Global Web-Enabled Landsat Data Monthly Global 30 m V032
# SRTMIMGM_003: NASA Shuttle Radar Topography Mission Combined Image Data Set V003
# SRTMGL1N_003: NASA Shuttle Radar Topography Mission Global 1 arc second number V003
# SRTMGL1_003: NASA Shuttle Radar Topography Mission Global 1 arc second V003
# SRTMGL3_NC_003: NASA Shuttle Radar Topography Mission Global 3 arc second NetCDF V003
# SRTMGL3_NUMNC_003: NASA Shuttle Radar Topography Mission Global 3 arc second Number NetCDF V003
# SRTMGL3N_003: NASA Shuttle Radar Topography Mission Global 3 arc second number V003
# SRTMGL3S_003: NASA Shuttle Radar Topography Mission Global 3 arc second sub-sampled V003
# SRTMGL3_003: NASA Shuttle Radar Topography Mission Global 3 arc second V003
# SRTMGL30_002: NASA Shuttle Radar Topography Mission Global 30 arc second V002
# SRTMIMGR_003: NASA Shuttle Radar Topography Mission Swath Image Data V003
# SRTMSWBD_003: NASA Shuttle Radar Topography Mission Water Body Data Shapefiles & Raster Files V003
# NASADEM_NC_001: NASADEM Merged DEM Global 1 arc second nc V001
# NASADEM_HGT_001: NASADEM Merged DEM Global 1 arc second V001
# NASADEM_NUMNC_001: NASADEM Merged DEM Source Global 1 arc second nc V001
# NASADEM_SC_001: NASADEM Slope and Curvation Global 1 arc second V001
# NASADEM_SIM_001: NASADEM SRTM Image Mosaic Global 1 arc second V001
# NASADEM_SSP_001: NASADEM SRTM Subswath Global 1 arc second V001
# NASADEM_SHHP_001: NASADEM SRTM-only Height and Height Precision Mosaic Global 1 arc second V001
# OPERA_L3_DIST-ALERT-HLS_V1_1: OPERA Land Surface Disturbance Alert from Harmonized Landsat Sentinel-2 product (Version 1)
# OPERA_L3_DIST-ANN-HLS_V1_1: OPERA Land Surface Disturbance Annual from Harmonized Landsat Sentinel-2 product (Version 1)
# VIPPHEN_EVI2_004: Vegetation Index and Phenology (VIP) Phenology EVI-2 Yearly Global 0.05Deg CMG V004
# VIPPHEN_NDVI_004: Vegetation Index and Phenology (VIP) Phenology NDVI Yearly Global 0.05Deg CMG V004
# VIP15_004: Vegetation Index and Phenology (VIP) Vegetation Indices 15Days Global 0.05Deg CMG V004
# VIP07_004: Vegetation Index and Phenology (VIP) Vegetation Indices 7Days Global 0.05Deg CMG V004
# VIP01_004: Vegetation Index and Phenology (VIP) Vegetation Indices Daily Global 0.05Deg CMG V004
# VIP30_004: Vegetation Index and Phenology (VIP) Vegetation Indices Monthly Global 0.05Deg CMG V004
# VJ114IMG_002: VIIRS/JPSS1 Active Fires 6-Min L2 Swath 375m V002
# VJ143C3_002: VIIRS/JPSS1 BRDF/Albedo Albedo Daily L3 Global 0.05Deg CMG V002
# VJ143MA3_002: VIIRS/JPSS1 BRDF/Albedo Albedo Daily L3 Global 1km SIN Grid V002
# VJ143IA3_002: VIIRS/JPSS1 BRDF/Albedo Albedo Daily L3 Global 500m SIN Grid V002
# VJ143C1_002: VIIRS/JPSS1 BRDF/Albedo Model Parameters Daily L3 Global 0.05Deg CMG V002
# VJ143MA1_002: VIIRS/JPSS1 BRDF/Albedo Model Parameters Daily L3 Global 1km SIN Grid V002
# VJ143IA1_002: VIIRS/JPSS1 BRDF/Albedo Model Parameters Daily L3 Global 500m SIN Grid V002
# VJ143MA4_002: VIIRS/JPSS1 BRDF/Albedo Nadir BRDF-Adjusted Ref Daily L3 Global 1km SIN Grid V002
# VJ143IA4_002: VIIRS/JPSS1 BRDF/Albedo Nadir BRDF-Adjusted Ref Daily L3 Global 500m SIN Grid V002
# VJ143C4_002: VIIRS/JPSS1 BRDF/Albedo Nadir BRDF-Adjusted Reflectance Daily L3 Global 0.05Deg CMG V002
# VJ143MA2_002: VIIRS/JPSS1 BRDF/Albedo Quality Daily L3 Global 1km SIN Grid V002
# VJ143IA2_002: VIIRS/JPSS1 BRDF/Albedo Quality Daily L3 Global 500m SIN Grid V002
# VJ143C2_002: VIIRS/JPSS1 BRDF/Albedo Snow-free Model Parameters Daily L3 Global 0.05Deg CMG V002
# VJ143DNBA3_002: VIIRS/JPSS1 DNB BRDF/Albedo Albedo Daily L3 Global 1km SIN Grid V002
# VJ143DNBA1_002: VIIRS/JPSS1 DNB BRDF/Albedo Model Parameters Daily L3 Global 1km SIN Grid V002
# VJ143DNBA4_002: VIIRS/JPSS1 DNB BRDF/Albedo Nadir BRDF-Adjusted Ref Daily L3 Global 1km SIN Grid V002
# VJ143DNBA2_002: VIIRS/JPSS1 DNB BRDF/Albedo Quality Daily L3 Global 1km SIN Grid V002
# VJ147IMG_002: VIIRS/JPSS1 FILDA-2 Fire Modified Combustion Efficiency Product 6-min L2 Swath 375 V002
# VJ121_002: VIIRS/JPSS1 Land Surface Temperature and Emissivity 6-Min L2 Swath 750m V002
# VJ121C2_002: VIIRS/JPSS1 Land Surface Temperature/Emissivity 8-Day L3 Global 0.05Deg CMG V002
# VJ121A2_002: VIIRS/JPSS1 Land Surface Temperature/Emissivity 8-Day L3 Global 1km SIN Grid V002
# VJ121C1_002: VIIRS/JPSS1 Land Surface Temperature/Emissivity Daily L3 Global 0.05Deg CMG V002
# VJ121A1D_002: VIIRS/JPSS1 Land Surface Temperature/Emissivity Daily L3 Global 1km SIN Grid Day V002
# VJ121A1N_002: VIIRS/JPSS1 Land Surface Temperature/Emissivity Daily L3 Global 1km SIN Grid Night V002
# VJ121C3_002: VIIRS/JPSS1 Land Surface Temperature/Emissivity Monthly L3 Global 0.05Deg CMG V002
# VJ115A2H_002: VIIRS/JPSS1 Leaf Area Index/FPAR 8-Day L4 Global 500m SIN Grid V002
# VJ103MODLL_021: VIIRS/JPSS1 Moderate Resolution Terrain Corrected Geolocation 6-Min L1 Swath 750m Light V021
# VJ109A1_002: VIIRS/JPSS1 Surface Reflectance 8-Day L3 Global 1km SIN Grid V002
# VJ109H1_002: VIIRS/JPSS1 Surface Reflectance 8-Day L3 Global 500m SIN Grid V002
# VJ109GA_002: VIIRS/JPSS1 Surface Reflectance Daily L2G Global 1km and 500m SIN Grid V002
# VJ109CMG_002: VIIRS/JPSS1 Surface Reflectance Daily L3 Global 0.05Deg CMG V002
# VJ114A1_002: VIIRS/JPSS1 Thermal Anomalies and Fire Daily L3 Global 1km SIN Grid V002
# VJ114_002: VIIRS/JPSS1 Thermal Anomalies/Fire 6-Min L2 Swath 750m V002
# VJ113C1_002: VIIRS/JPSS1 Vegetation Indices 16-Day L3 Global 0.05Deg CMG V002
# VJ113A2_002: VIIRS/JPSS1 Vegetation Indices 16-Day L3 Global 1km SIN Grid V002
# VJ113A1_002: VIIRS/JPSS1 Vegetation Indices 16-Day L3 Global 500m SIN Grid V002
# VJ113C2_002: VIIRS/JPSS1 Vegetation Indices Monthly L3 Global 0.05Deg CMG V002
# VJ113A3_002: VIIRS/JPSS1 Vegetation Indices Monthly L3 Global 1km SIN Grid V002
# VJ128C2_002: VIIRS/JPSS1 Water Reservoir Area 8-day L3 Global V002
# VJ128C3_002: VIIRS/JPSS1 Water Reservoir Monthly L3 Global V002
# VJ147MOD_002: VIIRS/JPSS1 FILDA-2 Fire Modified Combustion Efficiency Product 6-min L2 Swath 750m V002
# VNP14IMG_002: VIIRS/NPP Active Fires 6-Min L2 Swath 375m V002
# VNP43C3_002: VIIRS/NPP BRDF/Albedo Albedo Daily L3 Global 0.05Deg CMG V002
# VNP43MA3_002: VIIRS/NPP BRDF/Albedo Albedo Daily L3 Global 1km SIN Grid V002
# VNP43IA3_002: VIIRS/NPP BRDF/Albedo Albedo Daily L3 Global 500m SIN Grid V002
# VNP43D41_002: VIIRS/NPP BRDF/Albedo Local Solar Noon Daily L3 Global 30ArcSec CMG V002
# VNP43C1_002: VIIRS/NPP BRDF/Albedo Model Parameters Daily L3 Global 0.05Deg CMG V002
# VNP43MA1_002: VIIRS/NPP BRDF/Albedo Model Parameters Daily L3 Global 1km SIN Grid V002
# VNP43IA1_002: VIIRS/NPP BRDF/Albedo Model Parameters Daily L3 Global 500m SIN Grid V002
# VNP43MA4_002: VIIRS/NPP BRDF/Albedo Nadir BRDF-Adjusted Ref Daily L3 Global 1km SIN Grid V002
# VNP43IA4_002: VIIRS/NPP BRDF/Albedo Nadir BRDF-Adjusted Ref Daily L3 Global 500m SIN Grid V002
# VNP43C4_002: VIIRS/NPP BRDF/Albedo Nadir BRDF-Adjusted Reflectance Daily L3 Global 0.05Deg CMG V002
# VNP43D01_002: VIIRS/NPP BRDF/Albedo Parameter 1 Band M1 Daily L3 Global 30 ArcSec CMG V002
# VNP43D22_002: VIIRS/NPP BRDF/Albedo Parameter 1 Band M10 Daily L3 Global 30 ArcSec CMG V002
# VNP43D25_002: VIIRS/NPP BRDF/Albedo Parameter 1 Band M11 Daily L3 Global 30 ArcSec CMG V002
# VNP43D04_002: VIIRS/NPP BRDF/Albedo Parameter 1 Band M2 Daily L3 Global 30 ArcSec CMG V002
# VNP43D07_002: VIIRS/NPP BRDF/Albedo Parameter 1 Band M3 Daily L3 Global 30 ArcSec CMG V002
# VNP43D10_002: VIIRS/NPP BRDF/Albedo Parameter 1 Band M4 Daily L3 Global 30 ArcSec CMG V002
# VNP43D13_002: VIIRS/NPP BRDF/Albedo Parameter 1 Band M5 Daily L3 Global 30 ArcSec CMG V002
# VNP43D16_002: VIIRS/NPP BRDF/Albedo Parameter 1 Band M7 Daily L3 Global 30 ArcSec CMG V002
# VNP43D19_002: VIIRS/NPP BRDF/Albedo Parameter 1 Band M8 Daily L3 Global 30 ArcSec CMG V002
# VNP43D37_002: VIIRS/NPP BRDF/Albedo Parameter 1 DNB Daily L3 Global 30 ArcSec CMG V002
# VNP43D31_002: VIIRS/NPP BRDF/Albedo Parameter 1 NIR Daily L3 Global 30 ArcSec CMG V002
# VNP43D34_002: VIIRS/NPP BRDF/Albedo Parameter 1 ShortWave Daily L3 Global 30 ArcSec CMG V002
# VNP43D28_002: VIIRS/NPP BRDF/Albedo Parameter 1 VIS Daily L3 Global 30 ArcSec CMG V002
# VNP43D02_002: VIIRS/NPP BRDF/Albedo Parameter 2 Band M1 Daily L3 Global 30 ArcSec CMG V002
# VNP43D23_002: VIIRS/NPP BRDF/Albedo Parameter 2 Band M10 Daily L3 Global 30 ArcSec CMG V002
# VNP43D26_002: VIIRS/NPP BRDF/Albedo Parameter 2 Band M11 Daily L3 Global 30 ArcSec CMG V002
# VNP43D05_002: VIIRS/NPP BRDF/Albedo Parameter 2 Band M2 Daily L3 Global 30 ArcSec CMG V002
# VNP43D08_002: VIIRS/NPP BRDF/Albedo Parameter 2 Band M3 Daily L3 Global 30 ArcSec CMG V002
# VNP43D11_002: VIIRS/NPP BRDF/Albedo Parameter 2 Band M4 Daily L3 Global 30 ArcSec CMG V002
# VNP43D14_002: VIIRS/NPP BRDF/Albedo Parameter 2 Band M5 Daily L3 Global 30 ArcSec CMG V002
# VNP43D17_002: VIIRS/NPP BRDF/Albedo Parameter 2 Band M7 Daily L3 Global 30 ArcSec CMG V002
# VNP43D20_002: VIIRS/NPP BRDF/Albedo Parameter 2 Band M8 Daily L3 Global 30 ArcSec CMG V002
# VNP43D38_002: VIIRS/NPP BRDF/Albedo Parameter 2 DNB Daily L3 Global 30 ArcSec CMG V002
# VNP43D32_002: VIIRS/NPP BRDF/Albedo Parameter 2 NIR Daily L3 Global 30 ArcSec CMG V002
# VNP43D35_002: VIIRS/NPP BRDF/Albedo Parameter 2 ShortWave Daily L3 Global 30 ArcSec CMG V002
# VNP43D29_002: VIIRS/NPP BRDF/Albedo Parameter 2 VIS Daily L3 Global 30 ArcSec CMG V002
# VNP43D03_002: VIIRS/NPP BRDF/Albedo Parameter 3 Band M1 Daily L3 Global 30 ArcSec CMG V002
# VNP43D24_002: VIIRS/NPP BRDF/Albedo Parameter 3 Band M10 Daily L3 Global 30 ArcSec CMG V002
# VNP43D27_002: VIIRS/NPP BRDF/Albedo Parameter 3 Band M11 Daily L3 Global 30 ArcSec CMG V002
# VNP43D06_002: VIIRS/NPP BRDF/Albedo Parameter 3 Band M2 Daily L3 Global 30 ArcSec CMG V002
# VNP43D09_002: VIIRS/NPP BRDF/Albedo Parameter 3 Band M3 Daily L3 Global 30 ArcSec CMG V002
# VNP43D12_002: VIIRS/NPP BRDF/Albedo Parameter 3 Band M4 Daily L3 Global 30 ArcSec CMG V002
# VNP43D15_002: VIIRS/NPP BRDF/Albedo Parameter 3 Band M5 Daily L3 Global 30 ArcSec CMG V002
# VNP43D18_002: VIIRS/NPP BRDF/Albedo Parameter 3 Band M7 Daily L3 Global 30 ArcSec CMG V002
# VNP43D21_002: VIIRS/NPP BRDF/Albedo Parameter 3 Band M8 Daily L3 Global 30 ArcSec CMG V002
# VNP43D39_002: VIIRS/NPP BRDF/Albedo Parameter 3 DNB Daily L3 Global 30 ArcSec CMG V002
# VNP43D33_002: VIIRS/NPP BRDF/Albedo Parameter 3 NIR Daily L3 Global 30 ArcSec CMG V002
# VNP43D36_002: VIIRS/NPP BRDF/Albedo Parameter 3 ShortWave Daily L3 Global 30 ArcSec CMG V002
# VNP43D30_002: VIIRS/NPP BRDF/Albedo Parameter 3 VIS Daily L3 Global 30 ArcSec CMG V002
# VNP43MA2_002: VIIRS/NPP BRDF/Albedo Quality Daily L3 Global 1km SIN Grid V002
# VNP43D40_002: VIIRS/NPP BRDF/Albedo Quality Daily L3 Global 30ArcSec CMG V002
# VNP43IA2_002: VIIRS/NPP BRDF/Albedo Quality Daily L3 Global 500m SIN Grid V002
# VNP43C2_002: VIIRS/NPP BRDF/Albedo Snow-free Model Parameters Daily L3 Global 0.05Deg CMG V002
# VNP43D53_002: VIIRS/NPP BRDF/Albedo Uncertainty Daily L3 Global 30ArcSec CMG V002
# VNP43D42_002: VIIRS/NPP BRDF/Albedo Valid Observation Band M1 Daily L3 Global 30ArcSec CMG V002
# VNP43D49_002: VIIRS/NPP BRDF/Albedo Valid Observation Band M10 Daily L3 Global 30ArcSec CMG V002
# VNP43D50_002: VIIRS/NPP BRDF/Albedo Valid Observation Band M11 Daily L3 Global 30ArcSec CMG V002
# VNP43D43_002: VIIRS/NPP BRDF/Albedo Valid Observation Band M2 Daily L3 Global 30ArcSec CMG V002
# VNP43D44_002: VIIRS/NPP BRDF/Albedo Valid Observation Band M3 Daily L3 Global 30ArcSec CMG V002
# VNP43D45_002: VIIRS/NPP BRDF/Albedo Valid Observation Band M4 Daily L3 Global 30ArcSec CMG V002
# VNP43D46_002: VIIRS/NPP BRDF/Albedo Valid Observation Band M5 Daily L3 Global 30ArcSec CMG V002
# VNP43D47_002: VIIRS/NPP BRDF/Albedo Valid Observation Band M7 Daily L3 Global 30ArcSec CMG V002
# VNP43D48_002: VIIRS/NPP BRDF/Albedo Valid Observation Band M8 Daily L3 Global 30ArcSec CMG V002
# VNP64A1_002: VIIRS/NPP Burned Area Monthly L4 Global 500m SIN Grid V002
# VNP43DNBA3_002: VIIRS/NPP DNB BRDF/Albedo Albedo Daily L3 Global 1km SIN Grid V002
# VNP43DNBA1_002: VIIRS/NPP DNB BRDF/Albedo Model Parameters Daily L3 Global 1km SIN Grid V002
# VNP43DNBA4_002: VIIRS/NPP DNB BRDF/Albedo Nadir BRDF-Adjusted Ref Daily L3 Global 1km SIN Grid V002
# VNP43DNBA2_002: VIIRS/NPP DNB BRDF/Albedo Quality Daily L3 Global 1km SIN Grid V002
# VNP47IMG_002: VIIRS/NPP FILDA-2 Fire Modified Combustion Efficiency Product 6-min L2 Swath 375 V002
# VNP47MOD_002: VIIRS/NPP FILDA-2 Fire Modified Combustion Efficiency Product 6-min L2 Swath 750 V002
# VNP22C2_002: VIIRS/NPP Land Surface Phenology Yearly L3 Global 0.05Deg CMG V002
# VNP22Q2_002: VIIRS/NPP Land Surface Phenology Yearly L3 Global 500m SIN Grid V002
# VNP21_002: VIIRS/NPP Land Surface Temperature and Emissivity 6-Min L2 Swath 750m V002
# VNP21C2_002: VIIRS/NPP Land Surface Temperature/Emissivity 8-Day L3 Global 0.05Deg CMG V002
# VNP21A2_002: VIIRS/NPP Land Surface Temperature/Emissivity 8-Day L3 Global 1km SIN Grid V002
# VNP21C1_002: VIIRS/NPP Land Surface Temperature/Emissivity Daily L3 Global 0.05Deg CMG V002
# VNP21A1D_002: VIIRS/NPP Land Surface Temperature/Emissivity Daily L3 Global 1km SIN Grid Day V002
# VNP21A1N_002: VIIRS/NPP Land Surface Temperature/Emissivity Daily L3 Global 1km SIN Grid Night V002
# VNP21C3_002: VIIRS/NPP Land Surface Temperature/Emissivity Monthly L3 Global 0.05Deg CMG V002
# VNP15A2H_002: VIIRS/NPP Leaf Area Index/FPAR 8-Day L4 Global 500m SIN Grid V002
# VNP03MODLL_002: VIIRS/NPP Moderate Resolution Terrain Corrected Geolocation 6-Min L1 Swath 750m Light V002
# VNP09A1_002: VIIRS/NPP Surface Reflectance 8-Day L3 Global 1km SIN Grid V002
# VNP09H1_002: VIIRS/NPP Surface Reflectance 8-Day L3 Global 500m SIN Grid V002
# VNP09GA_002: VIIRS/NPP Surface Reflectance Daily L2G Global 1km and 500m SIN Grid V002
# VNP09CMG_002: VIIRS/NPP Surface Reflectance Daily L3 Global 0.05Deg CMG V002
# VNP14A1_002: VIIRS/NPP Thermal Anomalies and Fire Daily L3 Global 1km SIN Grid V002
# VNP14_002: VIIRS/NPP Thermal Anomalies/Fire 6-Min L2 Swath 750m V002
# VNP13C1_002: VIIRS/NPP Vegetation Indices 16-Day L3 Global 0.05Deg CMG V002
# VNP13A2_002: VIIRS/NPP Vegetation Indices 16-Day L3 Global 1km SIN Grid V002
# VNP13A1_002: VIIRS/NPP Vegetation Indices 16-Day L3 Global 500m SIN Grid V002
# VNP13C2_002: VIIRS/NPP Vegetation Indices Monthly L3 Global 0.05Deg CMG V002
# VNP13A3_002: VIIRS/NPP Vegetation Indices Monthly L3 Global 1km SIN Grid V002
# VNP28C2_002: VIIRS/NPP Water Reservoir Area 8-day L3 Global V002
# VNP28C3_002: VIIRS/NPP Water Reservoir Monthly L3 Global V002

# %%
print(f'LPCLOUD has {len(collections)} Collections')
# Out:
# LPCLOUD has 438 Collections

# %% [markdown]
# The `LPCLOUD` provider offers over 400 data products available in Earthdata Cloud. Using `collection_search` method, a string can be used to search through the available collections. The `collections` method allows iteration through the returned results. In this example, collections are filtered to retain only those that include "HLS" in their records.

# %%
for result in catalog.collection_search(q="HLS").collections():
    for link in result.links:
        if 'self' in link.rel:
            print(result.id, f"{link.href}", sep=": ")
# Out:
# HLSL30_2.0: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30_2.0
# HLSS30_2.0: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSS30_2.0
# HLSL30_VI_2.0: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30_VI_2.0
# HLSS30_VI_2.0: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSS30_VI_2.0
# ECO_L2T_LSTE_002: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L2T_LSTE_002
# OPERA_L3_DIST-ALERT-HLS_V1_1: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/OPERA_L3_DIST-ALERT-HLS_V1_1
# ECO_L2T_STARS_002: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L2T_STARS_002
# ECO_L3T_JET_002: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L3T_JET_002
# ECO_L1CT_RAD_002: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L1CT_RAD_002
# ECO_L4T_ESI_002: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L4T_ESI_002
# ECO_L4T_WUE_002: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L4T_WUE_002
# ECO_L3T_MET_002: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L3T_MET_002
# ECO_L3T_SEB_002: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L3T_SEB_002
# ECO_L3T_SM_002: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/ECO_L3T_SM_002
# OPERA_L3_DIST-ANN-HLS_V1_1: https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/OPERA_L3_DIST-ANN-HLS_V1_1

# %% [markdown]
# ### Get information about an individual Collection
#
# Once the desired collections are identified, their collection IDs can be used for further queries. Below we'll specify a STAC Collection, `HLSL30_2.0`, and request its STAC metadata. Note that the Collection IDs in CMR STAC differ from product short names.

# %%
# Define desired collection
collection = 'HLSL30_2.0'

# %%
#  = catalog.search(collections=collection)
catalog.get_collection(collection).to_dict()
# Out:
# {'type': 'Collection',
#  'id': 'HLSL30_2.0',
#  'stac_version': '1.1.0',
#  'description': 'The Harmonized Landsat Sentinel-2 (HLS) project provides consistent surface reflectance (SR) and top of atmosphere (TOA) brightness data from a virtual constellation of satellite sensors. The Operational Land Imager (OLI) is housed aboard the joint NASA/USGS Landsat 8 and Landsat 9 satellites, while the Multi-Spectral Instrument (MSI) is mounted aboard Europe’s Copernicus Sentinel-2A, Sentinel-2B, and Sentinel-2C satellites. The combined measurement enables global observations of the land every 2–3 days at 30-meter (m) spatial resolution. The HLS project uses a set of algorithms to obtain seamless products from OLI and MSI that include atmospheric correction, cloud and cloud-shadow masking, spatial co-registration and common gridding, illumination and view angle normalization, and spectral bandpass adjustment.\n\nThe HLSL30 product provides 30-m Nadir Bidirectional Reflectance Distribution Function (BRDF)-Adjusted Reflectance (NBAR) and is derived from Landsat 8/9 OLI data products. The HLSS30 (https://doi.org/10.5067/HLS/HLSS30.002) and HLSL30 products are gridded to the same resolution and Military Grid Reference System (MGRS (https://hls.gsfc.nasa.gov/products-description/tiling-system/)) tiling system and thus are “stackable” for time series analysis.\n\nThe HLSL30 product is provided in Cloud Optimized GeoTIFF (COG) format, and each band is distributed as a separate file. There are 11 bands included in the HLSL30 product along with one quality assessment (QA) band and four angle bands. See the User Guide for a more detailed description of the individual bands provided in the HLSL30 product.',
#  'links': [{'rel': 'self',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30_2.0',
#    'type': 'application/json'},
#   {'rel': 'root',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD',
#    'type': 'application/json',
#    'title': 'LPCLOUD STAC Catalog'},
#   {'rel': 'parent',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections',
#    'type': 'application/json',
#    'title': 'Provider Collections'},
#   {'rel': 'license',
#    'href': 'https://science.nasa.gov/earth-science/earth-science-data/data-information-policy',
#    'type': 'text/html',
#    'title': 'EOSDIS Data Use Policy'},
#   {'rel': 'about',
#    'href': 'https://cmr.earthdata.nasa.gov/search/concepts/C2021957657-LPCLOUD.html',
#    'type': 'text/html',
#    'title': 'HTML metadata for collection'},
#   {'rel': 'via',
#    'href': 'https://cmr.earthdata.nasa.gov/search/concepts/C2021957657-LPCLOUD.native',
#    'type': 'application/xml',
#    'title': 'Native metadata for collection'},
#   {'rel': 'via',
#    'href': 'https://cmr.earthdata.nasa.gov/search/concepts/C2021957657-LPCLOUD.echo10',
#    'type': 'application/echo10+xml',
#    'title': 'ECHO10 metadata for collection'},
#   {'rel': 'via',
#    'href': 'https://cmr.earthdata.nasa.gov/search/concepts/C2021957657-LPCLOUD.json',
#    'type': 'application/json',
#    'title': 'CMR JSON metadata for collection'},
#   {'rel': 'via',
#    'href': 'https://cmr.earthdata.nasa.gov/search/concepts/C2021957657-LPCLOUD.umm_json',
#    'type': 'application/vnd.nasa.cmr.umm+json',
#    'title': 'CMR UMM_JSON metadata for collection'},
#   {'rel': 'items',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30_2.0/items',
#    'type': 'application/geo+json',
#    'title': 'Collection Items'}],
#  'title': 'HLS Landsat Operational Land Imager Surface Reflectance and TOA Brightness Daily Global 30m v2.0',
#  'extent': {'spatial': {'bbox': [[-180, -90, 180, 90]]},
#   'temporal': {'interval': [['2013-04-11T00:00:00Z', None]]}},
#  'license': 'proprietary',
#  'keywords': ['EARTH SCIENCE',
#   'LAND SURFACE',
#   'SURFACE RADIATIVE PROPERTIES',
#   'REFLECTANCE'],
#  'providers': [{'name': 'LPCLOUD', 'roles': ['producer']},
#   {'name': 'NASA EOSDIS', 'roles': ['host']}],
#  'summaries': {'platform': ['LANDSAT-8', 'LANDSAT-9'],
#   'instruments': ['OLI', 'OLI']},
#  'assets': {'browse': {'href': 'https://worldview.earthdata.nasa.gov/images/layers/previews/geographic/HLS_L30_Nadir_BRDF_Adjusted_Reflectance.jpg',
#    'type': 'image/jpeg',
#    'title': 'Download HLS_L30_Nadir_BRDF_Adjusted_Reflectance.jpg',
#    'roles': ['browse']},
#   'thumbnail_0': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSL30.020/HLS.L30.T03WXN.2024206T221402.v2.0/HLS.L30.T03WXN.2024206T221402.v2.0.jpg',
#    'title': 'Thumbnail [0]',
#    'description': 'Browse image for Earthdata Search',
#    'roles': ['thumbnail']},
#   'thumbnail_1': {'href': 'https://worldview.earthdata.nasa.gov/images/layers/previews/geographic/HLS_L30_Nadir_BRDF_Adjusted_Reflectance.jpg',
#    'title': 'Thumbnail [1]',
#    'description': "The URL for viewing a Worldview visualization. The Worldview tool from NASA's Earth Observing System Data and Information System (EOSDIS) provides the capability to interactively browse over 600 global, full-resolution satellite imagery layers and then download the underlying data.",
#    'roles': ['thumbnail']},
#   'nasa': {'href': 'https://appeears.earthdatacloud.nasa.gov/',
#    'title': 'Direct Download [1]',
#    'description': 'The Application for Extracting and Exploring Analysis Ready Samples (AppEEARS) offers a simple and efficient way to perform data access and transformation processes.',
#    'roles': ['data']},
#   'provider_metadata': {'href': 'https://doi.org/10.5067/HLS/HLSL30.002',
#    'title': 'Provider Metadata',
#    'description': 'The LP DAAC product page provides information on Science Data Set layers and links for user guides, ATBDs, data access, tools, customer support, etc.',
#    'roles': ['metadata']},
#   's3_lp_prod_protected_HLSL30_020': {'href': 's3://lp-prod-protected/HLSL30.020',
#    'title': 'lp_prod_protected_HLSL30_020',
#    'roles': ['data']},
#   's3_lp_prod_public_HLSL30_020': {'href': 's3://lp-prod-public/HLSL30.020',
#    'title': 'lp_prod_public_HLSL30_020',
#    'roles': ['data']},
#   's3_credentials': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/s3credentials',
#    'title': 'S3 credentials API endpoint',
#    'roles': ['metadata']},
#   's3_credentials_documentation': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/s3credentialsREADME',
#    'title': 'S3 credentials API endpoint documentation',
#    'roles': ['metadata']},
#   'metadata': {'href': 'https://cmr.earthdata.nasa.gov/search/concepts/C2021957657-LPCLOUD.xml',
#    'type': 'application/xml',
#    'title': 'CMR XML metadata for C2021957657-LPCLOUD',
#    'roles': ['metadata']}}}

# %% [markdown]
# ## Item Search

# %% [markdown]
# For this section, a spatiotemporal query is performed to filter the data assets available from a collection (or across multiple collections). The area of interest is defined using a geojson file. Additionally, the data collection(s) and time range for our example are defined.

# %%
# Open geojson file
field = gpd.read_file('../../data/ne_w_agfields.geojson')
field
# Out:
#                                             geometry
# 0  POLYGON ((-101.67272 41.04754, -101.65345 41.0...

# %%
# Visualize area of interest using hvplot
field.hvplot(tiles='ESRI', crs='EPSG:4326', line_color='yellow', line_width=2, fill_color=None)
# Out:
# :Overlay
#    .WMTS.I     :WMTS   [Longitude,Latitude]
#    .Polygons.I :Polygons   [Longitude,Latitude]

# %% [markdown]
# We will now start to specify the search criteria we are interested in, i.e., the **date range**, the **region of interest** (roi), and the **data collections**, to pass to the STAC API

# %%
# Specify area of interest
roi = field['geometry'][0].__geo_interface__
roi
# Out:
# {'type': 'Polygon',
#  'coordinates': (((-101.67271614074707, 41.04754380304359),
#    (-101.65344715118408, 41.04754380304359),
#    (-101.65344715118408, 41.06213891056728),
#    (-101.67271614074707, 41.06213891056728),
#    (-101.67271614074707, 41.04754380304359)),)}

# %% [markdown]
# Date ranges can be submitted as a start and end date with a "/". For our search we will only use year and month to define our range, but an example is included below using a full `%Y-%m-%dT%H:%M:%SZ` format.

# %%
# Specify date range
date_range = "2021-05/2021-08"
# date_range = "2021-05-01T00:00:00Z/2021-08-30T23:59:59Z"

# %% [markdown]
# A STAC Collection is synonymous with what is referred by LP DAAC as a Data Product, though within STAC, the collection name may not match exactly with the product shortname.

# %%
# Define Collections
collections =['HLSL30_2.0', 'HLSS30_2.0'] 
collections
# Out:
# ['HLSL30_2.0', 'HLSS30_2.0']

# %% [markdown]
# The CMR STAC API is a powerful search and discovery utility, allowing filtering capabilities using the STAC API specification. Below, we specify highest cloud cover percentage to keep to pass that to the query.

# %%
cloudcover = 25

# %%
# Define Search Parameters
search_params = {
    "collections": collections,
    "intersects": roi,
    "datetime": date_range,
    "query":{"eo:cloud_cover": {"lt": cloudcover}}
}

# %% [markdown]
# Now that we have our search parameters we will place them into a dictionary, then use `pystac_client` to submit the request to search the catalog.

# %%
# Perform the search
query = catalog.search(**search_params)

# %% [markdown]
# Print the number of STAC Items returned from our search.

# %%
# Count result quantity
query.matched()
# Out:
# 64

# %% [markdown]
# We now have a search object containing the STAC records that matched our query. Let's pull out all of the STAC Items (as a PySTAC ItemCollection object) and explore the contents (i.e., the STAC Items).

# %%
# Return Resulting Items
items = query.item_collection_as_dict()

# %% [markdown]
# We can view the returned STAC Items.

# %%
# items

# %% [markdown]
# Below, view the metadata record for the first item.

# %%
items['features'][0]
# Out:
# {'type': 'Feature',
#  'id': 'HLS.L30.T13TGF.2021133T172406.v2.0',
#  'stac_version': '1.0.0',
#  'stac_extensions': ['https://stac-extensions.github.io/eo/v1.0.0/schema.json'],
#  'properties': {'datetime': '2021-05-13T17:24:06.480Z',
#   'eo:cloud_cover': 25,
#   'start_datetime': '2021-05-13T17:24:06.480Z',
#   'end_datetime': '2021-05-13T17:24:30.362Z'},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[-101.344445, 40.5048858],
#     [-101.2894253, 41.4919436],
#     [-101.9209422, 41.5106056],
#     [-102.2213228, 40.5293241],
#     [-101.344445, 40.5048858]]]},
#  'bbox': [-102.2213228, 40.5048858, -101.2894253, 41.5106056],
#  'assets': {'browse': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.jpg',
#    'title': 'Download HLS.L30.T13TGF.2021133T172406.v2.0.jpg',
#    'type': 'image/jpeg',
#    'roles': ['browse']},
#   'thumbnail_0': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.jpg',
#    'title': 'Thumbnail [0]',
#    'description': 'Download HLS.L30.T13TGF.2021133T172406.v2.0.jpg',
#    'roles': ['thumbnail']},
#   'thumbnail_1': {'href': 's3://lp-prod-public/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.jpg',
#    'title': 'Thumbnail [1]',
#    'description': 'This link provides direct download access via S3 to the granule',
#    'roles': ['thumbnail']},
#   'VZA': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.VZA.tif',
#    'title': 'Direct Download [0]',
#    'description': 'Download HLS.L30.T13TGF.2021133T172406.v2.0.VZA.tif',
#    'roles': ['data']},
#   'B11': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.B11.tif',
#    'title': 'Direct Download [1]',
#    'description': 'Download HLS.L30.T13TGF.2021133T172406.v2.0.B11.tif',
#    'roles': ['data']},
#   'B04': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.B04.tif',
#    'title': 'Direct Download [2]',
#    'description': 'Download HLS.L30.T13TGF.2021133T172406.v2.0.B04.tif',
#    'roles': ['data']},
#   'SAA': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.SAA.tif',
#    'title': 'Direct Download [3]',
#    'description': 'Download HLS.L30.T13TGF.2021133T172406.v2.0.SAA.tif',
#    'roles': ['data']},
#   'B05': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.B05.tif',
#    'title': 'Direct Download [4]',
#    'description': 'Download HLS.L30.T13TGF.2021133T172406.v2.0.B05.tif',
#    'roles': ['data']},
#   'B09': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.B09.tif',
#    'title': 'Direct Download [5]',
#    'description': 'Download HLS.L30.T13TGF.2021133T172406.v2.0.B09.tif',
#    'roles': ['data']},
#   'B03': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.B03.tif',
#    'title': 'Direct Download [6]',
#    'description': 'Download HLS.L30.T13TGF.2021133T172406.v2.0.B03.tif',
#    'roles': ['data']},
#   'B06': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.B06.tif',
#    'title': 'Direct Download [7]',
#    'description': 'Download HLS.L30.T13TGF.2021133T172406.v2.0.B06.tif',
#    'roles': ['data']},
#   'Fmask': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.Fmask.tif',
#    'title': 'Direct Download [8]',
#    'description': 'Download HLS.L30.T13TGF.2021133T172406.v2.0.Fmask.tif',
#    'roles': ['data']},
#   'VAA': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.VAA.tif',
#    'title': 'Direct Download [9]',
#    'description': 'Download HLS.L30.T13TGF.2021133T172406.v2.0.VAA.tif',
#    'roles': ['data']},
#   'B07': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.B07.tif',
#    'title': 'Direct Download [10]',
#    'description': 'Download HLS.L30.T13TGF.2021133T172406.v2.0.B07.tif',
#    'roles': ['data']},
#   'SZA': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.SZA.tif',
#    'title': 'Direct Download [11]',
#    'description': 'Download HLS.L30.T13TGF.2021133T172406.v2.0.SZA.tif',
#    'roles': ['data']},
#   'B01': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.B01.tif',
#    'title': 'Direct Download [12]',
#    'description': 'Download HLS.L30.T13TGF.2021133T172406.v2.0.B01.tif',
#    'roles': ['data']},
#   'B10': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.B10.tif',
#    'title': 'Direct Download [13]',
#    'description': 'Download HLS.L30.T13TGF.2021133T172406.v2.0.B10.tif',
#    'roles': ['data']},
#   'B02': {'href': 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.B02.tif',
#    'title': 'Direct Download [14]',
#    'description': 'Download HLS.L30.T13TGF.2021133T172406.v2.0.B02.tif',
#    'roles': ['data']},
#   'metadata': {'href': 'https://cmr.earthdata.nasa.gov/search/concepts/G2144027065-LPCLOUD.xml',
#    'title': 'CMR XML metadata for G2144027065-LPCLOUD',
#    'type': 'application/xml',
#    'roles': ['metadata']}},
#  'links': [{'rel': 'self',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30_2.0/items/HLS.L30.T13TGF.2021133T172406.v2.0',
#    'type': 'application/geo+json'},
#   {'rel': 'parent',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30_2.0/',
#    'type': 'application/geo+json'},
#   {'rel': 'collection',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD/collections/HLSL30_2.0/',
#    'type': 'application/geo+json'},
#   {'rel': 'root',
#    'href': 'https://cmr.earthdata.nasa.gov/stac',
#    'type': 'application/json'},
#   {'rel': 'provider',
#    'href': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD',
#    'type': 'application/json'},
#   {'rel': 'via',
#    'href': 'https://cmr.earthdata.nasa.gov/search/concepts/G2144027065-LPCLOUD.json',
#    'title': 'CMR JSON metadata for item',
#    'type': 'application/json'},
#   {'rel': 'via',
#    'href': 'https://cmr.earthdata.nasa.gov/search/concepts/G2144027065-LPCLOUD.umm_json',
#    'title': 'CMR UMM_JSON metadata for item',
#    'type': 'application/vnd.nasa.cmr.umm+json'}],
#  'collection': 'HLSL30_2.0'}

# %% [markdown]
# We will also specify the STAC Assets (i.e., bands/layers) of interest for both the S30 and L30 collections. These differ because B8A is the NIR band for the S30 collection, while B5 is the NIR band for the L30 collection.

# %%
s30_bands = ['B8A', 'B04', 'B02', 'Fmask']
l30_bands = ['B05', 'B04', 'B02', 'Fmask']

# %% [markdown]
# Retrieve the asset links for each band from the STAC Items that match our cloud cover threshold and store them in a list.

# %%
evi_band_links = []

for i in items['features']:
    if i['collection'] == 'HLSS30_2.0':
        evi_bands = s30_bands
    elif i['collection'] == 'HLSL30_2.0':
        evi_bands = l30_bands
    for a in i['assets']:
        if a in evi_bands:
            evi_band_links.append(i['assets'][a]['href'])

# %% [markdown]
# The filtering done in the previous steps produces a list of links to STAC Assets. Let's print out the first ten links.

# %%
evi_band_links[:10]
# Out:
# ['https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.B05.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.Fmask.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T13TGF.2021133T172406.v2.0/HLS.L30.T13TGF.2021133T172406.v2.0.B02.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T14TKL.2021133T172406.v2.0/HLS.L30.T14TKL.2021133T172406.v2.0.B02.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T14TKL.2021133T172406.v2.0/HLS.L30.T14TKL.2021133T172406.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T14TKL.2021133T172406.v2.0/HLS.L30.T14TKL.2021133T172406.v2.0.B05.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T14TKL.2021133T172406.v2.0/HLS.L30.T14TKL.2021133T172406.v2.0.Fmask.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14TKL.2021133T173859.v2.0/HLS.S30.T14TKL.2021133T173859.v2.0.B04.tif',
#  'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T14TKL.2021133T173859.v2.0/HLS.S30.T14TKL.2021133T173859.v2.0.B8A.tif']

# %% [markdown]
# Save the link lists as a text file.

# %%
name = 'HTTPS_HLS_Links.txt'
with open(f'../../data/{name}', 'w') as f:
    for link in evi_band_links:
        f.write(link + "\n")

# %% [markdown]
# You can also write links for S3 direct access in a separate text file.

# %%
name = 'S3_HLS_Links.txt'
with open(f'../../data/{name}', 'w') as f:
    for link in evi_band_links:
        s3 = link.replace('https://data.lpdaac.earthdatacloud.nasa.gov/', 's3://')
        f.write(s3 + "\n")

# %% [markdown]
# ## Additional Resources
#
# - https://github.com/nasa/cmr-stac
# - https://stacspec.org/
# - https://pystac-client.readthedocs.io/en/latest/index.html

# %% [markdown]
# ## Contact Info:
#
# Email: LPDAAC@usgs.gov
# Voice: +1-866-573-3222
# Organization: Land Processes Distributed Active Archive Center (LP DAAC)¹
# Website: <https://lpdaac.usgs.gov/>
#
# ¹Work performed under USGS contract G15PD00467 for NASA contract NNG14HH33I.
